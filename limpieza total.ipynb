# %%
import pandas as pd

def normalizar_nombres(nombres):
    nombres = nombres.lower().replace(" ", "_") 
    nombres = nombres.replace('á', 'a').replace('é', 'e').replace('í', 'i').replace('ó', 'o').replace('ü', 'u').replace('ú', 'u')
    nombres = nombres.replace('Á', 'a').replace('É', 'e').replace('Í', 'i').replace('Ó', 'o').replace('Ú', 'u')
    return nombres

def limpiar_columnas(df):
    df.columns = [normalizar_nombres(col) for col in df.columns]
    
    columnas_numericas = ['precio_m2', 'precio', 'superficie', 'superficie_util', 'superficie_solar', 
                          'superficie_construida', 'codigo_postal']
    
    for col in columnas_numericas:
        df[col] = df[col].astype(str).str.replace('.', '', regex=False).str.replace(' €/m²', '', regex=False).str.replace(' €', '', regex=False).str.replace(' m²', '', regex=False)
        df[col] = pd.to_numeric(df[col], errors='coerce')
    
    # Convertir columnas a datetime o entero
    df['actualizacion'] = df['actualizacion'].str.extract(r'(\d{2}/\d{2}/\d{4})')
    df['actualizacion'] = pd.to_datetime(df['actualizacion'], format='%d/%m/%Y', errors='coerce')
    df['timestamp'] = pd.to_datetime(df['actualizacion'], errors='coerce')
    df['baños'] = df['baños'].astype('Int64')
    df['habitaciones'] = df['habitaciones'].astype('Int64')
    
    # Columna 'planta'
    df['planta'] = df['planta'].str.replace('ª', '', regex=False).str.strip()
    df['planta'] = df['planta'].replace({'Bajo': 0, 'Principal': 0, 'Semisótano': -1, 'Entresuelo': -1, 'Sótano': -1, 'Más de 20': 21})
    df['planta'] = df['planta'].astype('float64').astype('Int64')
    
    columnas_conflictivas = ['luz', 'sistema_de_seguridad', 'vidrios_dobles', 
                             'se_aceptan_mascotas', 'carpinteria_interior', 'calefaccion', 'jardin',
                             'trastero', 'calle_asfaltada', 'cocina_equipada', 'agua', 
                             'aire_acondicionado', 'terraza', 'armarios_empotrados', 'balcon', 
                             'gastos_de_comunidad', 'urbanizado', 'garaje', 'puerta_blindada', 
                             'adaptado_a_personas_con_movilidad_reducida', 'ascensor', 'alcantarillado', 
                             'portero_automatico', 'exterior', 'soleado', 'piscina', 'calle_alumbrada', 
                             'lavadero', 'amueblado', 'interior', 'gas', 'tipo_suelo', 
                             'carpinteria_exterior', 'comedor', 'chimenea', 'no_se_aceptan_mascotas', 'telefono']
    #Las columnas conflictivas por defecto serán Si, a no ser que tengan un "No y se seguiran manteniendo nans
    #serán category: Si, No y Nan
    def limpiar_columnas_conflictivas(valor):
        if pd.isna(valor) or valor.strip() == "":
            return valor 
        elif "no" in valor.lower().split():  
            return "No"
        else:
            return "Si"
    
    for col in columnas_conflictivas:
        df[col] = df[col].apply(limpiar_columnas_conflictivas)
        df[col] = df[col].astype('category')  # Convertir a tipo 'category'
    
    # Eliminar duplicados y referencia
    df = df.drop_duplicates(subset='identificador', keep='first')
    df = df.drop(columns=['referencia'])
    
    # Columna 'se_aceptan_mascotas' 
    df['se_aceptan_mascotas'] = df.apply(lambda row: 'Si' if row['se_aceptan_mascotas'] == 'Si' else 
                                         ('No' if row['no_se_aceptan_mascotas'] == 'Si' else 'N/A'), axis=1)
    # Convertirla en category de Si, No y N/A uniendo y borrando no_se_aceptan_mascotas
    df['se_aceptan_mascotas'] = df['se_aceptan_mascotas'].astype('category')
    df = df.drop(columns=['no_se_aceptan_mascotas'])
    
    # Columna orientacion
    mapeo_direcciones = {
        'norte': 'NORTE', 'n': 'NORTE', 'sur': 'SUR', 's': 'SUR', 
        'este': 'ESTE', 'e': 'ESTE', 'oeste': 'OESTE', 'o': 'OESTE', 
        'suroeste': 'SUROESTE', 'so': 'SUROESTE', 'sureste': 'SURESTE', 
        'se': 'SURESTE', 'noreste': 'NORESTE', 'ne': 'NORESTE', 
        'noroeste': 'NOROESTE', 'no': 'NOROESTE', 'este-sur': 'SURESTE', 
        'sur-oeste': 'SUROESTE', 'norte|este': 'NORESTE', 'norte|oeste': 'NOROESTE',
        'sur|este': 'SURESTE', 'north/east': 'NORESTE', 'north/west': 'NOROESTE',
        'south/east': 'SURESTE', 'south/west': 'SUROESTE', 'sur|oeste': 'SUROESTE',
        'norte|este|oeste': 'NORTE', 'se': 'SURESTE', 'sur, este, oeste': 'SUR',
        'norte::este': 'NORESTE', 'norte::oeste': 'NOROESTE', 'sur::este': 'SURESTE', 
        'sur::oeste': 'SUROESTE', 'sur::este::oeste': 'SUR'
    }
    df['orientacion'] = df['orientacion'].str.lower().map(mapeo_direcciones).fillna('SIN ESPECIFICAR')
    
    return df

df = pd.read_csv("alquileres_scrap_completo.csv")
dfalquileres = limpiar_columnas(df)
dfalquileres.to_csv("alquilereslimpio.csv", index=False)

# %%
dfalquileres.columns
# Out:
# Index(['luz', 'jardin', 'sistema_de_seguridad', 'conservacion',
#        'vidrios_dobles', 'se_aceptan_mascotas', 'timestamp',
#        'carpinteria_interior', 'calefaccion', 'trastero', 'href',
#        'calle_asfaltada', 'tipo_de_casa', 'cocina_equipada', 'agua',
#        'emisiones', 'aire_acondicionado', 'terraza', 'armarios_empotrados',
#        'actualizacion', 'superficie', 'balcon', 'gastos_de_comunidad',
#        'urbanizado', 'superficie_construida', 'garaje', 'consumo',
#        'puerta_blindada', 'adaptado_a_personas_con_movilidad_reducida',
#        'identificador', 'ascensor', 'superficie_util', 'nombre',
#        'alcantarillado', 'planta', 'baños', 'portero_automatico', 'exterior',
#        'soleado', 'piscina', 'calle_alumbrada', 'precio_m2', 'precio',
#        'lavadero', 'orientacion', 'amueblado', 'interior', 'habitaciones',
#        'gas', 'tipo_suelo', 'carpinteria_exterior', 'superficie_solar',
#        'comedor', 'antiguedad', 'codigo_postal', 'ubicacion', 'agencia',
#        'chimenea', 'telefono'],
#       dtype='object')

# %%
for col in dfalquileres.columns:
    print(f"Valores únicos para la columna {col}:")
    print(dfalquileres[col].unique())
    print("-" * 40)
# Out:
# Valores únicos para la columna luz:
# [NaN, 'Si']
# Categories (1, object): ['Si']
# ----------------------------------------
# Valores únicos para la columna jardin:
# [NaN, 'Si']
# Categories (1, object): ['Si']
# ----------------------------------------
# Valores únicos para la columna sistema_de_seguridad:
# [NaN, 'Si']
# Categories (1, object): ['Si']
# ----------------------------------------
# Valores únicos para la columna conservacion:
# [nan 'En buen estado' 'Reformado' 'A estrenar' 'A reformar']
# ----------------------------------------
# Valores únicos para la columna vidrios_dobles:
# [NaN, 'Si', 'No']
# Categories (2, object): ['No', 'Si']
# ----------------------------------------
# Valores únicos para la columna se_aceptan_mascotas:
# ['N/A', 'No', 'Si']
# Categories (3, object): ['N/A', 'No', 'Si']
# ----------------------------------------
# Valores únicos para la columna timestamp:
# ['2025-02-21 11:52:59' '2025-02-21 11:53:00' '2025-02-21 11:53:01' ...
#  '2025-02-21 13:09:04' '2025-02-21 13:09:05' '2025-02-21 13:09:06']
# ----------------------------------------
# Valores únicos para la columna carpinteria_interior:
# [NaN, 'Si']
# Categories (1, object): ['Si']
# ----------------------------------------
# Valores únicos para la columna calefaccion:
# [NaN, 'Si', 'No']
# Categories (2, object): ['No', 'Si']
# ----------------------------------------
# Valores únicos para la columna trastero:
# [NaN, 'Si']
# Categories (1, object): ['Si']
# ----------------------------------------
# Valores únicos para la columna href:
# ['https://www.pisos.com/alquilar/piso-plaza_de_toros_santa_rita04004-40920273409_100500/'
#  'https://www.pisos.com/alquilar/piso-oliveros_altamira_barrio_alto04005-15062564089_100500/'
#  'https://www.pisos.com/alquilar/piso-ciudad_jardin_tagarete_zapillo-658149002_501470/'
#  ...
#  'https://www.pisos.com/alquilar/apartamento-km_0_km_3-43392414912_109800/'
#  'https://www.pisos.com/alquilar/apartamento-km_0_km_3-945856909436630_109800/'
#  'https://www.pisos.com/alquilar/piso-km_6_km_830380-44201590595_109800/']
# ----------------------------------------
# Valores únicos para la columna calle_asfaltada:
# [NaN, 'Si']
# Categories (1, object): ['Si']
# ----------------------------------------
# Valores únicos para la columna tipo_de_casa:
# [nan 'Unifamiliar' 'Adosada' 'Rústica' 'Pareada']
# ----------------------------------------
# Valores únicos para la columna cocina_equipada:
# [NaN, 'Si', 'No']
# Categories (2, object): ['No', 'Si']
# ----------------------------------------
# Valores únicos para la columna agua:
# ['Si', NaN]
# Categories (1, object): ['Si']
# ----------------------------------------
# Valores únicos para la columna emisiones:
# ['Error al procesar emisiones' 'E, D' 'G, F' 'G, E' 'E, E' 'G, G' 'F, E'
#  'F, F' 'D, C' 'C, C' 'D, D' 'A, A' 'E, F' 'B, B' 'C, B' 'B, G' 'B, A'
#  'D, E' 'A, B' 'C, G' 'E, G' 'C, D' 'C, A' 'E, B' 'F, G' 'D, F' 'E, C'
#  'D, A' 'A, E' 'B, C' 'E, A' 'C, E' 'B, E']
# ----------------------------------------
# Valores únicos para la columna aire_acondicionado:
# ['Si', NaN, 'No']
# Categories (2, object): ['No', 'Si']
# ----------------------------------------
# Valores únicos para la columna terraza:
# [NaN, 'Si', 'No']
# Categories (2, object): ['No', 'Si']
# ----------------------------------------
# Valores únicos para la columna armarios_empotrados:
# ['Si', NaN, 'No']
# Categories (2, object): ['No', 'Si']
# ----------------------------------------
# Valores únicos para la columna actualizacion:
# <DatetimeArray>
# ['2025-02-21 00:00:00', '2025-02-20 00:00:00', '2025-02-13 00:00:00',
#  '2025-02-07 00:00:00', '2025-02-11 00:00:00', '2025-02-18 00:00:00',
#  '2025-02-16 00:00:00', '2025-02-14 00:00:00', '2025-01-17 00:00:00',
#  '2024-08-25 00:00:00',
#  ...
#  '2024-05-03 00:00:00', '2024-02-22 00:00:00', '2024-05-06 00:00:00',
#  '2023-12-21 00:00:00', '2023-10-30 00:00:00', '2023-06-14 00:00:00',
#  '2023-11-17 00:00:00', '2024-03-12 00:00:00', '2023-05-17 00:00:00',
#  '2022-09-19 00:00:00']
# Length: 333, dtype: datetime64[ns]
# ----------------------------------------
# Valores únicos para la columna superficie:
# [7.80000000e+01 1.02000000e+02 9.50000000e+01 9.80000000e+01
#  7.40000000e+01 7.50000000e+01 8.50000000e+01 1.00000000e+02
#  7.30000000e+01 1.20000000e+02 4.50000000e+01 1.25000000e+02
#  1.17000000e+02 7.00000000e+01 1.10000000e+02 7.10000000e+01
#  4.00000000e+01 5.10000000e+01 1.05000000e+02 1.50000000e+02
#  9.00000000e+01 6.00000000e+01 1.21000000e+02 1.31000000e+02
#  1.13000000e+02 1.12000000e+02 2.10000000e+02 9.20000000e+01
#  1.04000000e+02 1.18000000e+02 1.68000000e+02 5.50000000e+01
#  1.15000000e+02 1.08000000e+02 1.07000000e+02 8.00000000e+01
#  7.70000000e+01 1.01000000e+02 1.30000000e+02 8.90000000e+01
#  1.28000000e+02 5.00000000e+01 6.50000000e+01 8.80000000e+01
#  8.60000000e+01 1.46000000e+02 1.03000000e+02 9.40000000e+01
#  1.45000000e+02 7.20000000e+01 1.34000000e+02 9.60000000e+01
#  3.19000000e+02 1.11000000e+02 1.48000000e+02 6.80000000e+01
#  1.90000000e+02 1.38000000e+02 1.35000000e+02 2.40000000e+02
#  1.24000000e+02 3.50000000e+01 1.26000000e+02 1.37000000e+02
#  8.40000000e+01 2.85000000e+02 9.70000000e+01 3.20000000e+01
#  1.19000000e+02 6.60000000e+01 5.90000000e+01 9.30000000e+01
#  1.80000000e+02 1.53000000e+02 1.70000000e+02 7.90000000e+01
#  4.10000000e+01 1.59000000e+02 2.30000000e+02 9.00000000e+00
#  4.60000000e+01 8.70000000e+01 9.10000000e+01 6.40000000e+01
#  5.20000000e+01 7.60000000e+01 3.00000000e+01 4.20000000e+01
#  6.10000000e+01 5.80000000e+01 5.60000000e+01 8.20000000e+01
#  1.40000000e+02 5.70000000e+01 4.70000000e+01 4.00000000e+02
#  1.65000000e+02 4.80000000e+01 2.00000000e+02 9.90000000e+01
#  6.90000000e+01 5.30000000e+01 6.70000000e+01 1.39200000e+03
#  6.20000000e+01            nan 1.00000000e+03 2.05000000e+02
#  4.90000000e+01 2.00000000e+00 1.60000000e+02 1.89000000e+02
#  1.47000000e+02 2.50000000e+02 3.00000000e+02 2.80000000e+02
#  2.20000000e+02 1.16000000e+02 2.65000000e+02 5.00000000e+02
#  6.00000000e+02 9.60000000e+02 4.30000000e+01 1.71000000e+02
#  8.10000000e+01 2.35000000e+02 2.50000000e+01 1.20000000e+01
#  2.24000000e+02 1.85000000e+02 1.43000000e+02 3.70000000e+01
#  8.30000000e+01 1.06000000e+02 3.00000000e+00 1.14000000e+02
#  1.00000000e+00 4.40000000e+01 3.90000000e+01 1.36000000e+02
#  3.60000000e+01 2.70000000e+02 1.95000000e+02 1.55000000e+02
#  1.57000000e+02 1.72000000e+02 2.28000000e+02 6.30000000e+01
#  2.13000000e+02 2.90000000e+01 1.29000000e+02 1.22000000e+02
#  2.40000000e+01 4.05000000e+02 1.09000000e+02 1.32000000e+02
#  3.80000000e+01 2.23000000e+02 1.86000000e+02 1.56000000e+02
#  2.01000000e+02 5.01000000e+02 1.98000000e+02 2.84000000e+02
#  1.39000000e+02 1.33000000e+02 2.31000000e+02 3.15000000e+02
#  1.97000000e+02 1.52000000e+02 1.84000000e+02 3.30000000e+01
#  1.23000000e+02 2.43000000e+02 1.61000000e+02 7.80000000e+02
#  9.90000000e+02 7.40000000e+02 4.90000000e+02 8.40000000e+02
#  1.46000000e+03 1.92000000e+02 2.00000000e+03 3.83000000e+02
#  2.76000000e+02 2.29000000e+02 1.69000000e+02 3.80000000e+02
#  2.60000000e+02 3.20000000e+02 1.15700000e+03 4.50000000e+02
#  4.66000000e+02 1.44000000e+02 1.41000000e+02 3.05000000e+02
#  7.60000000e+02 1.66000000e+02 4.10000000e+02 5.80000000e+02
#  1.79000000e+02 6.50000000e+02 3.50000000e+02 4.65000000e+02
#  3.10000000e+02 9.95000000e+02 2.50000000e+03 7.00000000e+02
#  2.09000000e+02 2.18000000e+02 1.73000000e+02 2.39000000e+02
#  8.04000000e+02 1.01400000e+03 2.25000000e+02 5.00000000e+00
#  3.90000000e+02 1.50000000e+03 4.31000000e+02 1.74000000e+02
#  6.72000000e+02 8.60000000e+02 2.04000000e+02 1.88000000e+02
#  3.74000000e+02 2.86000000e+02 1.13800000e+03 5.78000000e+02
#  2.81000000e+02 3.29000000e+02 1.75000000e+02 3.60000000e+02
#  5.71000000e+02 1.35000000e+03 1.04000000e+03 3.36000000e+02
#  8.05000000e+02 1.20000000e+03 1.49000000e+02 3.69000000e+02
#  1.05400000e+03 9.80000000e+02 4.36000000e+02 4.55000000e+02
#  2.97000000e+02 6.32000000e+02 5.50000000e+02 3.82000000e+02
#  3.70000000e+02 2.15000000e+02 6.67000000e+02 9.10000000e+02
#  1.54000000e+02 1.81000000e+02 3.79000000e+02 4.48000000e+02
#  6.29000000e+02 7.50000000e+02 1.87500000e+03 2.72000000e+02
#  9.00000000e+02 1.05000000e+03 3.30000000e+02 8.00000000e+02
#  1.78000000e+02 1.64000000e+02 1.94000000e+02 2.95000000e+02
#  4.20000000e+02 3.33000000e+02 3.17000000e+02 2.27000000e+02
#  5.40000000e+02 1.51000000e+02 3.75000000e+02 3.28000000e+02
#  4.29000000e+02 1.83000000e+02 1.62000000e+02 2.10000000e+01
#  2.37000000e+02 3.13000000e+02 1.76000000e+02 2.59000000e+02
#  2.30000000e+01 1.27000000e+02 3.40000000e+01 5.20000000e+02
#  1.82000000e+02 3.88000000e+02 1.63000000e+02 9.30000000e+02
#  4.03000000e+02 3.94000000e+02 6.15000000e+02 2.20000000e+01
#  3.40000000e+02 5.61000000e+02 1.18300000e+03 1.58000000e+02
#  3.89000000e+02 2.49000000e+02 2.74000000e+02 2.71000000e+02
#  1.93000000e+02 3.38300000e+03 6.53900000e+03 8.74000000e+02
#  2.03000000e+02 2.55000000e+02 5.40000000e+01 9.12000000e+03
#  2.32000000e+02 4.00000000e+00 3.91000000e+02 2.94000000e+02
#  1.50000000e+01 2.91000000e+02 8.79000000e+03 2.67000000e+02
#  2.70000000e+01 2.14000000e+02 2.34000000e+02 1.87000000e+02
#  1.50700000e+03 1.80000000e+01 2.44000000e+02 2.96000000e+02
#  3.00000000e+03 3.10000000e+01 2.70000000e+03 3.61000000e+02
#  2.75000000e+02 4.38000000e+02 5.46000000e+02 1.77000000e+02
#  2.17000000e+02 2.07000000e+02 2.12000000e+02 2.60000000e+01
#  2.93000000e+02 5.84000000e+02 2.41000000e+02 2.11000000e+02
#  2.06000000e+02 1.96000000e+02 1.67000000e+02 2.38000000e+02
#  3.32000000e+02 4.70000000e+02 5.11000000e+02 6.31000000e+02
#  3.76000000e+02 2.66000000e+02 2.02000000e+02 3.59000000e+02
#  5.45000000e+02 2.68000000e+02 2.89000000e+02 7.17000000e+02
#  4.80000000e+02 2.90000000e+02 3.12000000e+02 3.53000000e+02
#  3.39000000e+02 4.94000000e+02 3.14000000e+02 3.92000000e+02
#  3.45000000e+02 2.56000000e+02 2.22000000e+02 2.54000000e+02
#  9.05000000e+02 8.55000000e+02 9.40000000e+02 8.80000000e+02
#  9.75000000e+02 8.65000000e+02 3.81000000e+02 2.51000000e+02
#  4.08000000e+02 3.22000000e+02 8.90000000e+02 1.24000000e+03
#  8.10000000e+02 9.20000000e+02 1.06000000e+03 8.50000000e+02
#  1.03700000e+03 1.01000000e+03 1.02000000e+03 6.16000000e+02
#  9.50000000e+02 6.70000000e+02 3.66000000e+02 2.80000000e+01
#  1.42000000e+02 1.99000000e+02 1.91000000e+02 2.33000000e+02
#  1.95900000e+03 1.10000000e+01 2.42000000e+02 4.40000000e+02
#  2.21000000e+02 2.08000000e+02 2.48000000e+02 4.30000000e+02
#  4.79000000e+02 2.83000000e+02 2.64000000e+02 5.52000000e+02
#  5.43000000e+02 3.34000000e+02 5.57000000e+02 2.36000000e+02
#  4.59000000e+02 5.10000000e+02 2.73000000e+02 5.70000000e+02
#  3.06000000e+02 2.00000000e+01 2.47000000e+02 4.92000000e+02
#  6.30000000e+02 3.35000000e+02 3.25000000e+02 4.82000000e+02
#  2.45000000e+02 4.63000000e+02 2.63000000e+02 4.11000000e+02
#  2.77000000e+02 3.07000000e+02 1.90000000e+01 6.10000000e+02
#  7.73000000e+02 3.78000000e+02 7.64000000e+02 4.75000000e+02
#  5.30000000e+02 1.15800000e+03 5.90000000e+02 2.50700000e+03
#  1.17000000e+03 3.58000000e+02 4.35000000e+02 3.11000000e+02
#  2.69000000e+02 2.78000000e+02 4.99000000e+02 2.98000000e+02
#  3.67000000e+02 2.79000000e+02 6.52000000e+02 2.16000000e+02
#  1.25000000e+03 9.70000000e+02 1.90000000e+03 2.52000000e+02
#  7.10000000e+02 1.80000000e+03 3.57000000e+02 1.43000000e+03
#  2.53000000e+02 1.09000000e+03 8.20000000e+02 3.43000000e+02
#  8.63000000e+02 1.45000000e+03 6.90000000e+02 5.85000000e+02
#  2.61000000e+02 7.04000000e+02 7.90000000e+02 1.56000000e+03
#  2.14700000e+03 1.70000000e+03 4.16000000e+02 2.26000000e+02
#  1.08000000e+03 1.00000000e+01 5.06000000e+02 8.06000000e+02
#  1.60000000e+01 4.37000000e+02 1.30000000e+01 3.37000000e+02
#  4.32000000e+02 1.44700000e+03 3.46000000e+02 1.40000000e+01
#  4.28000000e+02 6.93000000e+02 7.28000000e+02 3.68000000e+02
#  1.75200000e+03 4.49000000e+02 1.44200000e+03 7.68000000e+02
#  4.12000000e+02 3.95000000e+02 4.14000000e+02 2.46000000e+02
#  4.07000000e+02 2.82000000e+02 6.52454969e+08 6.60000000e+03
#  3.62000000e+02 5.21000000e+02 3.24000000e+02 3.55000000e+02
#  1.18000000e+03 3.64000000e+02 6.00000000e+00 6.83000000e+02
#  3.10700000e+03 5.70000000e+03 5.37000000e+02 6.60000000e+02
#  3.85000000e+02 5.29000000e+02 6.45000000e+02 4.02000000e+02
#  5.02000000e+02 3.16000000e+02 4.09400000e+03 7.50000000e+03
#  3.65000000e+02 7.66000000e+02 4.60000000e+02 4.01000000e+02
#  5.76000000e+02 1.35135000e+05 4.21000000e+02 7.85000000e+02
#  1.01800000e+03 5.07000000e+02]
# ----------------------------------------
# Valores únicos para la columna balcon:
# [NaN, 'Si']
# Categories (1, object): ['Si']
# ----------------------------------------
# Valores únicos para la columna gastos_de_comunidad:
# [NaN, 'Si', 'No']
# Categories (2, object): ['No', 'Si']
# ----------------------------------------
# Valores únicos para la columna urbanizado:
# [NaN, 'Si']
# Categories (1, object): ['Si']
# ----------------------------------------
# Valores únicos para la columna superficie_construida:
# [7.80000000e+01 1.02000000e+02 9.50000000e+01 9.80000000e+01
#  7.40000000e+01 7.50000000e+01 8.50000000e+01 1.00000000e+02
#  7.30000000e+01 1.20000000e+02 4.50000000e+01 1.25000000e+02
#  1.17000000e+02 7.00000000e+01 1.10000000e+02 7.10000000e+01
#  4.00000000e+01 5.10000000e+01 1.05000000e+02 1.50000000e+02
#  9.00000000e+01 6.00000000e+01 1.21000000e+02 1.31000000e+02
#  1.13000000e+02 1.12000000e+02 2.10000000e+02 9.20000000e+01
#  1.04000000e+02 1.18000000e+02 1.68000000e+02 5.50000000e+01
#  1.15000000e+02 1.08000000e+02 1.07000000e+02 8.00000000e+01
#  7.70000000e+01 1.01000000e+02 1.30000000e+02 8.90000000e+01
#  1.28000000e+02 5.00000000e+01 6.50000000e+01 8.80000000e+01
#  8.60000000e+01 1.46000000e+02 1.03000000e+02 9.40000000e+01
#  1.45000000e+02 7.20000000e+01 1.34000000e+02 9.60000000e+01
#  3.19000000e+02 1.11000000e+02 1.48000000e+02 6.80000000e+01
#  1.90000000e+02 1.38000000e+02 1.35000000e+02 2.40000000e+02
#  1.24000000e+02 3.50000000e+01 1.26000000e+02 1.37000000e+02
#  8.40000000e+01 2.85000000e+02 9.70000000e+01 3.20000000e+01
#  1.19000000e+02 6.60000000e+01 5.90000000e+01 9.30000000e+01
#  1.80000000e+02 1.53000000e+02 1.70000000e+02 7.90000000e+01
#  4.10000000e+01 1.59000000e+02 2.30000000e+02 9.00000000e+00
#  4.60000000e+01 8.70000000e+01 9.10000000e+01 6.40000000e+01
#  5.20000000e+01 7.60000000e+01 3.00000000e+01 4.20000000e+01
#  6.10000000e+01 5.80000000e+01 5.60000000e+01 8.20000000e+01
#  1.40000000e+02 5.70000000e+01 4.70000000e+01 4.00000000e+02
#  1.65000000e+02 4.80000000e+01 2.00000000e+02 9.90000000e+01
#  6.90000000e+01 5.30000000e+01 6.70000000e+01 1.39200000e+03
#  6.20000000e+01            nan 1.00000000e+03 2.05000000e+02
#  4.90000000e+01 1.60000000e+02 1.89000000e+02 1.47000000e+02
#  2.50000000e+02 3.00000000e+02 2.80000000e+02 2.20000000e+02
#  1.16000000e+02 2.65000000e+02 5.00000000e+02 6.00000000e+02
#  9.60000000e+02 4.30000000e+01 1.71000000e+02 8.10000000e+01
#  2.35000000e+02 2.50000000e+01 1.20000000e+01 2.24000000e+02
#  1.85000000e+02 1.43000000e+02 3.70000000e+01 8.30000000e+01
#  1.06000000e+02 1.14000000e+02 4.40000000e+01 3.90000000e+01
#  1.36000000e+02 3.60000000e+01 2.70000000e+02 1.95000000e+02
#  1.55000000e+02 1.57000000e+02 1.72000000e+02 2.28000000e+02
#  6.30000000e+01 2.13000000e+02 2.90000000e+01 1.29000000e+02
#  1.22000000e+02 2.40000000e+01 4.05000000e+02 1.09000000e+02
#  1.32000000e+02 3.80000000e+01 2.23000000e+02 1.86000000e+02
#  1.56000000e+02 2.01000000e+02 5.01000000e+02 1.98000000e+02
#  2.84000000e+02 1.39000000e+02 1.33000000e+02 2.31000000e+02
#  3.15000000e+02 1.97000000e+02 1.52000000e+02 1.84000000e+02
#  3.30000000e+01 1.23000000e+02 2.43000000e+02 1.61000000e+02
#  7.80000000e+02 9.90000000e+02 7.40000000e+02 4.90000000e+02
#  8.40000000e+02 1.46000000e+03 1.92000000e+02 2.00000000e+03
#  3.83000000e+02 2.76000000e+02 2.29000000e+02 1.00000000e+00
#  1.69000000e+02 3.80000000e+02 2.60000000e+02 3.20000000e+02
#  1.15700000e+03 4.50000000e+02 4.66000000e+02 1.44000000e+02
#  1.41000000e+02 3.05000000e+02 7.60000000e+02 1.66000000e+02
#  4.10000000e+02 5.80000000e+02 1.79000000e+02 6.50000000e+02
#  3.50000000e+02 4.65000000e+02 3.10000000e+02 9.95000000e+02
#  2.50000000e+03 7.00000000e+02 2.09000000e+02 2.18000000e+02
#  1.73000000e+02 2.39000000e+02 8.04000000e+02 1.01400000e+03
#  2.25000000e+02 3.90000000e+02 1.50000000e+03 4.31000000e+02
#  1.74000000e+02 6.72000000e+02 8.60000000e+02 2.04000000e+02
#  1.88000000e+02 3.74000000e+02 2.86000000e+02 1.13800000e+03
#  5.78000000e+02 2.81000000e+02 3.29000000e+02 1.75000000e+02
#  3.60000000e+02 5.71000000e+02 1.35000000e+03 1.04000000e+03
#  3.36000000e+02 8.05000000e+02 1.20000000e+03 1.49000000e+02
#  3.69000000e+02 1.05400000e+03 9.80000000e+02 4.36000000e+02
#  4.55000000e+02 2.97000000e+02 6.32000000e+02 5.50000000e+02
#  3.82000000e+02 3.70000000e+02 2.15000000e+02 6.67000000e+02
#  9.10000000e+02 1.54000000e+02 1.81000000e+02 3.79000000e+02
#  4.48000000e+02 6.29000000e+02 7.50000000e+02 1.87500000e+03
#  2.72000000e+02 9.00000000e+02 1.05000000e+03 3.30000000e+02
#  8.00000000e+02 1.78000000e+02 1.64000000e+02 1.94000000e+02
#  2.95000000e+02 4.20000000e+02 3.33000000e+02 3.17000000e+02
#  2.27000000e+02 5.40000000e+02 1.51000000e+02 3.75000000e+02
#  3.28000000e+02 4.29000000e+02 1.83000000e+02 1.62000000e+02
#  2.10000000e+01 2.37000000e+02 3.13000000e+02 1.76000000e+02
#  2.59000000e+02 2.30000000e+01 1.27000000e+02 3.40000000e+01
#  5.20000000e+02 1.82000000e+02 3.88000000e+02 1.63000000e+02
#  9.30000000e+02 4.03000000e+02 3.94000000e+02 6.15000000e+02
#  2.20000000e+01 3.40000000e+02 5.61000000e+02 1.18300000e+03
#  1.58000000e+02 3.89000000e+02 2.49000000e+02 2.74000000e+02
#  2.71000000e+02 1.93000000e+02 3.38300000e+03 6.53900000e+03
#  8.74000000e+02 2.03000000e+02 2.55000000e+02 5.40000000e+01
#  9.12000000e+03 2.32000000e+02 3.91000000e+02 2.94000000e+02
#  1.50000000e+01 2.91000000e+02 8.79000000e+03 2.67000000e+02
#  2.70000000e+01 2.14000000e+02 2.34000000e+02 1.87000000e+02
#  1.80000000e+01 2.44000000e+02 2.96000000e+02 3.00000000e+03
#  3.10000000e+01 2.70000000e+03 3.61000000e+02 2.75000000e+02
#  4.38000000e+02 5.46000000e+02 1.77000000e+02 2.17000000e+02
#  2.07000000e+02 2.12000000e+02 2.60000000e+01 2.93000000e+02
#  5.84000000e+02 2.41000000e+02 2.11000000e+02 2.06000000e+02
#  1.96000000e+02 1.67000000e+02 2.38000000e+02 3.32000000e+02
#  4.70000000e+02 5.11000000e+02 6.31000000e+02 3.76000000e+02
#  2.66000000e+02 2.02000000e+02 3.59000000e+02 5.45000000e+02
#  2.68000000e+02 2.89000000e+02 7.17000000e+02 4.80000000e+02
#  2.90000000e+02 3.12000000e+02 3.53000000e+02 3.39000000e+02
#  4.94000000e+02 3.14000000e+02 3.92000000e+02 3.45000000e+02
#  2.56000000e+02 2.22000000e+02 2.54000000e+02 9.05000000e+02
#  8.55000000e+02 9.40000000e+02 8.80000000e+02 9.75000000e+02
#  8.65000000e+02 3.81000000e+02 2.51000000e+02 4.08000000e+02
#  3.22000000e+02 8.90000000e+02 1.24000000e+03 8.10000000e+02
#  9.20000000e+02 1.06000000e+03 8.50000000e+02 1.03700000e+03
#  1.01000000e+03 1.02000000e+03 6.16000000e+02 9.50000000e+02
#  6.70000000e+02 3.66000000e+02 2.80000000e+01 1.42000000e+02
#  1.99000000e+02 1.91000000e+02 2.33000000e+02 1.95900000e+03
#  1.10000000e+01 2.42000000e+02 4.40000000e+02 2.21000000e+02
#  2.08000000e+02 2.48000000e+02 4.30000000e+02 4.79000000e+02
#  2.83000000e+02 2.64000000e+02 5.52000000e+02 5.43000000e+02
#  3.34000000e+02 5.57000000e+02 2.36000000e+02 4.59000000e+02
#  5.10000000e+02 2.73000000e+02 5.70000000e+02 3.06000000e+02
#  2.00000000e+01 2.47000000e+02 4.92000000e+02 6.30000000e+02
#  3.35000000e+02 3.25000000e+02 4.82000000e+02 2.45000000e+02
#  4.63000000e+02 2.63000000e+02 4.11000000e+02 2.77000000e+02
#  3.07000000e+02 1.90000000e+01 6.10000000e+02 7.73000000e+02
#  3.78000000e+02 7.64000000e+02 4.75000000e+02 5.30000000e+02
#  1.15800000e+03 5.90000000e+02 1.17000000e+03 3.58000000e+02
#  4.35000000e+02 3.11000000e+02 2.69000000e+02 2.78000000e+02
#  4.99000000e+02 2.98000000e+02 3.67000000e+02 2.79000000e+02
#  6.52000000e+02 2.16000000e+02 1.25000000e+03 9.70000000e+02
#  1.90000000e+03 2.52000000e+02 7.10000000e+02 1.80000000e+03
#  3.57000000e+02 1.43000000e+03 2.53000000e+02 1.09000000e+03
#  8.20000000e+02 3.43000000e+02 8.63000000e+02 1.45000000e+03
#  6.90000000e+02 5.85000000e+02 2.61000000e+02 7.04000000e+02
#  7.90000000e+02 1.56000000e+03 2.14700000e+03 1.70000000e+03
#  2.26000000e+02 1.08000000e+03 1.00000000e+01 5.06000000e+02
#  8.06000000e+02 1.60000000e+01 4.37000000e+02 1.30000000e+01
#  3.37000000e+02 4.32000000e+02 1.44700000e+03 3.46000000e+02
#  1.40000000e+01 4.28000000e+02 6.93000000e+02 7.28000000e+02
#  3.68000000e+02 1.75200000e+03 4.49000000e+02 1.44200000e+03
#  7.68000000e+02 4.12000000e+02 3.95000000e+02 4.14000000e+02
#  2.46000000e+02 4.07000000e+02 2.82000000e+02 6.52454969e+08
#  6.60000000e+03 3.62000000e+02 5.21000000e+02 3.24000000e+02
#  4.00000000e+00 3.55000000e+02 1.18000000e+03 3.64000000e+02
#  6.00000000e+00 6.83000000e+02 3.10700000e+03 5.70000000e+03
#  5.37000000e+02 6.60000000e+02 3.85000000e+02 5.29000000e+02
#  6.45000000e+02 4.02000000e+02 5.02000000e+02 3.16000000e+02
#  4.09400000e+03 7.50000000e+03 3.65000000e+02 7.66000000e+02
#  4.60000000e+02 4.01000000e+02 5.76000000e+02 1.35135000e+05
#  4.21000000e+02 7.85000000e+02 1.01800000e+03 5.07000000e+02
#  2.00000000e+00]
# ----------------------------------------
# Valores únicos para la columna garaje:
# [NaN, 'Si']
# Categories (1, object): ['Si']
# ----------------------------------------
# Valores únicos para la columna consumo:
# ['Error al procesar consumo' 'E, D' 'G, F' 'G, E' 'E, E' 'G, G' 'F, E'
#  'F, F' 'D, C' 'C, C' 'D, D' 'A, A' 'E, F' 'B, B' 'C, B' 'B, G' 'B, A'
#  'D, E' 'A, B' 'C, G' 'E, G' 'C, D' 'C, A' 'E, B' 'F, G' 'D, F' 'E, C'
#  'D, A' 'A, E' 'B, C' 'E, A' 'C, E' 'B, E']
# ----------------------------------------
# Valores únicos para la columna puerta_blindada:
# [NaN, 'Si']
# Categories (1, object): ['Si']
# ----------------------------------------
# Valores únicos para la columna adaptado_a_personas_con_movilidad_reducida:
# [NaN, 'Si']
# Categories (1, object): ['Si']
# ----------------------------------------
# Valores únicos para la columna identificador:
# ['40920273409_100500' '15062564089_100500' '658149002_501470' ...
#  '43392414912_109800' '945856909436630_109800' '44201590595_109800']
# ----------------------------------------
# Valores únicos para la columna ascensor:
# ['Si', NaN, 'No']
# Categories (2, object): ['No', 'Si']
# ----------------------------------------
# Valores únicos para la columna superficie_util:
# [6.700e+01 9.000e+01 8.500e+01 6.300e+01 7.300e+01 7.500e+01       nan
#  5.500e+01 1.100e+02 1.150e+02 1.060e+02 9.800e+01 1.000e+02 1.200e+02
#  6.200e+01 3.000e+01 5.100e+01 1.050e+02 1.400e+02 5.900e+01 1.010e+02
#  1.130e+02 7.000e+01 9.500e+01 6.500e+01 6.000e+01 1.250e+02 1.120e+02
#  2.040e+02 9.200e+01 9.400e+01 1.180e+02 1.440e+02 5.000e+01 8.600e+01
#  9.100e+01 1.080e+02 8.000e+01 7.700e+01 8.100e+01 1.300e+02 8.900e+01
#  1.270e+02 6.400e+01 7.900e+01 7.600e+01 1.030e+02 7.800e+01 8.400e+01
#  1.040e+02 1.020e+02 1.170e+02 8.300e+01 3.190e+02 9.900e+01 1.480e+02
#  4.000e+01 4.600e+01 6.800e+01 1.550e+02 1.160e+02 1.350e+02 8.700e+01
#  7.400e+01 2.400e+02 1.070e+02 2.900e+01 1.260e+02 2.700e+01 8.800e+01
#  3.100e+01 1.890e+02 1.190e+02 6.100e+01 5.800e+01 4.500e+01 9.300e+01
#  1.800e+02 1.490e+02 1.580e+02 2.300e+02 3.700e+01 7.200e+01 3.800e+01
#  5.200e+01 4.200e+01 6.900e+01 5.600e+01 8.200e+01 5.700e+01 6.600e+01
#  3.900e+01 4.000e+02 3.200e+01 2.000e+02 9.700e+02 1.500e+02 3.200e+02
#  2.200e+02 9.100e+02 2.100e+02 1.450e+02 2.500e+02 1.900e+02 1.590e+02
#  1.290e+02 2.780e+02 1.200e+03 2.050e+02 5.000e+02 2.450e+02 5.400e+02
#  8.300e+02 1.650e+02 1.220e+02 3.500e+01 9.700e+01 3.400e+01 1.690e+02
#  1.820e+02 1.240e+02 1.330e+02 2.000e+01 7.100e+01 1.600e+02 2.250e+02
#  2.800e+01 5.400e+01 1.380e+02 2.600e+02 9.600e+01 1.370e+02 1.570e+02
#  4.300e+01 1.700e+02 2.500e+01 1.090e+02 1.320e+02 4.800e+01 2.430e+02
#  6.000e+02 9.650e+02 3.000e+02 8.000e+02 8.900e+02 9.400e+02 3.830e+02
#  2.760e+02 2.290e+02 3.500e+02 1.110e+02 1.360e+02 4.100e+01 1.870e+02
#  8.430e+02 1.410e+02 4.800e+02 3.650e+02 1.460e+02 7.000e+02 1.510e+02
#  6.050e+02 2.820e+02 4.650e+02 2.460e+02 8.460e+02 2.400e+03 2.030e+02
#  1.950e+02 2.970e+02 1.850e+02 4.750e+02 2.800e+02 2.900e+02 1.750e+02
#  9.000e+02 3.900e+02 1.540e+02 7.900e+02 5.600e+02 2.240e+02 1.210e+02
#  7.850e+02 1.280e+02 1.000e+03 3.570e+02 3.330e+02 1.760e+02 2.150e+02
#  3.600e+01 1.310e+02 1.140e+02 1.930e+02 1.420e+02 1.040e+03 1.230e+03
#  4.900e+01 1.660e+02 5.300e+01 1.470e+02 3.100e+02 9.600e+02 8.200e+02
#  8.800e+02 7.800e+02 5.880e+02 5.050e+02 7.200e+02 3.300e+01 8.000e+00
#  1.230e+02 4.700e+01 2.410e+02 1.390e+02 3.240e+02 3.382e+03 6.539e+03
#  7.950e+02 2.190e+02 2.070e+02 2.010e+02 1.860e+02 1.720e+02 1.340e+02
#  4.400e+01 1.610e+02 2.650e+02 1.430e+02 1.200e+01 2.470e+02 6.800e+02
#  2.700e+02 2.160e+02 3.700e+02 4.500e+02 1.530e+02 2.960e+02 3.300e+02
#  2.480e+02 3.280e+02 2.750e+02 2.200e+01 1.780e+02 5.030e+02 2.170e+02
#  2.600e+01 5.070e+02 1.920e+02 5.500e+02 1.520e+02 1.880e+02 3.840e+02
#  2.390e+02 6.450e+02 9.800e+02 3.400e+02 8.600e+02 8.400e+02 2.400e+01
#  3.800e+02 1.680e+02 1.100e+01 3.340e+02 2.230e+02 8.250e+02 8.100e+02
#  9.900e+02 7.500e+02 4.200e+02 1.980e+02 7.600e+02 9.450e+02 9.500e+02
#  8.500e+02 1.940e+02 6.700e+02 2.940e+02 3.370e+02 1.710e+02 2.850e+02
#  2.520e+02 2.670e+02 2.130e+02 3.550e+02 3.870e+02 5.250e+02 2.350e+02
#  1.990e+02 2.320e+02 1.600e+01 4.450e+02 1.560e+02 2.840e+02 4.310e+02
#  2.100e+01 2.620e+02 2.300e+01 3.030e+02 4.580e+02 1.790e+02 4.300e+02
#  1.770e+02 3.600e+02 1.670e+02 4.720e+02 1.500e+03 1.250e+03 3.910e+02
#  1.900e+03 1.030e+03 2.120e+02 1.060e+03 2.550e+02 6.500e+02 5.200e+02
#  3.150e+02 6.400e+02 5.150e+02 9.300e+02 4.900e+02 1.970e+02 9.200e+02
#  4.250e+02 4.400e+02 3.480e+02 1.630e+02 8.700e+02 1.100e+03 6.141e+03
#  2.140e+02 4.160e+02 1.640e+02 1.960e+02 3.290e+02 1.740e+02 1.000e+01
#  4.060e+02 2.210e+02 1.000e+00 2.610e+02 1.300e+01 4.700e+02 1.400e+01
#  4.370e+02 1.830e+02 2.380e+02 6.350e+02 2.540e+02 2.560e+02 3.390e+02
#  3.110e+02 2.980e+02 3.250e+02 3.107e+03 2.020e+02 4.950e+02 2.310e+02
#  3.610e+02 2.330e+02 4.010e+02 5.450e+02 2.880e+02 7.250e+02 4.820e+02
#  3.490e+02 1.840e+02 1.800e+01 1.900e+01]
# ----------------------------------------
# Valores únicos para la columna nombre:
# ['Piso en calle Amapola' 'Piso en Avenida de la Estación'
#  'Piso en Avenida del Cabo de Gata' ...
#  'Apartamento en calle Cala Pino Manga, 1'
#  'Apartamento en Avenida de la Gran Vía de la Manga, 6'
#  'Piso en Avenida de la Gran Vía de la Manga, 8']
# ----------------------------------------
# Valores únicos para la columna alcantarillado:
# [NaN, 'Si']
# Categories (1, object): ['Si']
# ----------------------------------------
# Valores únicos para la columna planta:
# <IntegerArray>
# [   3,    4,    6,    1,    0,   21,    2,    5, <NA>,    9,    7,    8,   10,
#    11,   12,   -1,   14,   13,   16,   17,   15,   20,   18,   19]
# Length: 24, dtype: Int64
# ----------------------------------------
# Valores únicos para la columna baños:
# <IntegerArray>
# [1, 2, 3, 4, 6, <NA>, 5, 7, 9, 8, 10, 11]
# Length: 12, dtype: Int64
# ----------------------------------------
# Valores únicos para la columna portero_automatico:
# [NaN, 'Si', 'No']
# Categories (2, object): ['No', 'Si']
# ----------------------------------------
# Valores únicos para la columna exterior:
# [NaN, 'Si']
# Categories (1, object): ['Si']
# ----------------------------------------
# Valores únicos para la columna soleado:
# [NaN, 'Si']
# Categories (1, object): ['Si']
# ----------------------------------------
# Valores únicos para la columna piscina:
# [NaN, 'Si', 'No']
# Categories (2, object): ['No', 'Si']
# ----------------------------------------
# Valores únicos para la columna calle_alumbrada:
# [NaN, 'Si']
# Categories (1, object): ['Si']
# ----------------------------------------
# Valores únicos para la columna precio_m2:
# [9.00e+00 6.00e+00 1.20e+01 8.00e+00 1.00e+01 7.00e+00 5.00e+00 1.60e+01
#  1.10e+01 1.00e+00 1.30e+01 2.00e+00 1.40e+01      nan 1.80e+01 1.70e+01
#  1.50e+01 5.00e+01 3.00e+01 6.00e+01 5.20e+01 2.80e+01 2.00e+01 2.90e+01
#  2.50e+01 4.50e+01 3.20e+01 3.60e+01 2.40e+01 4.70e+01 2.60e+01 5.30e+01
#  4.40e+01 3.10e+01 4.00e+01 3.80e+01 4.00e+00 3.30e+01 6.90e+01 5.60e+01
#  2.10e+01 8.00e+01 4.10e+01 1.90e+01 3.40e+01 2.30e+01 3.50e+01 5.90e+01
#  4.30e+01 3.70e+01 2.20e+01 2.70e+01 5.50e+01 3.00e+00 4.20e+01 1.20e+02
#  8.60e+01 7.80e+01 1.13e+02 9.90e+01 1.02e+02 8.80e+01 6.50e+01 9.50e+01
#  5.70e+01 4.80e+01 7.10e+01 6.20e+01 7.90e+01 3.90e+01 5.10e+01 4.60e+01
#  7.30e+01 6.30e+01 4.90e+01 6.10e+01 5.40e+01 6.70e+01 5.80e+01 7.00e+01
#  9.20e+01 9.60e+01 1.40e+02 7.40e+01 6.80e+01 6.40e+01 7.50e+01 1.05e+02
#  7.60e+01 8.20e+01 7.80e+02 1.20e+03 6.60e+01 9.40e+01 1.87e+02 8.10e+01
#  3.50e+02]
# ----------------------------------------
# Valores únicos para la columna precio:
# [      nan 1.250e+03 7.500e+02 6.500e+02 5.500e+02 2.115e+03 1.380e+02
#  4.300e+01 6.000e+02 1.760e+03 2.250e+03 1.650e+03 1.290e+03 1.470e+03
#  1.500e+03 3.000e+02 2.800e+03 1.000e+03 4.600e+02 5.000e+02 4.500e+02
#  8.500e+02 6.700e+01 1.830e+03 4.100e+03 2.300e+03 3.000e+03 2.150e+03
#  3.700e+03 5.800e+03 1.200e+03 8.000e+02 1.350e+02 7.000e+02 9.000e+02
#  4.900e+02 3.850e+02 9.400e+02 7.700e+02 1.300e+03 1.090e+03 8.900e+02
#  9.800e+02 8.150e+02 7.100e+02 1.400e+03 1.800e+03 1.150e+03 3.850e+03
#  1.170e+03 1.100e+03 1.160e+02 2.220e+03 2.190e+03 1.460e+03 1.000e+02
#  2.650e+03 1.730e+03 1.400e+02 2.170e+03 9.500e+02 1.800e+02 1.260e+03
#  1.500e+02 2.100e+03 4.000e+03 3.800e+02 2.500e+02 1.080e+04 1.800e+04
#  1.100e+04 7.500e+03 1.700e+03 8.000e+04 2.500e+04 1.020e+04 8.820e+03
#  1.600e+04 7.000e+03 1.750e+03 2.000e+03 8.800e+03 1.010e+04 1.050e+04
#  5.500e+03 6.800e+03 9.600e+03 1.000e+04 6.300e+03 3.500e+03 1.160e+04
#  2.500e+03 6.000e+04 8.300e+03 1.700e+04 3.150e+03 3.780e+03 3.720e+03
#  3.445e+03 2.400e+03 3.400e+03 1.920e+03 1.680e+03 1.640e+03 1.915e+03
#  1.455e+03 1.950e+04 1.845e+03 1.790e+03 1.820e+03 2.950e+03 1.270e+03
#  1.530e+03 4.000e+04 2.425e+03 2.800e+04 9.900e+02 1.430e+03 2.300e+02
#  2.020e+02 2.530e+02 1.630e+02 2.250e+02 2.420e+02 1.560e+02 1.150e+02
#  1.670e+02 3.170e+02 1.296e+03 7.900e+02 6.000e+03 1.197e+03 9.995e+03
#  1.860e+03 1.497e+03 1.147e+03 1.051e+03 1.224e+03 1.319e+03 1.903e+03
#  1.174e+03 1.209e+03 2.022e+03 1.262e+03 5.420e+02 1.970e+03 2.405e+03
#  2.020e+03 2.410e+03 1.985e+03 1.590e+03 2.485e+03 1.575e+03 4.400e+03
#  1.200e+04 2.330e+02 2.050e+02 1.050e+03 2.200e+03 8.250e+02 1.900e+03
#  7.800e+02 2.820e+03 3.230e+03 1.955e+03 2.480e+03 1.885e+03 9.250e+02
#  2.005e+03 1.420e+03 1.475e+03 1.725e+03 1.025e+03 2.900e+03 2.090e+03
#  1.930e+03 1.495e+03 1.810e+03 1.525e+03 1.520e+03 2.130e+03 2.010e+03
#  1.450e+03 2.385e+03 1.980e+03 1.960e+03 2.110e+03 2.495e+03 1.850e+03
#  1.655e+03 2.350e+03 1.310e+03 2.035e+03 1.635e+03 1.000e+00 3.450e+03
#  2.600e+03 4.200e+03 3.600e+03 2.390e+03 2.890e+03 3.170e+03 1.670e+03
#  2.285e+03 2.025e+03 2.210e+03 1.415e+03 1.905e+03 2.290e+03 1.805e+03
#  1.380e+03 1.490e+03 2.525e+03 2.630e+03 2.160e+03 3.490e+03 1.305e+03
#  1.435e+03 1.990e+03 1.630e+03 1.330e+03 2.055e+03 1.720e+03 2.470e+03
#  1.880e+03 1.060e+02 1.895e+03 1.040e+02 1.740e+03 1.610e+03 3.100e+03
#  2.240e+03 8.800e+01 1.100e+02 4.300e+02 3.700e+02 4.370e+02 3.470e+02
#  3.810e+02 3.480e+02 3.500e+02 3.400e+02 5.100e+02 2.150e+02 6.800e+02
#  7.850e+02 1.825e+03 1.280e+02 7.600e+01 1.080e+02 1.270e+02 1.200e+02
#  8.300e+01 1.750e+02 5.600e+02 4.200e+02 3.950e+03 6.000e+01 6.650e+02
#  7.000e+01 9.000e+03 2.700e+03 3.300e+03 1.600e+03 4.350e+03 8.000e+01
#  3.200e+02 6.500e+01 1.300e+02 1.680e+02 9.000e+01 5.000e+03]
# ----------------------------------------
# Valores únicos para la columna lavadero:
# [NaN, 'Si', 'No']
# Categories (2, object): ['No', 'Si']
# ----------------------------------------
# Valores únicos para la columna orientacion:
# ['ESTE' 'SIN ESPECIFICAR' 'NORTE' 'SUR' 'OESTE' 'SUROESTE' 'NORESTE'
#  'SURESTE' 'NOROESTE']
# ----------------------------------------
# Valores únicos para la columna amueblado:
# [NaN, 'Si', 'No']
# Categories (2, object): ['No', 'Si']
# ----------------------------------------
# Valores únicos para la columna interior:
# [NaN, 'Si', 'No']
# Categories (2, object): ['No', 'Si']
# ----------------------------------------
# Valores únicos para la columna habitaciones:
# <IntegerArray>
# [3, 2, 1, 4, 5, <NA>, 7, 6, 10, 9, 12, 8, 80, 11, 16, 90, 22, 13]
# Length: 18, dtype: Int64
# ----------------------------------------
# Valores únicos para la columna gas:
# [NaN, 'Si']
# Categories (1, object): ['Si']
# ----------------------------------------
# Valores únicos para la columna tipo_suelo:
# [NaN, 'Si']
# Categories (1, object): ['Si']
# ----------------------------------------
# Valores únicos para la columna carpinteria_exterior:
# [NaN, 'Si']
# Categories (1, object): ['Si']
# ----------------------------------------
# Valores únicos para la columna superficie_solar:
# [        nan 1.00000e+04 1.13000e+03 1.00000e+03 5.00000e+02 8.50000e+02
#  9.00000e+01 8.00000e+02 5.25000e+02 4.00000e+02 1.40000e+03 3.00000e+02
#  1.20000e+03 1.06000e+03 7.00000e+02 1.50000e+02 2.50000e+02 6.00000e+03
#  2.00000e+02 3.00000e+03 6.00000e+02 4.50000e+02 1.30000e+03 1.60000e+03
#  3.50000e+02 9.82000e+02 1.10000e+03 1.02000e+03 1.21000e+02 1.00000e+02
#  7.18000e+02 1.30000e+02 7.50000e+02 1.20000e+02 2.40000e+02 8.00000e+01
#  2.70000e+02 1.70000e+02 1.60000e+02 5.74000e+02 9.80000e+01 6.60000e+02
#  6.00000e+01 2.00000e+03 5.50000e+02 2.55000e+02 1.26400e+03 9.60000e+02
#  7.90000e+02 7.60000e+02 9.00000e+02 5.00000e+01 5.60000e+03 1.00000e+00
#  2.76000e+02 1.25000e+02 2.80000e+02 7.80000e+01 3.15000e+02 1.60200e+03
#  1.11000e+03 1.38000e+03 2.99000e+02 2.61000e+02 1.71000e+03 2.76500e+03
#  1.50000e+03 4.20000e+02 9.28000e+02 5.80000e+02 1.24300e+03 2.05800e+03
#  2.60300e+03 1.00200e+03 1.05300e+03 1.09000e+03 7.11000e+02 2.53000e+03
#  1.09300e+03 1.98000e+02 1.08300e+03 1.56500e+03 2.40000e+03 1.70000e+03
#  1.15000e+03 1.37200e+03 6.37000e+02 1.11500e+03 5.30000e+02 1.16400e+03
#  4.31000e+02 2.50600e+03 1.16100e+03 1.10500e+03 3.22000e+02 4.00000e+03
#  8.20000e+02 1.45000e+03 8.42000e+02 1.07900e+03 1.05000e+03 8.35000e+02
#  1.95000e+03 4.19500e+03 1.99000e+02 5.35000e+02 1.37500e+03 1.90000e+03
#  9.50000e+02 5.10000e+02 3.33000e+02 7.07000e+02 1.02690e+04 4.30000e+02
#  1.02100e+03 1.42000e+03 1.85000e+03 2.03000e+02 2.14000e+02 2.00000e+04
#  1.01100e+03 6.43000e+02 3.70000e+03 1.49500e+03 2.57700e+03 8.60000e+01
#  6.30000e+02 1.80000e+03 3.53000e+02 1.49000e+02 2.20000e+02 3.50000e+03
#  1.50700e+03 1.48000e+05 6.87000e+02 5.77000e+02 1.45000e+02 1.26000e+02
#  1.10000e+05 5.02000e+02 6.13000e+02 1.37000e+02 2.70000e+03 5.33000e+02
#  3.85000e+02 1.03300e+03 9.85000e+02 5.54000e+02 9.12000e+02 1.32300e+03
#  5.38000e+02 6.04000e+02 6.09000e+02 3.10000e+02 9.70000e+02 6.65000e+02
#  4.06700e+03 3.24800e+03 7.00000e+01 4.05000e+02 8.37000e+02 4.74000e+02
#  3.79000e+02 9.75000e+02 1.01000e+03 8.80000e+02 1.02000e+02 9.65000e+02
#  3.84000e+02 4.39000e+02 4.30000e+01 1.46700e+03 1.24900e+04 1.93000e+02
#  4.35000e+02 6.80000e+02 2.09000e+02 1.37300e+03 2.33000e+02 2.78000e+02
#  3.44000e+02 2.35000e+02 1.50200e+03 1.03000e+03 1.04000e+03 9.40000e+02
#  8.40000e+02 9.80000e+02 7.39000e+02 8.90000e+02 1.12000e+03 2.34000e+02
#  1.08000e+03 1.43000e+02 9.30000e+02 3.00000e+01 1.18000e+03 4.00000e+01
#  4.59000e+02 9.35000e+02 2.90000e+03 4.06000e+02 1.39000e+03 3.48000e+02
#  2.98700e+03 3.55000e+02 3.40000e+02 3.57000e+02 4.20000e+03 1.00000e+01
#  2.50000e+03 2.55500e+03 9.99000e+02 5.96000e+02 2.65000e+02 5.70000e+02
#  3.19000e+03 1.61000e+03 2.50700e+03 4.66500e+03 7.52000e+02 5.88000e+02
#  3.52000e+02 6.49400e+03 8.30000e+02 2.50000e+01 1.57600e+03 6.76000e+02
#  2.17000e+02 2.80000e+01 5.33200e+03 3.20000e+02 3.18000e+03 2.53000e+02
#  9.90000e+02 2.80000e+03 6.67680e+04 5.10000e+01 1.62500e+03 9.05000e+02
#  1.08400e+03 2.00000e+01 9.10000e+02 3.02900e+03 2.88000e+03 6.00000e+04
#  1.55000e+03 1.18200e+03 7.59000e+02 9.18500e+03 9.20000e+02 6.59000e+02
#  1.23000e+03 8.00000e+03 6.50000e+02 5.32000e+03 5.45800e+03 1.68000e+03
#  2.21800e+03 6.31500e+03 9.99999e+05 5.90000e+03 1.33000e+02 4.40000e+03
#  4.16000e+02 1.05500e+03 4.50000e+01 1.20000e+04 8.30000e+01 4.75000e+03
#  2.69000e+02 3.25000e+02 1.29000e+02 7.60000e+01 8.16000e+02 1.31000e+03
#  6.44000e+02 1.67000e+02 6.20000e+02 7.26000e+02 1.65000e+03 7.40000e+02
#  1.01700e+03 2.53300e+03 1.01000e+02 1.27800e+03 1.04400e+03 5.89000e+02
#  8.36000e+02 1.85000e+02 3.49000e+02 1.17900e+03 9.30000e+01 7.20000e+01
#  8.38000e+02 8.28000e+02 1.15800e+03 5.09000e+02 2.67000e+02 1.90000e+02
#  1.43800e+03 8.63000e+02 1.19900e+03 6.72000e+02 3.90000e+01 1.36200e+03
#  3.01000e+02 4.17000e+02 8.92000e+02 3.06000e+02 1.28000e+03 1.23000e+02
#  2.10000e+02 1.27000e+02 4.50000e+03 5.22000e+02 6.60000e+03 1.43900e+03
#  5.00000e+03 4.32000e+02 1.71000e+02 1.28200e+03 2.15000e+03 1.04000e+02
#  6.10000e+02 1.05700e+03 1.00600e+03 1.15500e+03 1.93600e+03 1.26000e+03
#  4.62000e+02 1.40000e+01 1.19200e+03 3.60000e+04 7.40000e+03 5.70000e+03
#  1.69800e+03 1.10000e+02 1.10000e+04 8.04000e+02 8.51000e+02 3.83600e+03
#  8.00000e+00 1.85000e+04 2.71000e+02 1.50000e+04 1.60000e+01 2.50000e+04
#  4.40000e+02 3.26630e+04 3.16000e+02 1.14400e+03 4.09400e+03 2.93000e+02
#  8.00000e+04 2.30000e+04 1.48660e+04 2.15000e+04 7.00000e+03 9.50000e+01
#  1.63000e+02 1.66000e+02 2.75000e+02 1.80000e+02 5.66000e+02 5.00000e+00
#  1.31000e+02 1.20900e+03 1.35000e+03 7.76000e+02]
# ----------------------------------------
# Valores únicos para la columna comedor:
# [NaN, 'Si', 'No']
# Categories (2, object): ['No', 'Si']
# ----------------------------------------
# Valores únicos para la columna antiguedad:
# ['Más de 50 años' 'Entre 30 y 50 años' nan 'Entre 20 y 30 años'
#  'Entre 5 y 10 años' 'Entre 10 y 20 años' 'Menos de 5 años']
# ----------------------------------------
# Valores únicos para la columna codigo_postal:
# [ 40040.  40050.     nan  40010.  40090.  40070.  40060.  40030.  40080.
#   41310.  40020.  41200.  41500.  47400.  46210.  46200. 111390. 111380.
#  111300. 111000. 115400. 114000. 115200. 110110. 110080. 110070. 110030.
#  110100. 110020. 110010. 110090. 110050. 110060. 110040. 140020. 140010.
#  140140. 140040. 140120. 140030. 140050. 140060. 140090. 140100. 140110.
#  140130. 140070. 140080. 147110. 180130. 180140. 180020. 180070. 180040.
#  180030. 180120. 180090. 180050. 180080. 180010. 180060. 180100. 180150.
#  180110. 180160. 181000. 186900. 186970. 210020. 230010. 230060. 230040.
#  237000. 230070. 237130. 230050. 230030. 296030. 296020. 296010. 296600.
#  296040. 296700. 290090. 290040. 290170. 290060. 290180. 290120. 290160.
#  290020. 290070. 290100. 290030. 291900. 290150. 290110. 290080. 290010.
#  290140. 295910. 290130. 295900. 291400. 290050. 297200. 296930. 296800.
#  296880. 296890. 296900. 410100. 410150. 410020. 410040. 410130. 410200.
#  410050. 410110. 410120. 410180. 410060. 410010. 410070. 410090. 410140.
#  410080. 410030. 410190. 410890. 440020. 500060. 500120. 500010. 500040.
#  501960. 500130. 500030. 500090. 500080. 500220. 500050. 500100. 500140.
#  500020. 500150. 500110. 500200. 500170. 500070. 500180. 508200. 390050.
#  390090. 390080. 390070. 390120. 390040. 390060. 390030. 390100. 390110.
#  390020. 390010. 396000. 397700. 397770.  50010.  50050.  50020.  50030.
#   51960.  92000.  90070.  90030.  90050.  90020.  90060.  90010.  90040.
#  240030. 240040. 240010. 240020. 240070. 240080. 240060. 240090. 240050.
#  244030. 244020. 240100. 244010. 340010. 340020. 340050. 340040. 370040.
#  370070. 370060. 370050. 370020. 370010. 370030. 370080. 420020. 420040.
#  420050. 470070. 470010. 470060. 470150. 470120. 470110. 470080. 470030.
#  470140. 470040. 470160. 470020. 470130. 470090. 470050. 470100. 490140.
#  490110.  20050.  20020.  20040.  20010.  20060.  20030.  20490.  22200.
#   20080. 130050. 130040. 130010. 160010. 160040. 160020. 160030. 190050.
#  191800. 190020. 190010. 190030. 450010. 450050. 450030. 450020. 450040.
#  456000. 450070.  80060.  80020.  80240.  80380.  80050.  80030.  80150.
#   80210.  80130.  80170.  80010.  80080.  80290.  80340.  80200.  80360.
#   80250.  80070.  80120.  80370.  80090.  80110.  80220.  80230.  80100.
#   80190.  80180.  80040.  80140.  80330.  80270.  80260.  80280.  80350.
#   80410.  80390.  80320.  80420.  89030.  89040.  89500.  89050.  88700.
#   88720. 170040. 172500. 170070. 172490. 170010. 170050. 170030. 172580.
#  172200. 172100. 172480. 250020. 250010. 250070. 250030. 250040. 250050.
#  432030. 430030. 438200. 435000. 430010. 438820. 432060. 438300. 430040.
#  431000. 432050. 430080. 280020. 280100. 280130. 280040. 280150. 280030.
#  280050. 280200. 280380. 280350. 280390. 280120. 280360. 280140. 280060.
#  280080. 280280. 280400. 280010. 280230. 280160. 280450. 280490. 280090.
#  280410. 280320. 280190. 280290. 280460. 280430. 280210. 280470. 280500.
#  280170. 280510. 280260. 280250. 280340. 280310. 280070. 280370. 280220.
#  280550. 280110. 280420. 280330. 280530. 280300. 280180. 280440. 280540.
#  280240. 280270. 281090. 282230. 282240. 282220. 282200. 286600. 281080.
#  287030. 287010.  37490.  35010.  31880.  35400.  32020.  32060.  30120.
#   30060.  35020.  30050.  37000.  35030.  30130.  31820.  31810.  31890.
#   37380.  31940.  30040.  30010.  30070.  32940.  37790.  30090.  30160.
#   31400.  35900.  30030.  30020.  37300.  32010.  31830.  30080.  32040.
#   31910.  37390.  30150.  37370.  35990.  30100.  37240.  35800.  32070.
#   32030.  31900.  36990.  31840.  37090.  32920.  32050.  38010.  38030.
#   32080.  33000.  33200.  30140.  38040.  35590.  33130.  31850.  32960.
#   33170.  32930.  31120.  31860.  33120.  31950.  31490.  32910. 120020.
#  120010. 120040. 120060. 120030. 120050. 121000. 460110. 460150. 464080.
#  460020. 460220. 461170. 460080. 460180. 460030. 460050. 460040. 460210.
#  460130. 460060. 460100. 469500. 469800. 460090. 460010. 460240. 460070.
#  460230. 460190. 460200. 461820. 461110. 465200. 464200. 469200. 469010.
#  464000. 469890. 460140. 460250. 465000. 467020. 469000. 460260. 467010.
#  460170. 464090. 460350. 467300. 465300. 466000.  60030.  60090.  60040.
#   60110.  60070.  60020.  60080.  68000.  60060.  60010.  60050.  60100.
#   61800.  63100. 100050. 100010. 100030. 100040. 100020. 150010. 150050.
#  150040. 157040. 150090. 157020. 157010. 151720. 157030. 150060. 150020.
#  150100. 150030. 150070. 157070. 150110. 154010. 151790. 154020. 157050.
#  154030. 154040. 154050. 155940. 151730. 157060. 155700. 158960. 270020.
#  270040. 270030. 270010. 271460. 320050. 320030. 320040. 320020. 320010.
#  329700. 362010. 362030. 360010. 362040. 362050. 362020. 362120. 360040.
#  362110. 361620. 362080. 361570. 362060. 360020. 362130. 360030. 363900.
#  360050. 361540. 361580. 363310. 363120. 362100.  70010.  70110.  70050.
#   71800.  76100.  70140.  70130.  70120.  70150.  70070.  70040.  71990.
#   71830.  70100.  70060.  76090.  71600.  76000.  70030.  76200.  70020.
#   76390.  70080. 350180. 350080. 350100. 350030. 350090. 352290. 350190.
#  351000. 350070. 354000. 350110. 350130. 350160. 351060. 350060. 351300.
#  351380. 350040. 350010. 351290. 352120. 351090. 350020. 354140. 350170.
#  356000. 351100. 352150. 351490. 351280. 352110. 351190. 351200. 352140.
#  386700. 386300. 386500. 382040. 382020. 386320. 383200. 386600. 384000.
#  380030. 380010. 386120. 386110. 386790. 386770. 380080. 381070. 385090.
#  386780. 381200. 382060. 380050. 380090. 380070. 386160. 385400. 385950.
#  385300. 382050. 380020. 380040. 260020. 260030. 260070. 260010. 260050.
#  260060. 260040. 310030. 310020. 310140. 310080. 310120. 310070. 310100.
#  310060. 317400. 310040. 310010. 310050. 316000. 310110.  10070.  10100.
#   10040. 200060. 200100. 200090. 200030. 200050. 200140. 200110. 200020.
#  200070. 200040. 200150. 200080. 203020. 203050. 200130. 489910. 480030.
#  480110. 480040. 480080. 480050. 480100. 489930. 480090. 480070. 480120.
#  489300. 480130. 480140. 489920. 482800. 480060. 480150. 480020. 480010.
#  482600. 489020. 489030. 330110. 330130. 330010. 330070. 330090. 330050.
#  330120. 330030. 330080. 330100. 331000. 330060. 330020. 332130. 332070.
#  333910. 332100. 332050. 332080. 332010. 332120. 332030. 332020. 332060.
#  332090. 332040. 335190. 308300. 300010. 305900. 301200. 300070. 300090.
#  301510. 300050. 300080. 301550. 308330. 300040. 301580. 301000. 300060.
#  301630. 300110. 300100. 301100. 301070. 300020. 301500. 300030. 301610.
#  301570. 305790. 300120. 305700. 308360. 307090. 302020. 302010. 302040.
#  303840. 302030. 302050. 303700. 303100. 303960. 303850. 303800. 303000.
#  305940. 308680. 303190. 303830. 303940. 303680. 307000.]
# ----------------------------------------
# Valores únicos para la columna ubicacion:
# ['almeria_capital' 'roquetas_de_mar' 'vera' 'chiclana_de_la_frontera'
#  'sanlucar_de_barrameda' 'cadiz_capital' 'cordoba_capital_zona_urbana'
#  'area_de_granada_granada_capital' 'almunecar' 'isla_cristina'
#  'punta_umbria' 'jaen' 'marbella' 'malaga_capital_zona_urbana' 'estepona'
#  'sevilla_capital' 'huesca' 'teruel' 'zaragoza' 'santander' 'laredo'
#  'avila' 'burgos' 'leon' 'palencia' 'salamanca' 'soria' 'valladolid'
#  'zamora' 'albacete' 'ciudad_real' 'cuenca' 'guadalajara' 'toledo'
#  'barcelona_capital' 'sitges' 'girona' 'lleida' 'tarragona'
#  'madrid_capital_zona_urbana' 'pozuelo_de_alarcon'
#  'madrid_norte_la_moraleja' 'alicante' 'castellon_castello' 'valencia'
#  'badajoz' 'caceres' 'a_coruna' 'lugo' 'ourense' 'pontevedra'
#  'islas_baleares_illes_balears' 'las_palmas' 'santa_cruz_de_tenerife'
#  'la_rioja' 'navarra_nafarroa' 'alava_araba' 'guipuzcoa_gipuzkoa'
#  'vizcaya_bizkaia' 'oviedo' 'gijon_concejo_xixon_conceyu_gijon'
#  'murcia_capital' 'cartagena' 'la_manga_del_mar_menor']
# ----------------------------------------
# Valores únicos para la columna agencia:
# ['SALVADOR VIVIENDAS & LOCALES' 'AGENCIA INMOBILIARIA PDM'
#  'ALCASA SERVICIOS INMOBILIARIOS' ... 'INMOBILIARIA 2 MARES'
#  'LA MANGA SELECTOR' 'INTERPLAYA']
# ----------------------------------------
# Valores únicos para la columna chimenea:
# [NaN, 'Si', 'No']
# Categories (2, object): ['No', 'Si']
# ----------------------------------------
# Valores únicos para la columna telefono:
# [NaN, 'Si']
# Categories (1, object): ['Si']
# ----------------------------------------

# %%
dfalquileres.dtypes
# Out:
# luz                                                 category
# jardin                                              category
# sistema_de_seguridad                                category
# conservacion                                          object
# vidrios_dobles                                      category
# se_aceptan_mascotas                                 category
# timestamp                                             object
# carpinteria_interior                                category
# calefaccion                                         category
# trastero                                            category
# href                                                  object
# calle_asfaltada                                     category
# tipo_de_casa                                          object
# cocina_equipada                                     category
# agua                                                category
# emisiones                                             object
# aire_acondicionado                                  category
# terraza                                             category
# armarios_empotrados                                 category
# actualizacion                                 datetime64[ns]
# superficie                                           float64
# balcon                                              category
# gastos_de_comunidad                                 category
# urbanizado                                          category
# superficie_construida                                float64
# garaje                                              category
# consumo                                               object
# puerta_blindada                                     category
# adaptado_a_personas_con_movilidad_reducida          category
# identificador                                         object
# ascensor                                            category
# superficie_util                                      float64
# nombre                                                object
# alcantarillado                                      category
# planta                                                 Int64
# baños                                                  Int64
# portero_automatico                                  category
# exterior                                            category
# soleado                                             category
# piscina                                             category
# calle_alumbrada                                     category
# precio_m2                                            float64
# precio                                               float64
# lavadero                                            category
# orientacion                                           object
# amueblado                                           category
# interior                                            category
# habitaciones                                           Int64
# gas                                                 category
# tipo_suelo                                          category
# carpinteria_exterior                                category
# superficie_solar                                     float64
# comedor                                             category
# antiguedad                                            object
# codigo_postal                                        float64
# ubicacion                                             object
# agencia                                               object
# chimenea                                            category
# telefono                                            category
# dtype: object
