# %%
import pandas as pd

# %%
df = pd.read_csv("csv_completos_bruto/compras_completo.csv", low_memory=False)

# %%
df["ubicacion"].unique()
# Out:
# array(['corredor_del_henares', 'madrid_noroeste', 'madrid_norte',
#        'madrid_sur', 'madrid_sureste', 'madrid_suroeste', 'arganzuela',
#        'madrid_capital_barajas', 'barrio_de_salamanca',
#        'madrid_capital_carabanchel', 'madrid_capital_centro',
#        'madrid_capital_chamartin', 'chamberi_distrito', 'ciudad_lineal',
#        'fuencarral_el_pardo', 'hortaleza', 'latina', 'moncloa_aravaca',
#        'moratalaz', 'puente_de_vallecas', 'madrid_capital_retiro',
#        'madrid_capital_san_blas', 'tetuan', 'madrid_capital_usera',
#        'madrid_capital_vicalvaro', 'villa_de_vallecas',
#        'villaverde_distrito', 'rioja_alta', 'rioja_baja', 'rioja_media',
#        'sierra_rioja_alta', 'sierra_rioja_baja',
#        'sierra_rioja_media_cameros', 'area_de_pamplona',
#        'navarra_media_oriental', 'navarra_nafarroa_noroeste', 'pirineos',
#        'navarra_nafarroa_ribera_alta', 'tierra_estella',
#        'navarra_nafarroa_tudela', 'area_de_aviles', 'area_del_nora',
#        'bajo_nalon_area_de_vaqueira', 'asturias_cabo_penas',
#        'camin_real_de_la_mesa_fuentes_del_narcea', 'comarca_de_la_sidra',
#        'gijon_concejo_xixon_conceyu', 'montana_central',
#        'oriente_de_asturias', 'oscos_eo_parque_historico_del_navia',
#        'oviedo_capital', 'valle_del_nalon', 'area_de_santander',
#        'ason_aguera', 'besaya', 'campoo_los_valles',
#        'cantabria_costa_occidental', 'costa_oriental', 'liebana',
#        'saja_nansa', 'trasmiera', 'valles_pasiegos',
#        'altiplano_y_oriental', 'alto_guadalentin', 'area_del_mar_menor',
#        'bajo_guadalentin', 'campo_de_cartagena', 'huerta_de_murcia',
#        'rio_mula_valle_ricote_vega_alta', 'fuerteventura', 'gran_canaria',
#        'lanzarote', 'el_hierro', 'la_gomera', 'la_palma', 'adeje',
#        'arafo', 'arico', 'arona', 'buenavista_del_norte', 'candelaria',
#        'el_rosario', 'el_sauzal', 'el_tanque', 'fasnia', 'garachico',
#        'granadilla_de_abona', 'guia_de_isora', 'guimar',
#        'icod_de_los_vinos', 'la_guancha', 'la_matanza_de_acentejo',
#        'la_orotava', 'la_victoria_de_acentejo', 'los_realejos',
#        'los_silos', 'puerto_de_la_cruz', 'san_cristobal_de_la_laguna',
#        'san_juan_de_la_rambla', 'san_miguel_de_abona',
#        'santa_cruz_de_tenerife_capital', 'santa_ursula',
#        'santiago_del_teide', 'tacoronte', 'tegueste',
#        'vilaflor_de_chasna', 'campina_sur', '_la_serena', 'la_siberia',
#        'llanos_de_olivenza', 'sierra_suroeste', 'tentudia',
#        'tierra_de_badajoz', 'tierra_de_barros',
#        'tierra_de_merida_vegas_bajas', '_vegas_altas', 'zafra_rio_bodion',
#        'alcantara_tajo_salor', 'area_de_caceres', 'campo_aranuelo',
#        'granadilla_las_hurdes', 'la_vera', 'las_villuercas_los_ibores',
#        'plasencia_monfrague', 'sierra_de_gata', 'tierra_de_montanchez',
#        'tierra_de_trujillo', 'valles_de_jerte_y_del_ambroz',
#        'vegas_de_alagon', 'bidasoa', 'debabarrena', 'debagoiena',
#        'donostialdea', 'goierri', 'tolosaldea', 'urola_kosta',
#        'arratia_nerbioi', 'bilbo_handia', 'el_rincon_de_ademuz',
#        'la_hoya_de_bunol', 'la_plana_de_utiel_requena', 'la_ribera_alta',
#        'la_ribera_baixa', 'la_safor', 'la_vall_albaida', 'los_serranos',
#        'valencia_capital', 'alt_vinalopo', 'baix_vinalopo', 'el_comtat',
#        'alacanti', 'alcoia', 'vinalopo_mitja', 'altea', 'benidorm',
#        'benimantell', 'bolulla', 'callosa_en_sarria', 'confrides',
#        'el_castell_de_guadalest', 'finestrat', 'alfas_del_pi', 'la_nucia',
#        'la_vila_joiosa_villajoyosa', 'orxeta', 'polop', 'relleu', 'sella',
#        'tarbena', 'area_de_calpe_javea', 'area_de_denia',
#        'area_de_pego_orba', 'albatera', 'benferri', 'orihuela',
#        'pilar_de_la_horadada', 'san_miguel_de_salinas',
#        'acequion_los_naufragos', 'aguas_nuevas_torreblanca_sector_25',
#        'torrevieja_centro', 'la_mata_distrito',
#        'la_siesta_el_salado_torreta_el_chaparral',
#        'los_balcones_los_altos_punta_prima',
#        'torrevieja_nueva_torrevieja',
#        'playa_de_los_locos_los_frutales_cabo_cervera', 'playa_del_cura',
#        'algorfa', 'almoradi', 'benejuzar', 'benijofar', 'bigastro',
#        'callosa_de_segura', 'catral', 'cox', 'daya_nueva', 'daya_vieja',
#        'dolores', 'formentera_del_segura', 'granja_de_rocamora',
#        'guardamar_del_segura', 'jacarilla', 'los_montesinos', 'rafal',
#        'redovan', 'rojales', 'san_fulgencio', 'san_isidro',
#        'andorra_sierra_de_arcos_bajo_martin', 'area_de_teruel',
#        'bajo_aragon_alcaniz', 'cuencas_mineras', 'gudar_javalambre',
#        'jiloca', 'maestrazgo', 'matarrana', 'sierra_de_albarracin',
#        'alto_gallego', 'cinca_la_litera', 'hoya_de_huesca',
#        'la_jacetania', 'la_ribagorza', 'los_monegros', 'sobrarbe',
#        'somontano_de_barbastro', 'aranda_campo_de_borja',
#        'area_de_calatayud', 'area_de_zaragoza',
#        'bajo_aragon_caspe_bajo_cinca',
#        'campo_de_carinena_campo_de_belchite', 'campo_de_daroca',
#        'cinco_villas_la_jacetania_de_zaragoza',
#        'hoya_de_huesca_de_zaragoza', 'ribera_alta_del_ebro',
#        'ribera_baja_del_ebro_los_monegros_de_zaragoza',
#        'tarazona_y_el_moncayo', 'valdejalon', 'alt_emporda',
#        'baix_emporda', 'cerdanya_de_girona', 'garrotxa', 'girones',
#        'osona_de_girona', 'pla_de_estany', 'ripolles', 'selva',
#        'alt_urgell', 'alta_ribagorca', 'cerdanya_de_lleida', 'garrigues',
#        'noguera', 'pallars_jussa', 'pallars_sobira', 'pla_urgell',
#        'segarra', 'segria', 'solsones', 'urgell', 'val_aran',
#        'alt_penedes', 'anoia', 'bages', 'baix_llobregat', 'bergueda',
#        'garraf', 'llucanes', 'maresme', 'moianes', 'osona',
#        'valles_oriental', 'valles_occidental_nord',
#        'valles_occidental_sud', 'badalona', 'hospitalet_de_llobregat',
#        'sant_adria_de_besos', 'santa_coloma_de_gramenet', 'ciutat_vella',
#        'barcelona_capital_eixample', 'gracia_distrito', 'horta_guinardo',
#        'barcelona_capital_les_corts', 'nou_barris', 'sant_andreu',
#        'sant_marti', 'sants_montjuic', 'sarria_sant_gervasi', 'a_marina',
#        'a_ulloa_chantada_terra_de_lemos', 'area_de_lugo',
#        'os_ancares_sarria_quiroga', 'terra_cha_meira_a_fonsagrada',
#        'area_de_pontevedra', 'area_de_vigo', 'caldas_tabeiros_deza',
#        'condado_paradanta', 'mino_baixo', 'o_morrazo', 'o_salnes',
#        'allariz_maceda_terra_de_caldelas', 'area_de_ourense',
#        'baixa_limia_a_limia', 'o_carballino_o_ribeiro',
#        'terra_de_celanova', 'terra_de_trives_valdeorras', 'verin_viana',
#        'area_de_a_coruna', 'area_de_betanzos', 'area_de_ferrol',
#        'arzua_ordes_terra_de_melide', 'a_coruna_bergantinos',
#        'fisterra_terra_de_soneira', 'muros_xallas', 'noia_a_barcala',
#        'o_barbanza_o_sar', 'o_eume_ortegal', 'a_coruna_santiago',
#        'guadalajara_alcarria', 'campina', 'senorio_de_molina_alto_tajo',
#        'guadalajara_sierra_norte', 'la_campana_de_oropesa', 'la_jara',
#        'la_mancha_de_toledo', 'la_mesa_de_ocana', 'la_sagra',
#        'los_montes_de_toledo', 'sierra_de_san_vicente', 'toledo_talavera',
#        'toledo_capital', 'toledo_torrijos', 'alcarria', 'mancha_alta',
#        'mancha_baja', 'manchuela', 'serrania_alta', 'serrania_baja',
#        'serrania_media', 'albacete_capital', 'campos_de_hellin',
#        'la_mancha_del_jucar_centro', 'la_manchuela',
#        'monte_iberico_corredor_de_almansa',
#        'sierra_de_alcaraz_y_campo_de_montiel', 'sierra_segura',
#        'alcudia_montes', 'campo_de_calatrava', 'ciudad_real_la_mancha',
#        'ciudad_real_montiel', 'area_de_bejar', 'area_de_ciudad_rodrigo',
#        'area_de_penaranda_de_bracamonte', 'area_de_salamanca',
#        'area_de_vitigudino', 'area_de_arenas_de_san_pedro',
#        'area_de_avila', 'burgohondo_el_tiemblo_cebreros',
#        'el_barco_de_avila_piedrahita', 'la_morana_arevalo',
#        'area_de_cantalejo_riaza', 'area_de_cuellar', 'area_de_segovia',
#        'area_de_almazan', 'area_de_medinaceli', 'area_de_pinares',
#        'area_de_soria', 'campo_de_gomara', 'tierras_altas',
#        'tierras_del_burgo', 'alfoz_de_burgos', 'arlanza', 'ebro',
#        'la_bureba', 'las_merindades', 'montes_de_oca', 'odra_pisuerga',
#        'paramos', 'ribera_del_duero', 'sierra_de_la_demanda',
#        'montana_de_palencia', 'paramos_valles',
#        'tierra_de_campos_cerrato', 'area_de_valladolid',
#        'este_area_de_penafiel', 'norte_area_del_pisuerga_y_esgueva',
#        'oeste_area_de_tordesillas', 'sureste_area_de_iscar_y_olmedo',
#        'suroeste_area_de_medina_del_campo',
#        'tierra_de_campos_de_valladolid', 'area_de_astorga',
#        'area_de_sahagun', 'bierzo', 'el_paramo', 'esla_campos',
#        'la_baneza', 'la_cabrera', 'la_montana_de_luna',
#        'la_montana_de_riano', 'tierras_de_leon', 'alba_tabara',
#        'alfoz_de_toro', 'benavente_los_valles',
#        'la_guarena_tierra_del_vino', 'sanabria_la_carballeda', 'sayago',
#        'tierra_de_campos_de_zamora', 'zamora_tierra_del_pan'],
#       dtype=object)

# %%
df.shape
# Out:
# (261934, 62)

# %%
df.columns
# Out:
# Index(['Antigüedad', 'identificador', 'Teléfono', 'Carpintería interior',
#        'Ascensor', 'Portero automático', 'Armarios empotrados', 'Conservación',
#        'Superficie construida', 'Lavadero', 'Calle alumbrada', 'Calefacción',
#        'Calle asfaltada', 'codigo_postal', 'Referencia',
#        'Sistema de seguridad', 'Aire acondicionado', 'Garaje',
#        'Cocina equipada', 'agencia', 'Terraza', 'Puerta blindada',
#        'Tipo de casa', 'Gas', 'href', 'Gastos de comunidad',
#        'Se aceptan mascotas', 'Adaptado a personas con movilidad reducida',
#        'Urbanizado', 'Comedor', 'Soleado', 'Habitaciones', 'nombre',
#        'ubicacion', 'Exterior', 'Jardín', 'Superficie solar', 'Planta',
#        'Balcón', 'superficie', 'actualizacion', 'emisiones', 'Vidrios dobles',
#        'Orientación', 'precio', 'Luz', 'consumo', 'Trastero', 'coordenadas',
#        'Superficie útil', 'Agua', 'Baños', 'Tipo suelo', 'Chimenea',
#        'Alcantarillado', 'precio_m2', 'timestamp', 'Carpintería exterior',
#        'Piscina', 'Interior', 'No se aceptan mascotas', 'Amueblado'],
#       dtype='object')

# %%
#Normalizamos los nombres de las columnas
def normalizar_nombres(nombres):
    nombres = nombres.lower().replace(" ", "_") 
    nombres = nombres.replace('á', 'a').replace('é', 'e').replace('í', 'i').replace('ó', 'o').replace('ü', 'u').replace('ú', 'u')
    nombres = nombres.replace('Á', 'a').replace('É', 'e').replace('Í', 'i').replace('Ó', 'o').replace('Ú', 'u')
    return nombres
df.columns = [normalizar_nombres(col) for col in df.columns]

# %%
df.columns
# Out:
# Index(['antiguedad', 'identificador', 'telefono', 'carpinteria_interior',
#        'ascensor', 'portero_automatico', 'armarios_empotrados', 'conservacion',
#        'superficie_construida', 'lavadero', 'calle_alumbrada', 'calefaccion',
#        'calle_asfaltada', 'codigo_postal', 'referencia',
#        'sistema_de_seguridad', 'aire_acondicionado', 'garaje',
#        'cocina_equipada', 'agencia', 'terraza', 'puerta_blindada',
#        'tipo_de_casa', 'gas', 'href', 'gastos_de_comunidad',
#        'se_aceptan_mascotas', 'adaptado_a_personas_con_movilidad_reducida',
#        'urbanizado', 'comedor', 'soleado', 'habitaciones', 'nombre',
#        'ubicacion', 'exterior', 'jardin', 'superficie_solar', 'planta',
#        'balcon', 'superficie', 'actualizacion', 'emisiones', 'vidrios_dobles',
#        'orientacion', 'precio', 'luz', 'consumo', 'trastero', 'coordenadas',
#        'superficie_util', 'agua', 'baños', 'tipo_suelo', 'chimenea',
#        'alcantarillado', 'precio_m2', 'timestamp', 'carpinteria_exterior',
#        'piscina', 'interior', 'no_se_aceptan_mascotas', 'amueblado'],
#       dtype='object')

# %%
df["identificador"].value_counts()
# Out:
# identificador
# 4950463419_109700         118
# 5080341116_109700         101
# 3889203840_109700         101
# 51683853682_995900        100
# 51698492343_108500        100
#                          ...
# 50917251328_101800          1
# 33340006923_101800          1
# 49237393323_101800          1
# 48398240261_100200          1
# 945856909774219_109800      1
# Name: count, Length: 123368, dtype: int64

# %%
# Eliminar identificadores únicos duplicados
df = df.drop_duplicates(subset='identificador', keep='first')

# %%
df["identificador"].value_counts()
# Out:
# identificador
# 51748300470_101800        1
# 45050223177_101800        1
# 44202884354_109300        1
# 31733421655_109300        1
# 42565896380_109300        1
#                          ..
# 51763338272_109300        1
# 47528948901_100500        1
# 36751850415_108900        1
# 51713137420_109300        1
# 945856909774219_109800    1
# Name: count, Length: 123368, dtype: int64

# %%
# Eliminamos la columna referencia porque nuestro valor único de inmueble será "identificador"
df = df.drop(columns=['referencia'])

# %%
df.columns
# Out:
# Index(['antiguedad', 'identificador', 'telefono', 'carpinteria_interior',
#        'ascensor', 'portero_automatico', 'armarios_empotrados', 'conservacion',
#        'superficie_construida', 'lavadero', 'calle_alumbrada', 'calefaccion',
#        'calle_asfaltada', 'codigo_postal', 'sistema_de_seguridad',
#        'aire_acondicionado', 'garaje', 'cocina_equipada', 'agencia', 'terraza',
#        'puerta_blindada', 'tipo_de_casa', 'gas', 'href', 'gastos_de_comunidad',
#        'se_aceptan_mascotas', 'adaptado_a_personas_con_movilidad_reducida',
#        'urbanizado', 'comedor', 'soleado', 'habitaciones', 'nombre',
#        'ubicacion', 'exterior', 'jardin', 'superficie_solar', 'planta',
#        'balcon', 'superficie', 'actualizacion', 'emisiones', 'vidrios_dobles',
#        'orientacion', 'precio', 'luz', 'consumo', 'trastero', 'coordenadas',
#        'superficie_util', 'agua', 'baños', 'tipo_suelo', 'chimenea',
#        'alcantarillado', 'precio_m2', 'timestamp', 'carpinteria_exterior',
#        'piscina', 'interior', 'no_se_aceptan_mascotas', 'amueblado'],
#       dtype='object')

# %%
df["precio"].value_counts()
# Out:
# precio
# A consultar    1348
# 150.000 €      1094
# 120.000 €      1093
# 250.000 €      1081
# 350.000 €       983
#                ...
# 4.000 €           1
# 216.700 €         1
# 136.240 €         1
# 269.995 €         1
# 88.600 €          1
# Name: count, Length: 6778, dtype: int64

# %%
# Limpieza de la columna precio
def limpiar_precio(x):
    try:
        if 'A consultar' in x or 'Error al procesar el precio' in x:
            return None
        return float(x.replace(' €/mes', '').replace('€', '').replace(' ', '').replace('.', '').replace(',', '.'))
    except ValueError:
        return None
df['precio'] = df['precio'].apply(limpiar_precio)
df['precio'] = df['precio'].astype(float)

# %%
df["precio"].value_counts()
# Out:
# precio
# 150000.0    1094
# 120000.0    1093
# 250000.0    1081
# 350000.0     983
# 180000.0     938
#             ...
# 653000.0       1
# 4000.0         1
# 216700.0       1
# 136240.0       1
# 88600.0        1
# Name: count, Length: 6776, dtype: int64

# %%
df.shape
# Out:
# (123368, 61)

# %%
df['precio_m2'].value_counts()
# Out:
# precio_m2
# Error al procesar precio m²    4338
# 1.000 €/m²                      423
# 2.000 €/m²                      417
# 2.500 €/m²                      376
# 1.666 €/m²                      306
#                                ...
# 9.765 €/m²                        1
# 7.124 €/m²                        1
# 5.836 €/m²                        1
# 6.752 €/m²                        1
# 111.111 €/m²                      1
# Name: count, Length: 8612, dtype: int64

# %%
# Limpieza de la olumna precio_m2
df['precio_m2'] = df['precio_m2'].apply(lambda x: float(x.replace(' €/m²', '').replace('€', '').replace(' ', '').replace('.', '').replace(',', '.')) if 'Error al procesar precio m²' not in x else None)
df['precio_m2'] = df['precio_m2'].astype(float)

# %%
df['precio_m2'].value_counts()
# Out:
# precio_m2
# 1000.0      423
# 2000.0      417
# 2500.0      376
# 1500.0      306
# 1666.0      306
#            ...
# 9765.0        1
# 7124.0        1
# 5836.0        1
# 6752.0        1
# 111111.0      1
# Name: count, Length: 8611, dtype: int64

# %%
df['superficie'].value_counts()
# Out:
# superficie
# 100 m²       2204
# 90 m²        2202
# 80 m²        1968
# 120 m²       1948
# 70 m²        1608
#              ...
# 55.000 m²       1
# 1.936 m²        1
# 1.651 m²        1
# 1.489 m²        1
# 30.657 m²       1
# Name: count, Length: 2320, dtype: int64

# %%
# Limpieza columna superficie
df['superficie'] = df['superficie'].apply(lambda x: float(x.replace(' m²', '').replace(' ', '')) if x.replace(' m²', '').replace(' ', '').isnumeric() else None)
df['superficie'] = df['superficie'].astype(float)

# %%
df['superficie'].value_counts()
# Out:
# superficie
# 100.0    2204
# 90.0     2202
# 80.0     1968
# 120.0    1948
# 70.0     1608
#          ...
# 17.0        1
# 872.0       1
# 944.0       1
# 991.0       1
# 827.0       1
# Name: count, Length: 969, dtype: int64

# %%
df['superficie_util'].value_counts()
# Out:
# superficie_util
# 90 m²        2538
# 100 m²       2128
# 80 m²        1954
# 70 m²        1674
# 120 m²       1490
#              ...
# 781 m²          1
# 19.308 m²       1
# 2.052 m²        1
# 4.978 m²        1
# 1.460 m²        1
# Name: count, Length: 1089, dtype: int64

# %%
# Limpieza columna superficie_util
df['superficie_util'] = df['superficie_util'].apply(lambda x: float(x.replace(' m²', '').replace(' ', '')) if isinstance(x, str) and x.replace(' m²', '').replace(' ', '').isnumeric() else None)
df['superficie_util'] = df['superficie_util'].astype(float)

# %%
df['superficie_util'].value_counts()
# Out:
# superficie_util
# 90.0     2538
# 100.0    2128
# 80.0     1954
# 70.0     1674
# 120.0    1490
#          ...
# 987.0       1
# 706.0       1
# 774.0       1
# 571.0       1
# 714.0       1
# Name: count, Length: 822, dtype: int64

# %%
df['superficie_solar'].value_counts()
# Out:
# superficie_solar
# 1.000 m²     588
# 500 m²       524
# 200 m²       413
# 400 m²       394
# 800 m²       366
#             ...
# 13.296 m²      1
# 2.076 m²       1
# 1.636 m²       1
# 5.097 m²       1
# 8.087 m²       1
# Name: count, Length: 4665, dtype: int64

# %%
# Limpieza columna superficie_solar
df['superficie_solar'] = df['superficie_solar'].apply(lambda x: float(x.replace(' m²', '').replace(' ', '').replace('.', '').replace(',', '.')) if isinstance(x, str) and x.replace(' m²', '').replace(' ', '').replace('.', '').replace(',', '').isnumeric() else None)
df['superficie_solar'] = df['superficie_solar'].astype(float)

# %%
df['superficie_solar'].value_counts()
# Out:
# superficie_solar
# 1000.0     588
# 500.0      524
# 200.0      413
# 400.0      394
# 800.0      366
#           ...
# 13296.0      1
# 2076.0       1
# 1636.0       1
# 5097.0       1
# 8087.0       1
# Name: count, Length: 4665, dtype: int64

# %%
df['superficie_construida'].value_counts()
# Out:
# superficie_construida
# 100 m²      2200
# 90 m²       2196
# 80 m²       1958
# 120 m²      1944
# 70 m²       1602
#             ...
# 8.422 m²       1
# 5.461 m²       1
# 4.215 m²       1
# 5.782 m²       1
# 4.668 m²       1
# Name: count, Length: 1904, dtype: int64

# %%
# Limpieza columna superficie_construida
df['superficie_construida'] = df['superficie_construida'].apply(lambda x: float(x.replace(' m²', '').replace(' ', '')) if isinstance(x, str) and x.replace(' m²', '').replace(' ', '').isnumeric() else None)
df['superficie_construida'] = df['superficie_construida'].astype(float)

# %%
df['superficie_construida'].value_counts()
# Out:
# superficie_construida
# 100.0    2200
# 90.0     2196
# 80.0     1958
# 120.0    1944
# 70.0     1602
#          ...
# 944.0       1
# 2.0         1
# 838.0       1
# 792.0       1
# 827.0       1
# Name: count, Length: 966, dtype: int64

# %%
df['baños'].value_counts()
# Out:
# baños
# 2.00      49913
# 1.00      35251
# 3.00      18365
# 4.00       6871
# 5.00       2726
# 6.00       1223
# 7.00        496
# 8.00        272
# 9.00        144
# 10.00       112
# 11.00        61
# 12.00        33
# 13.00        25
# 14.00        22
# 15.00        17
# 17.00        10
# 18.00         8
# 20.00         8
# 16.00         6
# 28.00         4
# 40.00         3
# 39.00         3
# 33.00         3
# 21.00         3
# 50.00         3
# 25.00         2
# 32.00         2
# 81.00         1
# 23.00         1
# 24.00         1
# 289.00        1
# 202.00        1
# 201.00        1
# 160.00        1
# 22.00         1
# 37.00         1
# 3.14          1
# 52.00         1
# 30.00         1
# 93.00         1
# Name: count, dtype: int64

# %%
# Aplicamos limpieza a baños ya que encontramos valores muy atípicos, por lo que nos quedamos con aquellos inmuebles con como mucho 10 baños y el resto lo dejamos en none
def limpiar_banos(x):
    try:
        x = float(x)
        if x > 10 or not x.is_integer():
            return None
        return x
    except ValueError:
        return None

df['baños'] = df['baños'].apply(limpiar_banos).astype('Int64')

# %%
df['baños'].value_counts()
# Out:
# baños
# 2     49913
# 1     35251
# 3     18365
# 4      6871
# 5      2726
# 6      1223
# 7       496
# 8       272
# 9       144
# 10      112
# Name: count, dtype: Int64

# %%
df.shape
# Out:
# (123368, 61)

# %%
df['habitaciones'].value_counts()
# Out:
# habitaciones
# 3.000      43662
# 4.000      24480
# 2.000      22281
# 5.000       9597
# 1.000       6590
# 6.000       4528
# 7.000       1820
# 8.000       1057
# 9.000        457
# 10.000       401
# 12.000       149
# 11.000       128
# 15.000        57
# 14.000        56
# 13.000        55
# 20.000        27
# 16.000        26
# 18.000        18
# 30.000         9
# 24.000         9
# 17.000         8
# 19.000         7
# 25.000         4
# 23.000         4
# 22.000         4
# 27.000         3
# 21.000         3
# 37.000         3
# 50.000         2
# 46.000         2
# 35.000         2
# 93.000         2
# 29.000         2
# 45.000         2
# 43.000         2
# 33.000         2
# 40.000         2
# 1.998          1
# 436.000        1
# 80.000         1
# 60.000         1
# 48.000         1
# 52.000         1
# 58.000         1
# 26.000         1
# 28.000         1
# Name: count, dtype: int64

# %%
# Aplicamos limpieza a habitaciones ya que encontramos valores muy atípicos, por lo que nos quedamos con aquellos inmuebles con como mucho 20 habitaciones y el resto lo dejamos en none
def limpiar_habitaciones(x):
    try:
        x = float(x)
        if x > 20 or not x.is_integer():
            return None
        return x
    except ValueError:
        return None

df['habitaciones'] = df['habitaciones'].apply(limpiar_habitaciones).astype('Int64')

# %%
df['habitaciones'].value_counts()
# Out:
# habitaciones
# 3     43662
# 4     24480
# 2     22281
# 5      9597
# 1      6590
# 6      4528
# 7      1820
# 8      1057
# 9       457
# 10      401
# 12      149
# 11      128
# 15       57
# 14       56
# 13       55
# 20       27
# 16       26
# 18       18
# 17        8
# 19        7
# Name: count, dtype: Int64

# %%
df['codigo_postal'].isna().sum()
# Out:
# 73303

# %%
# Todas las extracciones tienen timestamp (momento en el que ha sido scrapeado ese inmueble)
df['timestamp'].isna().sum()
# Out:
# 0

# %%
# Convertimos la columna a tipo datetime
df['timestamp'] = pd.to_datetime(df['timestamp'], errors='coerce')

# %%
df['timestamp']
# Out:
# 0         2025-02-28 21:02:41
# 1         2025-02-28 21:02:42
# 2         2025-02-28 21:02:42
# 3         2025-02-28 21:02:42
# 4         2025-02-28 21:02:42
#                  ...
# 261929    2025-03-01 17:07:38
# 261930    2025-03-01 17:07:39
# 261931    2025-03-01 17:07:39
# 261932    2025-03-01 17:07:39
# 261933    2025-03-01 17:07:40
# Name: timestamp, Length: 261934, dtype: object

# %%
df['timestamp'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
df['planta'].value_counts()
# Out:
# planta
# 1ª            11527
# 2ª             9093
# Bajo           6988
# 3ª             6686
# 4ª             4451
# 5ª             2541
# 6ª             1367
# 7ª              899
# 8ª              493
# 9ª              336
# Entresuelo      258
# Principal       218
# 10ª             176
# Más de 20       174
# 11ª             165
# 12ª              85
# Semisótano       64
# 13ª              59
# 14ª              58
# 15ª              49
# 17ª              38
# Sótano           35
# 16ª              29
# 19ª              27
# 18ª              27
# 20ª              16
# Name: count, dtype: int64

# %%
# Limpieza de la columna 'planta'
df['planta'] = df['planta'].str.replace('ª', '', regex=False).str.strip()
df['planta'] = df['planta'].replace({'Bajo': 0, 'Principal': 0, 'Semisótano': -1, 'Entresuelo': -1, 'Sótano': -1, 'Más de 20': 21})
df['planta'] = df['planta'].astype('float64').astype('Int64')

# %%
df['planta'].value_counts()
# Out:
# planta
# 1     11527
# 2      9093
# 0      7206
# 3      6686
# 4      4451
# 5      2541
# 6      1367
# 7       899
# 8       493
# -1      357
# 9       336
# 10      176
# 21      174
# 11      165
# 12       85
# 13       59
# 14       58
# 15       49
# 17       38
# 16       29
# 19       27
# 18       27
# 20       16
# Name: count, dtype: Int64

# %%
# Columnas cualitativas Si/No/Sin especificar
columnas_si_no = ['luz', 'sistema_de_seguridad', 'vidrios_dobles','se_aceptan_mascotas', 'calefaccion', 'jardin','trastero', 'gastos_de_comunidad',
                  'cocina_equipada', 'agua', 'aire_acondicionado', 'terraza', 'armarios_empotrados','balcon', 'garaje', 'puerta_blindada',
                  'adaptado_a_personas_con_movilidad_reducida', 'ascensor', 'alcantarillado', 'portero_automatico', 'exterior', 'piscina',
                  'calle_alumbrada', 'lavadero', 'amueblado', 'gas', 'comedor', 'chimenea', 'no_se_aceptan_mascotas', 'telefono']

# %%
df_si_no= df[columnas_si_no]

# %%
df_si_no
# Out:
#               luz sistema_de_seguridad vidrios_dobles se_aceptan_mascotas  \
# 0             NaN                  NaN            NaN                 NaN
# 1             NaN                  NaN            NaN                 NaN
# 2             NaN                  NaN            NaN                 NaN
# 3             NaN                  NaN            NaN                 NaN
# 4             NaN                  NaN            NaN                 NaN
# ...           ...                  ...            ...                 ...
# 261855        NaN                  NaN            NaN                 NaN
# 261858        NaN                  NaN             Si                 NaN
# 261859        NaN                  NaN            NaN                 NaN
# 261861        NaN                  NaN            NaN                 NaN
# 261893  Iberdrola                  NaN             Si                 NaN
#
#         calefaccion   jardin trastero gastos_de_comunidad cocina_equipada  \
# 0           Central  Privado      NaN                 NaN             NaN
# 1                Si       Si      NaN                 NaN             NaN
# 2                Si  Privado      NaN                 NaN              Si
# 3                Si       Si      NaN                 NaN             NaN
# 4        Aerotermia  Privado      NaN                 NaN             NaN
# ...             ...      ...      ...                 ...             ...
# 261855  Gas natural      NaN       Si     Entre 60 y 80 €              Si
# 261858  Gas natural      NaN      NaN     Entre 40 y 60 €             NaN
# 261859          NaN      NaN      NaN                 NaN             NaN
# 261861       Gasoil      NaN       Si                  Si              Si
# 261893       Gasoil   Propio      NaN                 NaN              Si
#
#        agua  ... exterior      piscina calle_alumbrada lavadero amueblado  \
# 0       NaN  ...      NaN  Comunitaria             NaN      NaN       NaN
# 1       NaN  ...      NaN          NaN             NaN      NaN       NaN
# 2       NaN  ...      NaN  Comunitaria             NaN      NaN       NaN
# 3       NaN  ...      NaN          NaN             NaN      NaN       NaN
# 4       NaN  ...      NaN          NaN             NaN      NaN       NaN
# ...     ...  ...      ...          ...             ...      ...       ...
# 261855  NaN  ...       Si          NaN             NaN      NaN       NaN
# 261858  NaN  ...       Si          NaN             NaN      NaN       NaN
# 261859  NaN  ...      NaN          NaN             NaN      NaN       NaN
# 261861  NaN  ...      NaN          NaN             NaN      NaN        Si
# 261893   Si  ...      NaN          NaN              Si      NaN        Si
#
#         gas comedor chimenea no_se_aceptan_mascotas telefono
# 0       NaN     NaN      NaN                    NaN      NaN
# 1       NaN     NaN      NaN                    NaN      NaN
# 2       NaN     NaN      NaN                    NaN      NaN
# 3       NaN     NaN      NaN                    NaN      NaN
# 4       NaN     NaN      NaN                    NaN      NaN
# ...     ...     ...      ...                    ...      ...
# 261855  NaN     NaN      NaN                    NaN      NaN
# 261858  NaN     NaN      NaN                    NaN      NaN
# 261859  NaN     NaN      NaN                    NaN      NaN
# 261861  NaN     NaN      NaN                    NaN      NaN
# 261893  NaN      Si       Si                    NaN      NaN
#
# [123368 rows x 30 columns]

# %%
# Crear un diccionario para almacenar los valores únicos de cada columna
valores_unicos = {}

# Iterar sobre cada columna conflictiva y obtener los valores únicos
for col in columnas_si_no:
    valores_unicos[col] = df[col].unique()

# Mostrar los valores únicos de cada columna
for col, valores in valores_unicos.items():
    print(f"Valores únicos en la columna '{col}': {valores}\n")
# Out:
# Valores únicos en la columna 'luz': [nan 'Si' 'Iberdrola' 'Otra compañía' 'Endesa' 'Sin especificar'
#  'Unión fenosa' 'Sin luz']
#
# Valores únicos en la columna 'sistema_de_seguridad': [nan 'Si' 'Alarma' 'vigilancia 24h, con cámaras de seguridad'
#  'Videovigilancia 24 h' 'Urb cerrada' 'Vigilancia 24 h' '24 horas'
#  '24 horas control de acceso' 'Videocamaras' 'vigilancia 24h'
#  'Seguridad 24 hora' 'Acceso restringido' 'con cámaras de seguridad'
#  'Rejas' 'Ventanas con persianas e seguridad' 'Conserje' 'Portero'
#  'Portero físico 24/7' 'Portero 24/7' 'Conserje 24 h' 'Alarma y rejas'
#  'Camaras de vigilancia' 'Servicio de conserjería' 'Concerje' 'Available'
#  'Sie' 'Portero físico' 'Alarma.' 'Videovigilencia.'
#  'Portero con vivienda' '2 turnos + cámaras nocturnas' '24h' 'Camaras'
#  'Circuito de video vigilancia en zonas comunes' 'Servicio de conserjeria'
#  'Seguridad privada urbanizacion' 'Vigilancia 24 horas'
#  'Servicio de portería' 'Portero fisico horario laboral'
#  'Portería. Portero físico' 'Cámaras vigilancia, conserje'
#  'Camaras vigilancia en portal' 'Puerta acorazada' 'Caja fuerte empotrada'
#  'Alarma conectada' '24/7' 'Rejas en toda la casa y alarma'
#  'Complejo residencial privado' 'Rejas de seguridad' 'Camaras y alarma'
#  'urbanización cerrada' 'Alarma conectada a central'
#  'Security service 24h' 'En urbanización' 'Video vigilancia zonas comunes'
#  'Puerta seguridad' 'Persianas' 'Alarma!' 'Alarma y puerta de seguridad'
#  'Recepción abierta 24/7' 'Carril bici de doble sentido en la avenida'
#  'Camaras de vigilancia y vigilancia nocturna'
#  'Vídeo vigilancia en todo el edificio.' 'Complejo cerrado'
#  'Sistema de alarma' 'Complejo bien privado.' 'Portón cerrado siempre'
#  'Puerta blindada' 'Video-vigilancia'
#  'Alarma instalada/ sistem detección incendio y agua'
#  'Tiene alarma y sistema videovigilancia' 'Videportero'
#  'Conserje compartido con la comunidad colindante'
#  'Domotica , antifugas de agua y gas. Y de incendios' 'Portero 24 horas'
#  'Alarm' 'Alarma propia' 'Alarm, surveillance cameras' 'Security shutters'
#  'Alarm, security shutters'
#  'Propiedad vallada y circuito de camaras cerrado'
#  'Comunidad con portero físico todo el año'
#  'Cameras, alarmas casa demotic' 'Privada' 'Porteria'
#  'Servicio de porteria' 'Rejas en ventanas' 'Camara de vigilancia'
#  'Dispone de una alarma con cámaras' 'Cctv en zonas comunes de acceso'
#  'Servicio de portería 24/7' 'Camaras de seguridad'
#  'Servicio de recepcion 24/7' 'Camaras de seguridad en urbanización'
#  'Cámaras de vigilancia' 'Cámaras de seguridad  en la comunidad'
#  'Alarma conectada 24 horas' 'Alarma en las parcelas'
#  'Alarma / camara vigilancia'
#  'Alarm, security entrance, security service 24h'
#  'Alarm, security entrance' 'Portero físico.'
#  'Alarma y cámaras de seguridad' 'Caja fuerte, alarma y dom'
#  'Alarm, security entrance, security shutters' 'Videovigilancia'
#  'Posibilidad de confección a seguridad' 'Security entrance'
#  'Security entrance, security shutters' 'Preinstalación alarma, cámaras'
#  'Surveillance cameras' 'Preinstalación alarma y video cámaras'
#  'Preinstalación de alarma, cámaras'
#  'Security entrance, security service 24h, security'
#  'Alarm, security entrance, security service 24h, su'
#  'Alarm, security entrance, surveillance cameras'
#  'Alarm, security entrance, security shutters, surve'
#  'Security shutters, surveillance cameras' 'Alarm, security service 24h'
#  'Acceso a la calle privado' 'Videoportero autoático y sistema de alarmas'
#  'Comunidad cerrada en perímetro' 'Alarmas' 'En la comunidad'
#  'Videovigilancia - luces de emergencia' 'Urbanización privada cerrada'
#  '24h urbanización privada lujo' 'Alarma en toda la casa'
#  'Alarma y cameras' 'Portero electrónico' 'Sistema alarma con cámaras.'
#  'Alarma i reixes' 'Alarma protec girona' 'Alarma conectada a policia'
#  'Domótica' 'Cerradura de segurida -puerta de seguridad'
#  'Puerta de seguridad' 'Video portero' 'Cerradura y ouerta de seguridad'
#  'Puerta de seguridad blindada.' 'Puerta blindad con alarma'
#  'Alarma con instalación interior, cámaras, wifi'
#  'Próximamente vigilancia en parking' 'Sistema de alarma security'
#  'Alarma conectada a policía' '1992' 'Ascensor con llave' 'Cámaras'
#  'Alarma instalada' 'Vigilancia 24h'
#  'Alarma y detectores en todas las ventanas' 'Codigo   1945'
#  'Video vigilancia' 'Conserje 365 dias'
#  'Circuito de cámaras, alarma perimetral' 'Conserje 24h' 'Puerta'
#  'Patio cerrado y garaje con portal automático'
#  'Puerta de seguridad y rejas' 'Alarma securitas direct'
#  'Cristales de seguridad en toda la casa' 'Camaras de seguridad y portero'
#  'Puerta principal' 'Alarma y portero físico' 'Preinstalación'
#  'Alarma perimetral e interior' 'Alarma en la vivienda']
#
# Valores únicos en la columna 'vidrios_dobles': [nan 'Si' 'Climalit' 'Climalt en las ventanas y puesta de la solana'
#  'Climalit, persianas eléctricas toda la casa,toldos' 'Todas las ventanas'
#  'Climalit 4/6/4 con butiral barrotillo estilo inglé' 'Velux'
#  'De climalit' 'Doble acristalamiento climalit' 'Doble ventana en salón'
#  'Seguridad' 'Climalit cristal termico' 'Toipo climalit'
#  'Contraventana y mosquiteras' 'De climalit con puente termico'
#  'Con mosquiteras' 'Climalit de pvc'
#  'Ventanas de aluminio con cristales climalit' 'Dobles de climalit'
#  'En ventanas y balcones' 'Doble climalit, velux en buhardilla' 'No'
#  'Dobles de climalit, oscilovatiente, acusaticas'
#  'Doble cámara , cuatro vidrios' 'Si de climalit' 'Si, de climalit'
#  'Rotura puente  térmico' 'Doble climalit' 'Climalit 4/6/4'
#  'Doble ventana' 'Acristalamiento guardian y climalit 4/6/4'
#  'Y dobles ventanas' 'Cerramientos de aluminio'
#  'De pvc, acristalamiento doble y camara aislante'
#  'De climalit oscilovatientes' 'Madera de guinea' 'Si climalit'
#  'Oscilobatientes' 'En la zona del exterior' 'Persianas eléctricas'
#  'Doble acristalamiento camara de aire aislante' 'Dobles' 'Triple vidrio'
#  'Ventanas oscilovatientes'
#  'Aluminio lacaddo doble acristalamiento climalit' 'Tiene doble cristal.'
#  'Pvc oscilobatientes y climalit' 'Pvc' 'Termoacustica'
#  'En ventanas nuevas' 'Ventanas nuevas con doble cristal'
#  'En todas las ventanas' 'con sistema climalit' '6+15+6'
#  'Climalit, cristal de seguridad' '4+10+4' 'Climalit (control solar)'
#  'Doble cristal en puertas y ventanas'
#  'Ventanas con doble cristal antirruidos'
#  'Cuádruple acristalamiento y protección solar' 'Tipo climalite'
#  'climalit.' 'Cuádruple acristalamiento' 'Mosquiteras'
#  'Doble acristalamiento' 'Doble acristalamiento con cámara de aire'
#  'Con palillería' 'Clima lit' 'En toda la casa' 'Climalix'
#  'Doble acristalamiento y oscilobatiente'
#  'Si, en todas las puertas y ventanas.'
#  'Cuádruple cristal con cámara tipo climalit' 'Si.' 'Aluminio'
#  'Acristalamiento doble de seguridad'
#  'Doble acristalamiento con puente térmico' 'Dobles acristalamientos'
#  'Climalit con mosquiteras' 'Climalit con aluminio blanco'
#  'Aluminio blanco' 'Aluminio blanco, climalit, mosquiteras'
#  'Vidrios climalit dobles y triple cristal' 'Aluminio gris'
#  'Climalit y doble ventana' 'Dobles ventanas' 'Palillería'
#  'Climalit, de hierro los balcones' 'Climalit 24 mm'
#  'Climalit con aluminio burdeos' 'En aluminio gris' 'En dos dormitorios'
#  'Climalit aluminio lacado en blanco'
#  'Climalit, doble ventanas, aluminio con mosquiteras' 'Con climalit'
#  'Climalit oscilobatientes con alumunio blanco' 'Stadip y planitherm'
#  'Climalit y oscilo.' 'En el balcón cerrado' 'Ventanas oscilobatientes'
#  'Climalit o similar' 'En ventanas de madera' 'Oscilobatientes.'
#  'Doble cristal' 'Sin rotura de puente térmico'
#  'Triple cristal y gas argón entre cristal y cristal' 'En planta baja'
#  'La mitad están cambiados. Resto de hierro' 'Climait' 'Grosor especial'
#  'En los ventanales de comedor a calle' 'En ventanas' 'Con persianas'
#  'Climalit 4+4' 'Con persianas eléctricas' 'Doble ventana climalit'
#  'Cliamalit' 'Climalit con cámara de aire' 'Triples en toda la vivienda'
#  'Aislamiento termico y acustico' 'Climalit con rotura de puente termico'
#  'Climalit, pvc, oscilobatientes' 'Y madera' 'Vidrios triples'
#  'Climalit, cristales de seguridad' 'Salón y ventanas' 'En la terraza'
#  'Aluminio climalit' 'Oscilo batientes' 'Ventanas de madera con climalit'
#  'Algunas ventanas' 'Con puente térmico' 'Con control de luz solar'
#  'Control solar' 'Puente térmico' 'Con protección de rayos del sol'
#  'Con control solar' 'De seguridad'
#  'Climalit con rotura de puente térmico'
#  'Cámara de aire interna tipo climalit' 'Doble chimalli'
#  'Climalit oscilobatiente' 'Doble ventana de aluminio' 'En todo el piso'
#  'Cristal aislante tipo climalit' 'Aislante tipo climalit'
#  'Concristal aislante tipo climalit' 'Si todas las puertas y ventanas'
#  'No en todo el apartamento' 'Ventanal' 'Solo salón comedor'
#  'Gran ventanal' 'Ventanal comedor y habitacion' 'Doble cámara hab.'
#  'Available' 'Recien cambiados' 'Con muy buenos acabados' 'Doble cristal.'
#  'Clinalit' 'En cerramientos exteriores' 'En cerramientos aluminio'
#  'Cristal cámara ancho especial, térmico' 'Alumini' 'Climatic'
#  'Y mosquiteras' 'Si y oscilivatientes' 'Aislante' 'Doble puente térmico'
#  '.' 'Al-lumini' 'Puente termico' 'Algunas ventanas batientes'
#  'Doble ventana en toda la vivienda.' 'Muy buen aislamiento.'
#  'Doble cámara con baja emisión y puente térmico' 'Todas la ventanas'
#  'Si, aluminio inox' 'Y sin climalit, depende de las ventanas y/o vidrie'
#  'Color gris claro' 'De aluminio con verjas y toldos' 'Aislantes ruido'
#  'Aislante acústico' 'Alguns' 'Climalt' 'Ventanas de aluminio'
#  'Con cámara, anti robo y control solar' 'Pvc, doble cristal'
#  'Simulacion madera' 'Con aislante termico' 'Con cuarteron ingles'
#  'Ailantes del frio y ruido' 'Aluminio con rotura de puente térmico'
#  'Climalit mosquiteras' 'Y ventanas de aluminio'
#  'Con ventanas de aluminio' 'Con cristales de climalit'
#  'Con cámara, con puente térmico' 'Càmara' 'Sí, ventanas de aluminio'
#  'Tipo climalit' 'Aluminio doble cristal.' 'Doble cristal climalit'
#  'Seguretat' 'Marca climalit con mosquitera' 'Climalit cuarterones'
#  'En todas las ventanas y balconeras' 'Climalit, con puente térmico'
#  'Dobles-climalit' 'Disponible' 'Doble acristalado climalit' 'Ventanas'
#  'C' 'Con persianas electricas' 'Vidrios tipo climalit' 'Blindados'
#  'Ventanas con mosquiteras' 'Insonorizados'
#  'Doble carpintería exterior en cerramiento balcón'
#  'Bien aislado. Todo nuevo' 'Con camara' 'Sistema climalit'
#  'Triple cristal' 'Térmico e insonorizante' 'Ventanal doble de aluminio'
#  'Ventanas oscilobatiente' 'Tipo climalti' 'Con puente termico'
#  'Amplios ventanales' 'Oscilobatiente' 'Doble cristal y doble ventana'
#  'P.v.c. Climalit' 'En ventanal del salón' 'Doble ventana y vidreo doble'
#  'P.v.c. Con climalit' 'Ventana oscilovatiente' 'Vidrios dobles'
#  'En p.v.c lacados' 'Doble ventana pvc' 'Climalit, térmico y acústico.'
#  'Ventanas dobles' 'Con rotura de puente térmico' 'La planta baja'
#  'Abatibles' 'Climalit doble' 'Contraventanas y ventanas' 'Absatibles,'
#  'Climatit' 'Acristalamiento terraza exterior y domotizado.'
#  'Climalit y mosquiteras' 'Palilleria' 'En salon' 'Climalit de doble hoja'
#  'En la zona nueva' 'Cristales de seguridad toda la casa' 'Convalecientes'
#  'Oscilobatietes' 'Aluminio  doble cristal' 'Tipo "climalit"'
#  'Tipo "climalit" y contraventanas' 'Rotura puente térmico'
#  'Doble ventana aluminio' '4-16-6 bajo emisivo' 'Doble ventana alumunio'
#  'Bajo emisivo' 'Bajo emisivos' 'Vidrios triples con doble cámara'
#  'Triples' 'En la fachada principal' 'Pvc climalit' 'Coverlin' 'Isolab'
#  'Climalit y oscilobatientes' 'Aluminio con climalit' 'Triples con argon'
#  'En toda la vivienda'
#  'Todas las ventanas oscilobatientes y con mosquiter' 'Rpt'
#  'Doble cristal climalit rpt' 'Cristal climalit' 'Climalit puente termico'
#  'Con rpt' 'Doble acristalamiento en las ventanas' 'Ventanas climalit'
#  'Ventanas dobles oscilobatientes'
#  'Si, dispone de vidrios dobles, ventanas climalit' 'Insonorizado'
#  'Aluminio antiguo']
#
# Valores únicos en la columna 'se_aceptan_mascotas': [nan 'Si']
#
# Valores únicos en la columna 'calefaccion': ['Central' 'Si' 'Aerotermia' nan 'Gas natural' 'Eléctrica' 'Gasoil'
#  'Suelo radiante' 'Suelo radiante,' 'Placas solares' 'Propano' 'Y pelé'
#  'G/n' 'Individual' 'Electrica con acumuladores' 'Butano'
#  'Acumuladores y bomba de calor y aire acondicionado en todos los dormitorios'
#  'Geosolar' 'Gas propano' 'Suelo radiante, aerotermia y placas solares.'
#  'Geotermia' 'Propano canalizado' 'Pellets' 'Gas ciudad' 'Acumuladores'
#  'Nocturna' 'Leña y solar' 'Aerotermia - suelo radiante' 'Bomba de calor'
#  'Sin especificar' 'Con acumuladores y agua caliente con termo electri'
#  'De gasoil' 'Bomba frio/calor' 'Bombas calor frio'
#  'Suelo radiante refrigerante' 'De gasoil con deposito de 750 litros'
#  'De gasoil con deposito de 500 litros' 'Hilo radiante'
#  'Calefaccion individual' 'Electrica punto azul' 'Bajo consumo'
#  'Con reguladores' 'Aire acondicionado' 'Estufa'
#  'Sistema de aerotermia en toda la vivienda'
#  'Central contadores individuales' 'Gas butano' 'Individual - gas natural'
#  'No disponible' 'Calor azul bajo consumo' 'Suelo radiante con aerotermia'
#  'Bomba frío-calor' 'Climatizacion' 'Gas natural y biomasa'
#  'Bomba frio calor' 'Geotermia y aerotermia'
#  'Calefacción central con contador individual' 'Climatización'
#  'Con acumuladores electricos' 'Gasóleo' 'Calefacción individual' 'Pelet'
#  'Aerotermía con suelo radiante' 'Caldera central con contador individual'
#  'Central con contador individual' 'Ind. Gas' 'C.c. Contador individual'
#  'C.c.' 'Radiante' 'No tiene' 'Biomasa' 'Aeroteremia' 'Ind gas'
#  'Leña o carbón' 'Con contador' 'Con contador repartidores'
#  'Eléctrica bajo cunsumo' 'Chimenea' 'Pellet' 'Con repartidores'
#  'Gas individual' 'Folio radiante' 'Con repartidores individuales'
#  'No dispone' 'Central con contador' 'No tiene calefacción'
#  'Aerotermia-suelo radiante' 'Aerotermia- suelo radiante' 'Butano-propano'
#  'Electrica' 'Sin calefacción' 'Caldera individual' 'Caldera indivudual'
#  'Preinstalación' 'Estufa de leña' 'Combustible fosil' 'De pelles'
#  'Cocina calefactora' 'Gas oil' 'Otros' 'Centralizada'
#  'Calefacción individual de gas ciudad' 'Leña' 'Sin detallar'
#  'Aerotermia con suelo radiante' 'Gas ciudad, serv centrales'
#  'Central contador individual' 'Gas-oil' 'Paneles solares' 'Aereotermia'
#  'Central (minimos incluidos)' 'Indiv' 'Indv' 'Central , contador ind.'
#  'Indiv.' 'Gasoleo' 'Centrales de gasoil' 'Centrales'
#  'Suelo radiante aerotermia' 'Radiante con aerotermia' 'Carbon y leña'
#  'Estufas y cocina leña' 'Gas nat.'
#  'Calefaccion por vaso de expansion (chimenea)' 'Acumulador eléctrico'
#  'Pavimento radiante a gas natural' 'Chimenea de leña' 'Suelos radiantes'
#  'Calefacción central' 'Radiante por suelo' 'Pre installation' 'Electric'
#  'Fireplace' 'Suelo radiante en toda la vivienda' 'Suelo radiante - gas'
#  'Caldera radiadores gasoil' 'Solar' 'Yes' 'Instalada por radiadores'
#  'Por conductos de aire' 'Estufa pele' 'Radiadores calor azul'
#  'Por conductos' 'Leña/pelet' 'Chimeneas y estufas leña'
#  'Aires frío/calor' 'Individual - gasoleo' 'No' 'Split f/c' 'Calor azul'
#  'Suelo radiante y refrigerante por aerotermia' 'Bomba f/c'
#  'Radiadores de gas ciudad' 'Por acumuladores' 'Bomba frío/calor'
#  'Radiadores' 'Gas natural por suelo radiante' 'Prehistalación'
#  'Por radiadores' 'Por radiadores y caldera gas ciudad'
#  'Radiadores caldera de gas propano urbanización con contadores individuales'
#  'Splits' 'Electrica acumuladores' 'Split y chimenea'
#  'Radiadores con calderas  el gas es propano hay depósito en la urbanización'
#  'Centralizada por toda la casa' 'Chimenea de leña en salón'
#  'Radiadores gas natural' '3 chimeneas' 'Chimenea en salon'
#  'Climatización centralizada' 'Sí, por gas' 'Split en el salón'
#  'Estufa de pellet' 'Estufa de leñas' 'Pre-instalacion' 'Preinstalacion'
#  'Por conductos calor y frío' 'Suelo radiante y refrescante calor y frío'
#  'Split en salon' 'Por gasoil' 'Gad' 'Split frio calor' 'Gasolin'
#  'Centralizado' 'Individual por gas' 'Estufa  leña' 'Indvidual por gas'
#  'Por gas mas 2 chimeneas' 'Individ.' '1 split bomba calor y frío'
#  'Gas, 1 split calor y frío' 'Individual gas ciudad'
#  'Se llevba los radiadores' 'De leña con la chimenea'
#  'Calefaccion de gas radiadores' 'Estufa pellet' 'Estufa peles'
#  'Preistalación' 'Split calor y frío salón, cocina y dormitorio'
#  'Placas solares y suelo radiante' 'Estufa pellets'
#  'Preinstalación calefaccion radiador' 'Suelo radiente'
#  'Ventilación mecanica' 'Acumuladores eléctricos' 'Caldera centralizada'
#  'Suelo radiante.' 'Con calefacción'
#  'Calefaccion suelo radiante y refrigeracion mediant'
#  'Calefacción con suelo radiante por aerotermia'
#  'Suelo radiante mediante aerotermia daikin'
#  'Suelo radiante  y refigeracion mediante aerotermia' 'Gasoleo y leña'
#  'Central heating by radiators' 'De leña' 'Chimenea leña'
#  'Calefacción central de gasoil.' 'Bomba frío calor' 'Radiating floor'
#  'Duct based' 'Centralised' 'Split' 'Estufa de pellets'
#  'Electric radiators' 'Central heating'
#  'Central heating, central heating by radiators, gas' 'Split en pared'
#  'Natural gas' 'Hot cold' 'Underfloor heating (throughout)' 'Heat pumps'
#  'Centralised fuel oil' 'Centralised gas' 'Heater' 'Radiadores electricos'
#  'Preinstalacion por toda la vivienda' 'Canalizada f/c'
#  'Radiadores gas ciudad' 'Aerotermo' 'Dos chimeneas'
#  'Aire acondicionado frío/calor'
#  'Calefacción y aire acondicionado por conductos' 'Split en salón'
#  'Radiadores a los que le suministra la estufa de pe' 'De gas propano'
#  'Calefaccion de gasoil y de leña' 'Pre' 'Central a gas'
#  'Central electric' 'Suelo radiante, aerotermia' 'Chimenea pellet'
#  'Electric underfloor heating' 'Aerothermia' '-' 'Por suelos radiantes'
#  'Pelets con radiadores en toda la casa' 'Aerothermal system'
#  'Solar panels' 'Pre - instalación' 'Central (gas)'
#  'Bomba de calor (split)' 'Bomba calor'
#  'A/a, calefacciã³n central, chimeneas' 'Infrarojos'
#  'Suelo radiante en baños' 'Central gas' 'Solar panel' 'Central gasoil'
#  'Sistema altherma daikin' 'Central heating, central heating by radiators'
#  'Central heating, underfloor heating (throughout)' 'Blue heat radiators'
#  'Underfloor heating (throughout), underfloor heatin'
#  'Underfloor heating (throughout), electric radiator'
#  'Central heating, ceiling heating system, central h'
#  'Underfloor heating (throughout), ceiling heating s'
#  'Underfloor heating (bathrooms)' 'Underfloor heating (partial)'
#  'Central heating, gasoil heating'
#  'Underfloor heating (throughout), gas heating' 'Firewood heater'
#  'Central heating, underfloor heating (throughout),'
#  'Ceiling heating system' 'Gas heating' 'Central heating, gas heating'
#  'Central heating, ceiling heating system' 'Radiadores a gas'
#  'Radiadores a gasoil' 'Gas underfloor heating' 'A/a' 'Not available'
#  'Central heating, electric radiators, gas heating' 'Conductos'
#  'Por splits' 'Central heating by radiators, gas heating' 'Estufa leña'
#  'Bomba frio y calor' 'Hilo radial'
#  'Radiadores conectados a tuberías de butano' 'Estufa bomasa'
#  'Centra con termostatos' 'Acumuladores de calor'
#  'Estufa con salida exterior' 'Individual gas propano.' 'Aire'
#  'Con contadores individuales' 'Individual a gas'
#  'Central sin contador - radiadores' 'Con consumo individual'
#  'Individual gas - radiadores' 'Individual gas-oil - radiadores'
#  'Individual gas - suelo radiante' 'Calefacción'
#  'Aire acondicionado reversible, calefacción centralizada eléctrica'
#  'Aire acondicionado reversible, calefacción centralizada gaz'
#  'Aire acondicionado reversible' 'Calefacción centralizada eléctrica'
#  'Calefacción centralizada gaz'
#  'Aire acondicionado reversible, suelo radiante'
#  'Aire acondicionado reversible, calefacción de gasoil'
#  'Aire acondicionado reversible, calefacción de gasoil, suelo radiante'
#  'Preinstalación de aerotermia' 'bomba de frío/calor' 'Aero térmia'
#  'Con radiadores' 'Radial' 'Calefacción radiante por gas propano'
#  'Calefacción de gas por suelo radiante' 'Hidroestufas de pellets'
#  'Hidroestufa de pelets' 'Gas natural y aerotermia' 'Gas cudad'
#  'De gas natural' 'De gas por suelo radiante' 'Propano- butano'
#  'Bomba de calor x 2 splits' 'Amb bomba de calor' 'Estufa pallet'
#  'Bomba de frío/calor' 'Instalación' 'Radiant' 'Chimenea a gasoil'
#  'Ind.gas' 'Ind.por conductos frio y calor' 'Climatizacion por conductos'
#  'Aerotérmia' 'Radiant i aerotèrmia' 'Llenya' 'Gasoil/aerotermia'
#  'Gasoil y madera' 'A gas' 'X radiadores' 'Por conducto'
#  'Aerotermia con suelo radiante para climatización y'
#  'Aerotermia en suelo radiante' 'Por aire' 'Caldera de leña'
#  'Por radiadores de gas natural' 'Aerotèrmia' 'suelo radiante'
#  'Placas solares y aerotermia' 'Estufa de gas butano' 'Bomba'
#  'Aerotermia suelo radiante' 'De gasoleo' 'Radiante de gasoil'
#  'Aerometria' 'Oil underfloor heating' 'Aceite' 'Individual gasoleo'
#  'Bomba de calor-frio' 'Termo eléctrico' 'Radiada por suelo' 'Aerotérmica'
#  'Si oil' 'Conducto' 'De gas' 'Leña por conductos' 'No terminado'
#  'Eléctrica en hab. 1 y 2' 'Calentador' 'Con bomba de calor.' 'Aacc'
#  'Central con contador de gas natural' 'Suelo radiante y aerotermia'
#  'placas solares fotovoltaicas' 'Radiante techo' 'Pelets'
#  'Caldera a gasoil' 'Cocina de leña' 'Preinstalación aerotermia'
#  'Chimenea de pellets' 'Pelles' 'Propanp' 'Caldera de pellets'
#  'Carbon leña' 'Discriminacion horaria' 'Suelo radiante por agua'
#  'Suelo radiante en toda la casa con termostato indi'
#  'Mixta gasoleo y aereotermia' 'Dispone de pre- instalacion de gas ciudad'
#  'Central incluida en la comunidad'
#  'Gasoil - central incluida en la comunidad'
#  'Gas ciudad con contador individual' 'Gasoil con contador individual'
#  'Pelex' 'Depósito de gas propano' 'Madera' 'Mixta'
#  'Suelo radiante por aero termia' 'Leña, placas solares'
#  'Caldera de biomasa con apoyo placas solares' 'Pelett'
#  'Caldera de pellets conectada a radiadores' 'Gas propano ciudad'
#  'Aeroermia' 'Aerotrmia' 'Calor azul ( bajo consumo )' 'Individual gasoil'
#  'Aerotermina por radiadores' 'Gasoil y pellets'
#  'Suelo radiante por sistema de aerotermia individua'
#  'Bomba de frío/calorpor conductos' 'Central individual'
#  'Instalación de gas natural' 'Calor azul y bomba de calor'
#  'Calefacción de leña' 'Calefacción de gas individual'
#  'Calefacción  de pellet' 'Calefacción de suelo radiante'
#  'Central con contadores' 'Electrica suelo radiante'
#  'Individual por acumuladores' 'Individual aerotermia'
#  'Contadores individuales' 'Individual - gas' 'Individual gas natural'
#  'Individual de propano' 'Individual propano' 'Individual de gasoil'
#  'Electica' 'Individual de gas' 'Eletricidad' 'De luz'
#  'Con contador individual' 'Aire acondicionado con bomba de calor'
#  'Acumuladores electricos' 'Central de gasoil' 'Propano individual'
#  'Gas natural individual' 'Estufa inserter con ventiladores y termostato'
#  'Estufa con ventiladores para toda la casa, ellos no la han puesto nunca'
#  'Gasoil, caldera con deposito de 1000l' 'Aestufa pelet' 'Pelllet u orujo'
#  'Peles' 'Central de propano' 'Tarifa nocturna' 'Radiante frio y calor'
#  'Gas -oil' 'Suelo radiante y contadores' 'Chimenea con caset'
#  'Gasoil y chimenea' 'Suelo radiante-aerotermia' 'Aerotemia'
#  'Suelo radiante (gasoil individual)' 'Calefacción central gasoil' 'Ss/cc'
#  'Estufa de pelles' 'Individual de gas natural' 'Indiv. Gas natural'
#  'Calefacción central - agua caliente individual, en este caso por calentador de butano'
#  'Individual gas natural, en la galería' 'Indiv. Gas antural' 'Sscc'
#  'Servicios centrales' 'Eléctrica con radiadores de bajo consumo'
#  'Chimena de leña que va a los radiadores' 'Estufa pallets y gasoleo'
#  'Calefacción suelo radiante' 'Caleacción a traves de suelo radiante'
#  'Indv. Gasoil' 'Ind de gas' 'Ind de gas propano'
#  'Caldera central con contadores de consumo'
#  'Central con contadores individuales de consumo'
#  'Centralizada con contador de consumo'
#  'Caldera centralizada con contador de consumo'
#  'Caldera central con contador de consumo'
#  'Central de gas natural más aerotermia, mediante su'
#  'Cental con contadores individuales' 'Paneles solares y gasoil de apoyo'
#  'Peleas' 'Y biomasa' 'Carbón' 'Gloria' 'Gaa propano'
#  'Necesaria instalación' 'Leña con chapa calefactora'
#  'Central con consumo individual' 'Gasoil comunitario' 'Bompa de calor'
#  'Gas ciudad individual' 'Gas natural con suelo radiante'
#  'Central consumo individual.' 'Gas natural-suelo radiante'
#  'Suelo radiante-gasoil' 'Central consumo individual'
#  'Gas natural suelo radiente' 'Gasoil suelo radiante'
#  'Central con contadores individuales'
#  'Gas natural suelo radiante 3 plantas' 'Gasoleo y pellets'
#  'Gas en la ventana' 'Pelllets sistema de aire por el suelo'
#  'Suelo radiante y refrescante' 'Central (contador individual)'
#  'Gasoil, contador individual' 'Carbon' 'No tiene radiadores' 'Gn'
#  'Gn de baja' 'Gas natural con estufa pellets en el salon'
#  'Gasoleo suelo radiante' 'Chimenea con salida aire al dormitorio'
#  'Radiante de propano dormitorios con radiadores' 'Electrica aire'
#  'Gasoil radiadores depósito de 5000 litros'
#  'Gasoil+estufa leña y pellets' 'Piñon' 'Acumulador'
#  'Bodega acondicionada y con chimenea' 'Hilo radiante agua'
#  'Contador individual' 'Central de pellets con contador individual'
#  'Aerotermia. Suelo radiante. Contador individual'
#  'Gas individual. Suelo radiante' 'Central con contador invidual'
#  'Geotermia comunitaria' 'Central con contador individual de gas'
#  'Comunitaria' 'Chimenea pellets']
#
# Valores únicos en la columna 'jardin': ['Privado' 'Si' nan 'Comunitario' '1650m²' 'Propio' '500m² de jardín'
#  'Barbacoa' '300m² de jardín' '40m²' '60m²' '4457m²' '900m²'
#  'Jardín zen, en su mayoría de grava con poco mantenimiento'
#  'Paisajismo mediterráneo en diferentes niveles'
#  'Paisajismo mediterráneo en diferentes niveles, baño exterior, cocina de verano, barbacoa y comedor al aire libre'
#  'Hermoso jardín paisajístico y tranquilo'
#  'Paraíso en el jardín trasero con luces de ambiente, paisajismo mediterráneo en diferentes niveles'
#  'Espacio de jardín bien cuidado, paisajismo mediterráneo en diferentes niveles'
#  '25m² de jardín' '430m² de jardín' '300m²' '20m² de jardín' '200m²'
#  '1000m²' '117m²' '1133m²' '750m²' '10576m²' '1100m²' '22m²' '3725m²'
#  '600m²' '150m²' '1300m²' '660m²' '1200m²' '73m²' '30m²']
#
# Valores únicos en la columna 'trastero': [nan 'Si' 'Sótano' 'Trastero de 11.20 m²' 'Nª 77'
#  'Debajo escalera exterior' 'Bastantes amplios' 'M2'
#  'Se vende por separado' '5.20' '10 m² reformado' '11 m²' '5,30 m² útiles'
#  '20m²' 'Incluido en la vivienda' 'En nel mismo edificio' 'numero 6' '8m²'
#  'Tiene trastero' 'Incluido en el precio' '2' 'Interior' '5 m²' '8.5m²'
#  'Trastero bastante amplio uno 35 m²' 'área: 40 mts2' 'Incluido'
#  'Si grande' 'Planta 6   nº 6' '11m²' '6x4 m²' '3 metros' '3' 'Metros²'
#  'En buhardilla' '9m²' 'Trastero de cuatro metros' 'Nº 13'
#  'Pequeño armario en la misma planta de la vivienda'
#  'Muy cerca del ascensor' 'Numero 4 en sotano -1' 'Nº12' '7 m²' 'Doble'
#  'De unos 7 m² aprox' 'Trastero abuhardillado' 'Superficie 8 m²' '5m' '20'
#  '6 m²' '4 m², gran altura' 'Si amplio junto a plaza de garaje'
#  'Bajo cubierta' 'Con trastero' '18 m² aprox.'
#  'Amplio trastero bajo cubierta' 'Si bajo cubierta'
#  'Uno bajo cubierta y el otro en el garaje' '1j' 'Bajocubierta 4a' 'dos'
#  'En sotano' 'En el sótano' 'Bajocubierta' '5-16' 'En planta sótano'
#  '2 trasteros' 'Junto a garaje' 'Comunitario' 'Bc de 7 m.' 'Con suelo'
#  'Bc' 'De 4 m². Con ventana.' 'Opcional' 'Amplio' '8 m²' 'Txoko'
#  'Trastero de 14 m²' 'Varios' 'Tiene trastero.' 'Arriba grande'
#  'Carbonera' 'Opcional desde 6.000€ a 9.000e' 'En el piso' 'Nº 15'
#  'Con acceso desde el baño' 'Caseta de aperos exterior' 'Desvan' 'Nº 35'
#  'Exterior cubierto' 'N 64' 'Trastero grande' 'Dos' '7m'
#  'En la propia terraza' 'Dentro del piso 8m' 'Desván arriba'
#  'Por escalera -1, 3-a' 'Dentro de la vivienda' 'Detras de las plazas'
#  'En planta baja con altillo' 'En el portal en el mismo edificio' 'Grande'
#  '3 despensas' 'Comunicado con el piso'
#  'En la 2ª planta, junto a la vivienda' 'Amplísimo' 'Al lado del piso'
#  '16' 'En terraza' 'De 5-6 metros en terraza'
#  'Numero 1 planta sotano primero' 'En parte superior' 'Letra.....e'
#  'Privado' 'Cuarto trastero en terraza' '8.5' 'En el solarium' '10'
#  'En la terraza comunitaria' 'Tiene 5 trasteros' 'En la terraza' '25'
#  'En la cubierta del edificio' '33' 'Nº 30' 'En segunda planta'
#  'Dentro de la vivienda un espacio' 'Si, junto ala cocina'
#  'Un enorme trastero junto al garaje'
#  'En la azotea hay un cuarto de trastero' 'T5' '100.00 m²'
#  'Lavadero azotea en cubierta' 'Trastero en garaje' '90m²' '3 trasteros'
#  'Adicional €15.000' 'Nº 38 8m²' '8.6 m² construidos' 'Solana'
#  'Si en la planta baja del edificio' 'Garaje' '60m'
#  '25m² anexo a la plaza de garaje' '1 trastero' 'Lavandería con trastero'
#  'Trastero 4.85m²' 'Al lado de la plaza de garaje' 'En el mismo edificio'
#  'Trastero junto a plaza de aparcamiento' 'Uno pequeño en lavadero.'
#  '11,21' 'En la azotea' 'Opcional 6.500 €' 'Son dos / 8m²' 'Nº 1 y nº 2'
#  'Opcional (9200 €) ref. 539'
#  'Pequeño en el patio y en rellano es hueco escalera'
#  'Trast. Nº 18 (11 m²), trast. Nº 19 (12 m²)' 'Muy amplio' '52m²' '5m²'
#  '3.45m²' '10m²' '30m²' '50m²' '15m²' '6m²' '130m²' '3m²' '17m²' '26m²'
#  '2m²' '18m²' '9.5m²' '16m²' '2.8m²' '7m²' '4m²' '7.96m²' '60m²' '72m²'
#  'En vivienda' 'En bajocubierta con velux'
#  '2 trasteros: en vivienda y bajo cubierta' '13 m'
#  'Si, solo de uso y disfrute' 'En el balcón' 'En planta bajo cubierta'
#  'Bajo cubierta nº 54' 'Si abajo' 'Accesible por ascensor' 'Despensa'
#  'Acceso del ascensor hasta el trastero'
#  'Sí en sótano del edificio con acceso directo' 'Toko' 'Independiente'
#  'En la vivienda, tipo despensa' '2 en la propia vivienda'
#  'Altura 2,17 mts. Junto al ascensor en la planta -1'
#  'Junto al garaje,  opcional' '10,50 metros'
#  'Opcional en el mismo edificio' 'Situado en las cercanías' 'Pequeño' 'No'
#  'Incluido en el precio de venta'
#  '2 trasteros, uno en planta baja y otro en terraza' 'En la vivienda'
#  'Uno incluido en precio y otro opcional' 'En terraza comunitaria'
#  'No incluido en el precio' 'En el patio de la cocina'
#  'Trastero en la planta de arriba' '2x3' 'Pequeña habitación en vivienda'
#  'Privado, en garaje' 'En el hueco de la escalera' 'Nº1' '32'
#  'Despensa en cocina' 'Nº21' 'Si con acceso desde la cocina' '59'
#  'En la entrada' 'Espacio en terraza cerrado a tal fin' 'En azotea'
#  'En el lavadero' 'Nº 29' 'Opcional junto con plaza de  garaje'
#  'En el garaje' 'En la galeria' 'Trastero en cubierta'
#  'Tiene un pequeño trastero en una parte de la terraza acristalada'
#  'En la misma planta que el piso' 'Nº9'
#  'En la zona baja de la casa además de una caseta exterior para guardar la leña'
#  'Muy grande' 'Trastero en planta de sótano' '4,78 mt2'
#  'Trastero incluido' 'Junto a las plazas de aparcamiento'
#  'Anexo a las dos plazas de aparcamiento' 'Varios cuartos'
#  '-en la misma finca' 'Guarda esquis' 'Altillo'
#  'Varias zonas del immueble habilitables al efecto' '22' '6' '15' '35'
#  'Terrado' '11' '13 m² + terraza' '9 m²' 'Dos trasteros'
#  'En el desvan asignado como n.º 2' '12 m²' 'Nº10' 'En la planta baja'
#  'Opcional, va amb el pàrking' 'Nº28'
#  'Hay una guardilla en el segundo piso' 'Nº48' 'Armarios empotrados'
#  'Buhardillaa - trastero' 'Altillo en garaje' '80m²'
#  'En zona comunitaria y otro privado en terrado' '6,30m² en buhardilla'
#  '4' 'Con posibilidades' 'Al safareig' 'Misma finca' 'En garaje'
#  'En el sotano' 'En el parking' '4,5' 'En planta baja' 'Num. 2'
#  'Cobertizo de montaña en el jardín' 'Terrado comunitario'
#  'Nº 48 y el parking nº 23' '5' 'Elevado y propio num²' 'Sotano'
#  '6 trasteros enjardín' 'Habitacion extra como trastero' '30 m²'
#  '100m²+10m²' '14m' 'Exteriores' '17 m²' '31.62m' '18m' '9m' 'Zona garaje'
#  '20m' '1.06m' 'Nº 8 -  en parking' '10m+12+60m' '13m+8m' '10m' '21m²'
#  'Nº 12' 'No incluido' '8m+15m' 'T03 o t02' '12m+12m' '23.65m'
#  'En las golfas' 'De 14m²' 'Se vende aparte por 1.000 euros'
#  '2 trasteros ubicados en la terraza' 'Trastero/lavadeo 10 m²'
#  '2 de 1,26 m², 1,30 m².'
#  'En la terraza comunitaria donde se tiende la ropa'
#  'Plaza de aparcamiento numero 13  trast nº 25'
#  'Privado con acceso al parking' '7 m²  dispone de 2' 'tipo buhardilla'
#  'Junto con parking' 'Con parking' '3 en terraza'
#  'En la misma plaza de pk' '18' 'Salida a solarium'
#  'En la terraza, bajo cubierta' 'Nº 6' 'Trastero en el garaje' '10 m²'
#  'De 24m² para almacenamiento adicional'
#  '24 m en planta sótano del edificio' '26 m²' '20 m²' 'Local'
#  'Pequeño trastero o despensa' '100' 'En terrado' '13' '6 m3'
#  'En una terraza' 'En una de las habitaciones y altillo' 'Trastero 4'
#  'En la misma terraza' 'Pequeño trastero debajo de la escalera'
#  '0 metros cuadrados' '7 metros cuadrados' '32 metros cuadrados'
#  'Bodega nº 108 - 1' 'Bodega' '16 metros cuadrados' '4 metros cuadrados'
#  '5 metros cuadrados' '9 metros cuadrados' '50 metros cuadrados'
#  '6 metros cuadrados' 'Trastero bajo cubierta y bodega en sotano -2'
#  '14 metros cuadrados' '60 metros cuadrados' '13 metros cuadrados'
#  '8 metros cuadrados' 'En sótano' 'Arriba' '18 en la -2'
#  '10 metros cuadrados' 'Nº 71' '3 metros cuadrados' '44 metros cuadrados'
#  'Nº 4 - 2' '100 metros cuadrados' '15 metros cuadrados'
#  '121 metros cuadrados' '20 metros cuadrados' '200 metros cuadrados'
#  '108 metros cuadrados' '23 metros cuadrados' 'Plaza número 96'
#  '1 metros cuadrados' 'Tres' '5.5 metros frente la pueta de entrada'
#  '18 metros cuadrados' '40 metros cuadrados' '12 metros cuadrados'
#  '104 metros cuadrados' 'Bodega pequeña' 'Garaje y trastero opcional'
#  '26 metros cuadrados' '4 planta' '+ bodega' '70 metros cuadrados'
#  '2 metros cuadrados' '25 metros cuadrados' '30 metros cuadrados'
#  '58 metros cuadrados' '57 metros cuadrados' '17 metros cuadrados'
#  '31 metros cuadrados' '11 metros cuadrados' '118 metros cuadrados'
#  '135 metros cuadrados' '35 metros cuadrados' '59 metros cuadrados'
#  '56 metros cuadrados' '80 metros cuadrados' '34 metros cuadrados'
#  'Trastero comunitario en portal' 'Amplio.'
#  'Trastero dentro de la vivienda' '39 metros cuadrados'
#  '33 metros cuadrados' '172 metros cuadrados' '6030 metros cuadrados'
#  '21 metros cuadrados' '78 metros cuadrados' '42 metros cuadrados'
#  '145 metros cuadrados' '7' '23' '14' 'Alrededor de toda la buhardilla'
#  'Caseta exterior' 'Si 1' 'Varias habitaciones a reformar' '15 m²'
#  'Dentro de la casa' 'Nº 16 sot 1' '3 ( detras de la plaza de garaje )'
#  '10 m² en planta baja' 'Armario en garaje' '2,5 m²' '50 m²' '2 naves'
#  '34 (detras plaza garaje)' '11 ( misma planta de la vivienda)'
#  '-1, unos 40 m²' 'Individual con terraza' 'Nº 5' 'Nº11' 'Dos.'
#  'Muy ámplio' 'De 25 m²' 'Se encuentra en el sótano.' 'Nº3' '14 metros'
#  'Nº6' 'En el patio' 'En la planta de arriba del edificio'
#  'Situado en la azotea' 'En la planta de arriba' 'En la planta del garaje'
#  'Nº7' '2.5m²' '3.31m²' '7.78m²' '12m²' '23m²' 'Grande 30m²' 'De 8 m²'
#  'Encima apartamento' 'Incluye un trastero en la venta' '6 m'
#  'Varios trasteros' 'Cuarto de lavandería' 'N.º 4-15 metros' '4000'
#  '10 metros' 'Nº 25 garaje nº25' 'Sotano nº 3 garaje nº 3'
#  'Bajo cubierta nº 4' 'bien equipado , buen acabado y puerta individual'
#  'Bajo cubierta nº 1ºa' 'Sot -1 4/04' 'Bajo cubierta nº 8' 'Cobertizo'
#  'Bajo cubierta desde el mismo piso' '1-a' 'Bajo cubierta (nº 6)'
#  'Carbonera en cubierta' 'Detrás de la plaza de garaje' '12 en cubierta'
#  'N-5' '13 en cubierta y otro dentro del piso' 'En sótano nº t22' '4 m².'
#  '6mt útiles' 'Tres trasteros' '8' 'Sí, 8 m²' '2x2'
#  '2 dentro de la vivienda' 'Dentro del piso'
#  'Arriba pta.bnº3 y 2º sotano nº 126' 'Despensa dentro del piso'
#  'Con armario empotrado' 'Nº 7 y garaje nº 5' 'Comun comunidad'
#  'Detras del garaje' 'Debajo del edificio' '17'
#  'Bajo la escalera y en patio' 'Available' '13m²' 'Desván/sótano'
#  'Almacén de 28m²' 'Portaesquis' '26' '62' 'En la cochera'
#  'Dispone de trastero' '19 metros cuadrados'
#  'Tiene un pequeño trastero de 2x2' 'Carbonera nº 4 en semisótano'
#  'Carbonera y trastero' '2º i en sótano' '37' 'Almacén de 27m²' 'Nº 2'
#  'Nº 34 en sótano 2' 'Patio' '5 metros' 'Nº 5 en sótano' 'Nº 8'
#  'Nº 15 en sótano 1' 'Nº 3' 'Nº 4' 'Antigua carbonera en semisótano'
#  'Nº 6 en planta 4ª' '84 metros cuadrados' 'Abajo' 'En la plaza'
#  'De 20 m² en el sótano.' 'Nº 3 de 12 m² en bajocubierta' '(sótano)'
#  'Nº 7' 'Arriba - 5º d' 'Sótano 3º' 'Nº 4 en sótano -2'
#  'Nº 9 en semisótano' 'En sótano 1' 'Nº 10' 'El primero en la azotea'
#  'Nº 24' 'Nº 3 en bajocubierta' 'Nº 4 en bajocubierta' 'Nº 6 abajo'
#  'Planta 3ª. (25 m²). Tiene agua y luz. Inseparable de la vivienda'
#  'En bajocubierta' 'Nº 4  en planta baja' 'De 4 m² en planta calle'
#  'Nº 6 en sótano' 'Nº 12 en sótano' 'Nº 8 en sótano 2' 'Nº 11' 'Almacén'
#  '2 (abajo y en bc)' 'Nº 12 en planta calle' 'Nº 20 en sótano 2'
#  'En sótano 1º' 'Nº 19 de 3,50 m² en sótano 1º' '13 m²'
#  'Nºs 2 y 7 en sótano -1' '4º a en sótano' 'Nº 12 en sótano -2'
#  'En bajocubierta y 2 carboneras en sótano']
#
# Valores únicos en la columna 'gastos_de_comunidad': [nan 'Entre 80 y 100 €' 'Entre 20 y 40 €' ... '15€' '87€' '200€']
#
# Valores únicos en la columna 'cocina_equipada': [nan 'Si' 'Amueblada' ... 'Office amueblada y equipada'
#  'Y equipada officce' 'Y equipada la del 2º']
#
# Valores únicos en la columna 'agua': [nan 'Si' 'Termo gas' 'Gas natural' 'Gasóleo' 'Termo electrico'
#  'Agua individual' 'Individual_gas' 'Si_sin_detallar'
#  'Agua caliente individual' 'Central' 'Individual_butano'
#  'Individual_electrica' 'Propano' 'Individual_gasoleo'
#  'Central_con_contador_individual' 'Toma_de_gas'
#  'Central con contador individual' 'Butano' 'Aerotermia' 'No_tiene'
#  'Individual_propano' 'Otros' 'Comunitaria' 'Minimos incluidos' 'Incluida'
#  'Caldera gas ind. Solo agua' 'Incl' 'Sin calefaccion' 'Gas ciudad'
#  'Placas solares' 'Termo eléctrico' 'Termo electrico y de gas'
#  'Caliente por termo eléctrico' 'Pozo y agua de badajoz'
#  'Individual_solar' 'Individual_calor_azul' 'Tiene suministro de agua.'
#  'Solar' '10 mil litros en cubas.' 'Available' 'De la población'
#  'Deposito 10.000l' 'Cisterna' 'Pozo h2'
#  'Calentador solar para agua caliente' 'Antical' 'Osmosis'
#  'Descalcificador' 'Deposito de agua 9000l' '2 depositos de agua'
#  'Osmosis, descalcificador'
#  'Agua caliente termo-acumulación lapesa de acero inoxidable.'
#  '2 depósitos recogida lluvia' 'Placas agua caliente'
#  'Agua caliente mediante aerotermia' 'La finca tiene 2 pozos de agua'
#  'Descalcificador/acumulador' 'Biomasa' 'Acs butano' 'Pozo y traída'
#  'Traída vecinal y pozo artesano' 'Traída. 40 euros /año'
#  'Agua traida vecinal, 25 euros/año.' '50 €/año' 'Pozo propio y traida'
#  'Pozo, y rio huecar' 'Pozo propio legalizado' 'Del pueblo'
#  'Contadores aparte' 'Pozo' 'Central con contador' 'Pozo compartido'
#  'De la traída y pozo para el riego']
#
# Valores únicos en la columna 'aire_acondicionado': [nan 'Si' 'Aerotermia' 'Frío y calor' 'Frío' 'Salon'
#  'En elsalón y el dormitorio' 'Aire acondicionado centralizado'
#  'Salón y dorm ppal' 'Canalizado en toda la casa' 'Suelo refrescante'
#  'A/a f/c' 'Splits en salón y habitación principal' 'Frío-calor'
#  'Con bomba de calor' 'Aire acondicionado'
#  'Aerotermia - suelo refrescante' 'Por conductos'
#  'Preinstalacion de aire acondicionado en toda la ca'
#  'Suelo radiante refrigerante' 'Preinstalación en toda la vivienda'
#  'En comedor y dormitorio'
#  'Dos aparatos de aire acondicionado de bajo consumo'
#  'En todos los dormitorios y en el comedor'
#  'De frio y calor en el comedor y en el dormitorio' 'A/a'
#  'Climatizador por conductos' 'Canalizado por conductos' 'Preinstalacion'
#  'En toda la casa' 'Individual' 'A/a f/c centralizado'
#  'Integral por toda la casa' 'Por conductos en todas las estancias'
#  'No dispone.' 'Por conductos independientes' 'Frío/calor centralizado'
#  'Geotermia y aerotermia' 'Climatizacion por conductos frio y calor'
#  'Frío/calor' 'frío y calor, por conductos'
#  'Suelo radiante y refrescante aerotermia' 'Split salon'
#  'Split salon y dormitorio principal' 'Preinstalación' 'Caldera'
#  'De ventana' 'Suelo radiante' 'Sin especificar'
#  'Aire acondicionado frío/calor' 'Preinstalación por conductos'
#  'Aire acondicionado split' 'Pre installation'
#  'Preinstalacion frio y calor'
#  'Instalación completa mediante conductos de fujitsu' 'Hot cold'
#  'Pre-instalación por conductos' 'Centralizado' 'Instalación'
#  'Pre-instalación' 'Yes' 'Preinstalacion aire acondicionado'
#  'Instalado por conductos' 'A/c salón' 'Preinstalacion hecha'
#  'Pre instalacion' 'Pre instalación hecha' 'Bomba de calor' 'Central'
#  'Un split' 'Split' 'Split frio y calor' '2 splits' 'No' 'Splits'
#  'Bomba frio-calor' '1 split b.f/c salon' '3 split b.f/c' 'Split f/c'
#  'Varios split f/c' '2 split f/c'
#  'Suelo radiante y refrigerante por aerotermia' '2 splits f/c'
#  '4 splits f/c' 'Split f/c y preinstalacion bomba'
#  'Split b.f/c en habit princ y salon' 'Bomba f/c (preinstalación)'
#  'Bomba frio/calor y ventiladores de techo en todas' 'B.f/c' '3 split'
#  'Bomba frío/calor en planta baja y primera planta'
#  'Split en salón y dormitorio principal' 'Preinstalación de bomba'
#  '1 split en el salón' 'Bomba f/c' 'Bomba frio/calor en ambas plantas'
#  '1 split f/c' '2 bombas frío/calor' '2 split' 'Prehistalacion'
#  'Prehistalación' 'Por conducto' 'Un  split en salón'
#  'Split salon , salita dormitorio'
#  '2 splits con bomba de calor en salon y dormitorio principal'
#  'Split en el salon'
#  '1 en el salon + preistalacion de aiire por conductos sin maquina'
#  'Por conductos con bomba de calor'
#  'Centralizado frio calor por todas las estancias'
#  'Dos splits uno en salon y otro en dormitorio'
#  '3 split uno en el salon y dos en dos dormitorios' 'Salon frio calor'
#  'Spli' 'X conductos  tambien tiene splits'
#  '1 split en el salon con bomba de calor' 'En salon' 'Un split en salon'
#  'En toda la vivienda' 'Split en salon' '7 solitario f/c'
#  '1 split en salon' '1 aire frio' 'Aire con maquina por rejillas'
#  'Split en el salón' 'Preinstalación conductos' 'Salon split'
#  'Por conductos calor y frío' 'Un split salón frío y calor'
#  'Bomba de calor y frío' 'Split en cada habitación'
#  'Split en todas las estancias' 'Split frio calor en todas las estancias'
#  'Split en salon y habitaciones' '1 split frio en el salón' 'Conducatos'
#  'Split ,salon,cocina,dormitorisos'
#  'Por conductos, más un split de calor y frío' 'Split (3)'
#  '1 split bomba calor y frío' 'Split y ventiladores'
#  '2 split en salon y hb pral' '4 split'
#  '3 split calor y frío en el salón, garaje y un dormitorio'
#  '1 split calor y frío' '2 split en los dos salones'
#  'Por conducto planta de abajo' '3 splits calor y frío'
#  'Instalación hecha' 'Split calor y frío salón, cocina y dormitorio'
#  'Preinstalacion de a/a' 'Comunitario'
#  'Suelo radiante refrescante por aerotermia'
#  'Suelo refrigerante mediante aerotermia daikin' 'Individual a/c units'
#  'Centralised' 'Calefacción' 'Duct based' 'Por conductos y'
#  'En el comedor' '2 aparatos' 'En cocina' 'En 1 habitacion'
#  'Canalizada f/c' 'Preinstalación aire acondicionado'
#  'Split frio calor en el salon' 'Por conductos frio y calor'
#  'Split frio calor en el salón'
#  'Preinstalacion de aire acondicionado por conductos'
#  'Aire acondicionado frio calor por conductos' 'A/a f/c por conductos'
#  'Splits frio/calor' 'Split en el comedor' 'Split en salón' 'Sin maquina'
#  'Aire acondicionado por conductos'
#  'Split frio calor en salón y dormitorio principal' 'Splits, 3'
#  'Split frio calor en salon y dormitorio'
#  'Dos maquinas de aire acondicionado por conductos f'
#  'Split frio calor en dos salones y dormitorio princ'
#  'Split frio calor en un dormitorio y salón'
#  'Split frio calor en el salón y el dormitorio princ'
#  'Split pasillo primera planta' 'Split frio calor en los dos salones'
#  'Aire acondicionado por conductos frio calor'
#  'Por conductos, bomba de calor' 'En el salón y dormitorio'
#  'Not available' 'Pre - instalación' 'Parcial' 'Bomba de calor  daikin'
#  'Por conductos regulable en cada instancia' 'Bomba de calor daikin'
#  'Underfloor cooling system, individual a/c units'
#  'Underfloor cooling system'
#  'Ceiling cooling system, individual a/c units' 'Splits y unidades'
#  'Conductos' '4 splits' 'Frio-calor' 'Ceiling cooling system'
#  'Bomba frio y calor' 'Climatizador' 'Chimenea' 'A/a incluido¡¡¡'
#  'A/a incluido' 'Pre instalación a/a'
#  'Preinstalación de aire acondicionado'
#  'Preinstalación de aire acondicionado por conducto'
#  'Aire acondicionado preinstalado' 'Preintalacion de aire acondicionado'
#  'Preinstalación por conducto' 'Preinstalación de a/c por conducto'
#  'Preinstalado' 'Preinstalacion aire' 'Suelo radiante y aerotermia'
#  'Aire por conductos' 'Por conductos y split'
#  'Individual con bomba de calor' 'Ventiladores de techo'
#  'Ventilador de techo' 'Aire acondicionado frío' 'Ascensor'
#  'Conductes tres zones' '2 splits, comedor y recibidor'
#  'Por conductos, frio y calor' 'Preintalacio a/a'
#  'Frio y calor por conductos'
#  'Bomba de calor en dormitorio principal 1ª planta'
#  'Bomba de calor por aerotermia' 'Aerotérmia'
#  'Pre instalación aire acondicionado frío y calor' 'Aerotèrmia'
#  'Bomba de calor en comedor' 'Bomba por conductos con aerotermia'
#  'En distribuidor' 'Salon i buhardilla' 'Preinstaación'
#  'Aerotermia frio y calor' '2 splits en salon y habitacion' '1split'
#  'Todo eléctrico' 'Bomba frio y calor, 2 splits' 'Comedor' 'Aerotérmica'
#  'Conducto' '2 aparatos con bomba de calor'
#  'Salon y todas las habitaciones'
#  'Frío y calor mediante suelo radiante - aerotermia' 'Comedor/2dd'
#  'No terminado' 'Aerotermia por conductos'
#  'Frio y calor en pasillo y salón. Frio en hab. Ind' 'Pre-instalacion'
#  'Inverter' '2 máquinas' 'Aacc frio calor comedor' 'Aire por conducto'
#  'Climatización por conductos' 'Frio y calor por canductos' 'Calor'
#  '2 habitaciones y salón' 'Frio en el salon' 'Preinstación'
#  'Suelo refrescante por sistema de aerotermia indiv'
#  'Aire acondicionado en salón y dormitorio principal' 'Toda la vivienda'
#  '3 aparatos' 'En el salon' '1 en el salon' '7 aparatos'
#  'Preinstalacion de aire'
#  'En el salón de la entrada, y en dos habit. Una que da  a la zona de los tejados de san justo y el otro esta en el dormit ppal del fondo que era el de los padres'
#  'En algunos despachos' '2 frío en salón y dorm ppal'
#  'Bodega con sala de juegos' 'Pellet']
#
# Valores únicos en la columna 'terraza': [nan 'Si' 'En cocina de cerrada en aluminio y cristal' ...
#  'En salón y patio terraza en cocina' '1 de 18 m² en un dormitorio'
#  'Abierta en dormitorio, galería en salón y 2 más']
#
# Valores únicos en la columna 'armarios_empotrados': ['1' 'Si' nan 'Más de 2' '2' '4 armarios' 'Dormitorios'
#  '5 armarios empotrados' '2 a/e' '3 vestidos' 'No' '3 a/e'
#  'Sin especificar' 'En todas las habitaciones' 'Empotrados'
#  'Armarios empotrados y forrados'
#  'En todos los dormitorios y en el pasillo' 'En todos los dormitorios'
#  '5 empotrados + vestidor' '5 empotrados grandes' '2 empotrados'
#  '4 empotrados' '6 armarios empotrados'
#  'Todos los dormitorios, ademas de vestidores.' '3 y revestidos'
#  '4 armarios empotrados.' 'Armarios de madera' 'Tiene armario empotrado.'
#  'Varios empotrados' 'En cada dormitorio' 'Más de 10'
#  'Despensa y empotrados' '3 empotrados'
#  'Los armarios vienen vestidos por dentro' '3 armarios empotrados'
#  '1 armarios empotrados' '2 armarios empotrados' 'Armarios normales'
#  'Vestidores' '4 armarios empotrados'
#  'En todas las habitaciones y forrados' 'En dos dormitorios'
#  '2 mas vestuario' '3 vestidores' 'Vestidor' 'Cuatro' 'Cinco'
#  'Empotrados dos' 'Tres armarios' '1 altillo'
#  'Armarios empotrados en todas las habitaciones' '1 grande'
#  'Vestidor hab prin 1 baño 2 hab' '4 (uno x habitacion) y zapatero'
#  '3 empotrados y vestidos' 'Empotrados uno en dormitorio principal'
#  '4 empotrados y vestidos' 'Empotrados de cerezo' '7 armarios empotrados'
#  '2 hechos a medida' '1 empotrado' '4 empotrados y un vestidor'
#  '10 empotrados' 'Todas habitaciones y pasillo' '2 vestidores'
#  'En los dormitorios y el distribuidor' 'Vestidor en dormitorio principal'
#  '4 armarios, tienen todos los dormitorios' 'Amplios' 'Tres'
#  '1 armario empotrado y vestidor' 'En todos dormitorios'
#  'En ahbitacion y pasillo' 'Roperos revestidos' 'En los dormitorios'
#  '3 armarios amplios revestidos' 'Todos los dormitorios'
#  'Todas las habitaciones tienen su armario empotrado' '5 empotrados'
#  'Forrados de madera' 'Vestidores en todas las habitaciones suite'
#  '1 en distribuidor y 1 en suite' 'En dormitorio matrimonio' 'Amueblado'
#  'Vestidor de 4 m².' 'Pueden hcerse 4 ud' 'Empotrados en hab'
# ...
#  'En galería de 2,28 m².' 'Con sala de caldera'
#  'Coina principal y trastero hay 2' 'En baño exterior' '2 m².'
#  'Patio interior' 'Cocina' '3,55 m².' 'Amplio y con armario empotrado'
#  '5,40 m²,' '8m²' '1.28m²' '1.44m²' '1.71m²' '1.45m²' '1.37m²' '2.34m²'
#  '21m² y 25m²' 'De 12 m²' '2.08m²' '1.29m²' '0,60m²' '0.56m²' '2.12m²'
#  '1.93m²' '4 m² cerrado' '7,5m' '5m' '5.7m' 'Empotrado' 'En cocina 3 m.'
#  '18 ext' '3 interior' '4 int' 'En cocina-comedor en a/e.' 'De 4 m²'
#  'Independiente de 4 m²' 'Incorporado en la cocina' 'De 3m²' 'De 3 m²'
#  'De 10 m² independiente' 'Independiente 4 m²' 'De 8 m²'
#  'De 5 m² exterior' 'Integrado' 'De 3m² en la terraza' 'En el baño'
#  '2 metros' 'Muy amplio' '6,04 m²' 'En el patio interior' '13.67 m'
#  '2 m. En balcon parte atras' 'Salida desde la cocina'
#  'Incorporado a la cocina' '3,15 m²' '6m tipo patio' '1,26m'
#  'Lavadero independiente exterior y galería' '20 m. En parte de arriba'
#  'Independiente y exterior.' 'Junto a cocina, independiente y exterior.'
#  'Dos lavaderos independientes' '3 ext'
#  'Independiente, también para almacenaje' 'En semisótano'
#  'En sotano  4 m.' '6 ext' 'Anexo a cocina' '4 mts.' 'Exterior de 3 m²'
#  'Lavadero exterior' 'Dado a cocina' 'Habitación grande con lavadero'
#  'De 6 m²' 'Incluido en el baño' 'Caldera' 'Integrado en cocina'
#  'Dins armari' 'Arriba' 'Patio 5m²' '6m²' 'Instalación hecha'
#  'Con entrada desde la cocina' 'Zona de lavadero de 3 m²' '4,2m²'
#  'Galeria 2,02 int.' '4m' '3,48' '7,13m²' 'Salida por cocina' '12m²'
#  '3.05m²' 'Independiente al lado de la cocina' 'Integrado en baño' '4 ext'
#  '2 m.' 'Integrado en armario' '5m² y también hay 1 ducha'
#  'Al lado del parking' 'En baño' '3m'
#  'Acceso desde una de las habitaciones' 'Lavadero con trastero'
#  'Añadido a la cocina' 'Junto la cocina' 'Arriba en el terrado' '12 m²'
#  'En patio muy grande y comodo' '14m' 'Obra nueva'
#  'Lavadero para tender y lavanderia' 'Con patio' 'Interior tipo galeria'
#  'Independiente a la cocina'
#  'Integrado en armario con lavadora y secadora' '18 m²'
#  'Con lavadora y pilón' 'En semisotano' 'En salón posterior/ terraza'
#  'Varios' 'Lavandería' 'Zona exterior' 'Planta baja' 'Lavadero'
#  'Exterior y con pozo' 'Cuarto para lavadora' 'Amplia zona de lavandería'
#  'En bajo' 'Sala de coladuria' 'Lavadora y secadora' 'Lavadora'
#  'Anexo a la cocina y con pileta' 'Si en patio' 'Habitacion de planchar'
#  'Lavadero despensero' 'Amplio y abierto'
#  'Amplio lavadero en terraza exterior' 'Si dispone' 'Galeria cubierta'
#  'Muy ámplio' 'Lavadero acristalado.' 'Con bastante capacidad' 'Reformado'
#  'Espacioso' 'Con toma de agua para lavadora'
#  'Galería cerrada instalación lavadora' 'Galería en la cocina' '45m²'
#  'Si cocina' 'Zona de lavado independiente' 'Con cuarto de lencería'
#  'Agua próxima de manantial' 'Cuarto de lavado y plancha' 'Común'
#  'Espacio para lavandería' 'Cuarto de lavandería totalmente equipado'
#  'Zona de lavado, en la planta inferior' 'En la planta baja'
#  'En 2ª planta']
#
# Valores únicos en la columna 'amueblado': [nan 'Si' 'Cocina y despensa' 'Completamente amueblado' 'No'
#  'Semi amueblado' 'Cocina amueblada'
#  'Se puede quedar prácticamente amueblado' 'Algunos' 'Cocona'
#  'Solo la cocina' 'Totalmente amueblado' 'Semi amueblada' 'Cocina'
#  'Amueblado' 'Completamente' 'Vacío' 'Amueblado con cocina equipada'
#  'Si, con muebles de diseño' 'Si con muebles de diseño'
#  'Diseño contemporáneo'
#  '+25.000€ (no incluído en precio aunque lo marque como amueblado)'
#  'Todos los apartamentos se encuentran amueblados' 'Totalmente equipado'
#  'Todo el piso esta amueblado.' 'Opcional' 'Se vende amueblado'
#  'También vacío' 'O sin mueble' 'Semi-amueblado'
#  'Si con muebles de calidad' 'Si completo' 'Completo'
#  'Se quedan los muebles' 'Si  completo' 'Si completo muebles de calidad'
#  'Si amueblado' 'Semiamueblado' 'Opcional a negociar' 'Inventario' 'L'
#  'Parcialmente amueblado' 'Esta amueblado.' 'Castaño' 'Como está' 'Opc'
#  'Recién amueblado y reformado' 'Parcial' 'Como quieran'
#  'Excepto sillas, mesa y aparador de cocina' 'Todo' 'Muebles  historicos'
#  'Con todo' 'Semi' 'Con todo lo existente'
#  'Dos empotrados completamente revestidos' 'Excepto algunas cosas' 'Algo'
#  'Se vende semiamueblada.' 'Completamente amueblado moderno'
#  'Muebles no en el precio' 'Se vende semiamuelado' 'A convenir'
#  'Todo el mobiliario incluidos' 'Algunos muebles' 'A consultar'
#  'Amueblada' 'Se quedan algunos' 'Totalmente amueblada'
#  'Se vende amueblado y con electrodomésticos' '2' '3' '4' '5'
#  'Partly furnished' 'Completamente amueblada'
#  'Menos el salon y un dormitorio' 'Semiamueblada' 'Solo cocina' 'semi'
#  'Con muebles' 'Total' 'Semi-amueblada' 'Solo deja una mesa y las sillas'
#  'Se vende amueblado, excepto sin sofa y cosas perso' 'Parcialmente'
#  'Completamente amueblado, listo para entrar' 'Muebles de diseño'
#  'Cierta cosas no incluida' 'Muebles de alta calidad' 'Equipado'
#  'Preparado para entrar a vivir' 'Todos nuevos' 'Clasico' 'Y equipado'
#  'En venta amueblado tal como aparece en las fotos' 'Semi - amueblado'
#  'Totalmente amueblado y equipado' 'Muebles nuevo9s y de calidad'
#  'Cocina + baños' 'Excepto sofa, sillas x 2 y modelo de barco con cuadro'
#  'Amueblado totalmente, con muebles de calidad.'
#  'Los muebles son propiedad de la arrendataria'
#  'Excepto cosas personales y 2 vitrinas' 'Totalmente'
#  'Salvo efectos personales.' 'Completamente salvo efectos personales'
#  'Todo amueblado' 'Deja algun mueble' 'Se vende amueblada'
#  'Se puede negociar' 'Como se ve en las fotografías'
#  'Con muebles cuenta 45.000€' 'Equipada' 'Armarios empotrados'
#  'No amueblado' 'Totalmente amueblado: restaurante y casa.'
#  'Tal como se ve en las fotos' 'Y electrodomesticos'
#  'Hay camas y cocina equipada' 'A excepción de los objetos personales'
#  'Optional furniture' 'Equipado completamente' 'Fully furnished'
#  'Como aparece en las fotos y en video' 'Completa'
#  'Se quedan algunos muebles' 'Todo el piso amueblado'
#  'Se hablaría fuera del precio' 'Se vende sin amueblar'
#  'Modernos seminuevos' 'Amueblado y equipado'
#  'Semiamueblado, cocina equipada' 'Excepto colchón habitación principal'
#  'Salón , comedor y habitaciones' 'Todos los muebles' 'Semi amueblado.'
#  'Menos efectos personales' 'Negociable' 'Según inventario'
#  'Según inventario - menos efectos personales' 'Totalmente equipado.'
#  'Fully furnished, optional furniture' 'Excepto objetos personales'
#  'Dejaran varios muebles' 'Toda la vivienda' 'Muebles para renovar'
#  'Available' 'Muebles antiguos' 'Totalmente acondicionada' 'Opcionbal'
#  'Negociar' 'No en su totalidad' 'Tal cual' 'Muebles y electrodomésticos'
#  'No completamente' 'Tal cual está' 'Con muebles y electrodomesticos'
#  'Alta calidad i mazizos' 'No esta del todo amueblado'
#  'Si el comprador lo desea sin muebles no hay problema'
#  'De primera calidad' 'Incluido' 'Excepto mesa comedor y sillas'
#  'Con opción de negociar' 'A negociar' 'Y con electrodomésticos' 'Opcinal'
#  'Casi todo' 'Algunos a acordar' 'Incluidos' 'Dejan todo'
#  'Posibilidad de muebles' 'Con electrodomésticos' '+electrodomésticos'
#  'Parcialmente, armarios empotrados.'
#  'Totalmente equipado como se muestra en las fotos'
#  'Amueblado con electrodomésticos en garantía' 'Muebles a medida'
#  'Totalmente amueblado.' 'Retira objetos personales' 'Si.' 'Si,'
#  'Sin mubles, (se negoción)' 'Lista para entrar a vivir' '7' '6' '10'
#  'Cocina posibilidad amueblado entero' 'Como oficina'
#  'Se deja totalmente amueblado' 'Cocina y baños'
#  'Cocina con electrodomésticos' 'Cocina completamente equipada'
#  'Cocina equipada y varios muebles'
#  'Totalmente amueblado para entrar a vivir' 'Muebles de calidad alta'
#  'Por 190.000 euros, opcion amueblado total' 'Armarios' 'Consultar'
#  'La mayoría' 'De la cocina'
#  'Se queda con prácticamente todos los muebles.'
#  'Se podrían quedar los muebles, opcional'
#  'Se podrían quedar casi todos los muebles'
#  'Se vende sin muebles, si no se acuerda otra cosa'
#  'Todo el piso está amueblado' 'Opcionales'
#  'Puede ser amueblado o sin amueblar' 'amueblado'
#  'Cocina, despensa, baños y algún dormitorio'
#  'Totalmente amueblada y equipada' 'Salon y cocina'
#  'Se vende solo con cocina amueblada' 'Totalmente amueblado y decorado'
#  'Calidad del mobiliario nivel medio bajo'
#  'Solo faltan los muebles auxiliares' 'Se dejan todos los muebles'
#  'Cocina equipada' 'Amueblada la planta baja' 'Parte' 'Excepto el salón'
#  'A elección.' 'Amueblado a negociar' 'Completa como sale en las fotos'
#  'Como nuevo, sin apenas uso' 'Esta totalmente amubelado'
#  'Amueblada como sale en las fotos' 'Se vende completamente amueblado'
#  'El piso se entrega amueblado' 'Semi amibelado' 'Excepto algunos'
#  'De maderas nobles']
#
# Valores únicos en la columna 'gas': [nan 'Natural' 'Tiene enganche de gas natural' 'Si' 'Gas natural'
#  'Individual' 'G/n' 'Gas natural: calefacción y agua caliente sanitaria'
#  'Otra compañía' 'Butano cocina' 'Natural canalizado' 'Gsdoil' 'Propano'
#  'Gas natural para agua caliente' 'Acs' 'Toma para instalación individual'
#  'Aerotermia' 'Calefacción individual' 'Toma gas natural exterior'
#  'Caldera nueva' 'Toma de gas ventana' 'Ciudad' 'Butano' 'Sin gas'
#  'Ciudad, serv individuales' 'Ciuda' 'Agua caliente' 'Gasoil' 'Eléctrico'
#  'Cocina y placa de gas' 'Instalacion de gas y electicidad'
#  'Cocinillas de gas.' 'Gas butano' 'Calentador'
#  'Preinstalación gas ciudad' 'Calentador con gas ciudad' 'Natual'
#  'Termo eléctrico' 'Central con contadores individualizados'
#  'En el edificio.' 'Gas hasta la ventana' 'En fachada' 'Ciudad.'
#  'Individual.' 'Si (individual)' 'Agua caliente y calefacción'
#  'Gas ciudad' 'Caldera' 'En la ventana' 'Hay instalación de gas'
#  'Propano 4 + 4' 'Bombona' 'Cuidad' 'Agua caliente por gas'
#  'Caldera individual' 'Toma disponible' 'Central con contadores'
#  'Toma de gas' 'Sin especificar' 'Gas propano' 'Gas natural.'
#  'Gas butano en cocina.' 'En urb' 'En urbanización' 'En urbanizacion'
#  'Natural en urb' 'Natural en urbanización' 'Con posibilidad de ponerlo'
#  'Propano en urb' 'Oil' 'Calefaccion' 'Nat' 'Para cocinar'
#  'Gas natural en urbanización' 'Dar de alta' 'No' 'Opcional'
#  'Calefacción y agua sanitaria' 'Para calefacción y agua sanitarios'
#  'Para calefacción y agua sanitaria' 'Radiadores' 'Calefacción'
#  'En la cocina semisubterráneo' 'Preinstalacion hasta parcela' 'Central'
#  'Natura' 'En el segundo piso' 'Gas natural con contador individual'
#  'Acometida' 'Gasoil 1.500 litros' 'Gas natural individual'
#  'Posibilidad de poner gas natural' 'No hay' 'Gas natural, calefacción'
#  'Instalacion' 'Acometida de gas en el patio' 'Caldera de condensación'
#  'Gasoleo' 'Iberdrola' 'Deposito gasoil' 'Caldera de gas' 'Si gas natural'
#  'Canalizado' 'En el edificio' 'Propano y butano'
#  'Gas individual y estufa de pellts en el salon'
#  'Caldero individual gas natural']
#
# Valores únicos en la columna 'comedor': [nan 'Si' 'Salón comedor con balcon' ... '24,19 m²'
#  'Amplio con comedor y acceso a una gran terraza con'
#  'Salón cocina americana']
#
# Valores únicos en la columna 'chimenea': [nan 'Si' 'En el salón.' 'Decorativa' 'Salón'
#  'Con remate de piedra berroqueña.' '2' 'Salon, buahardilla'
#  'En planta principal y en superior' 'Funcional' 'Con casette' 'Cassette'
#  'Dos chimeneas francesas. Una en cada salón' 'De gas' 'Hierro fundido'
#  'Cassette insert' 'Abierta' 'En la cocina' 'Casette' 'En el salón'
#  '2 de leña' 'Cocina y dormitorio' 'Dispone de tiro y preinstalación.'
#  'Nueva' 'En salon' 'De leña en cocina' 'Condenadas' 'Gas natural'
#  'Casete' 'Preinstalación' 'Conducto' 'Artificial' '2 chimeneas'
#  'En el txoko' 'Salon' 'En salón' 'Si en el salón' 'Si en el merendero'
#  '3 chimeneas' 'pre-instalación' 'En txoko de planta baja'
#  'Salida en planta baja' 'En la bodega' 'Merendero' 'Pellet'
#  'Dos, en el salon y en el txoko' 'Cuenta con la instalación' 'No'
#  'Estufa jotul' '2 chimeneas una en salón y orea en suite' 'Leña'
#  'En el salon' 'En choco y salón' 'De cristal' 'En zona de estar'
#  'Estufa leña' 'Tres' 'Dos' 'Dos una en cada salón' 'Terraza'
#  'En planta alta' 'En cocina' 'En salón y cocina' 'Estufa de leña'
#  'Tiene chimenea' 'En segundo salón' 'No posee'
#  'Chiminea salida de gases en cocina'
#  'Posibilidad de instalarla. Preparado todo.'
#  'Barbacoa exterior en terraza de arboles frutales' 'Eléctrica'
#  'Con aire canalizado' '3' '2 una por planta'
#  '2 una en salon y otra en nave' 'Caset' 'Varias chimeneas' 'De pellets'
#  'Dispone' 'Pellets' 'Salón comedor' 'Estufa' '4' 'En el restaurante'
#  'Log burner' 'Salón comedor.' 'De leña' 'En comedor' 'En el comedor'
#  'En comedor con turbinas' 'En la planta baja' 'Electrica'
#  'En cada planta' 'Estufa de leña en la cocina' 'Tiro exterior homologado'
#  '2 chimeneas, cocina y salon' 'En el sotano' 'Estufa de pellet'
#  '1 de leña y 1 de pellet' '2 estufas de leña' 'Estufa de leña con horno'
#  '2 chimineas una en el salon y otra en la barbacoa'
#  'En salón y dos dormitorios' 'De pelets' 'Salon - comedor' 'Available'
#  'Chimenea en el comedor'
#  '-amplia bodega con chimenea en planta calle y en el salón' 'Central'
#  'Barbacoa' 'Posibilidad' 'En la segunda planta'
#  'Preinstalación de chimenea' 'Dos, sala y cocina'
#  'Dos en la masía más estufa de pellets en casa invi' 'Estufas de pellets'
#  '2: menjador i garatge' 'Opcional' 'Pared de piedra'
#  'Gran chimenea en la cocina' 'Varias' 'A l´altell' 'Cocina' 'Tiro hecho'
#  'Hueco comedor' 'Salon comedor y suitte' 'Salon comedor'
#  'En el salón de la planta baja' 'Para montar' 'Posibilidad de poner'
#  'Cerrada' 'En el porche' 'En el gran comedor' 'En salon comedor'
#  'Tiro de salida de humos preparado' 'Interior y exterior' 'En el estudio'
#  'Hab 10m²' 'Una en cada salón' 'Comedor' '2 en comedores'
#  'Estufa de leña en la sala de estar' 'En salón y  sala polivalente'
#  'En comedor y habitación superior' 'En salones' 'Cocina salón y bodega'
#  'Chimenea jotul' 'Chimenea en salón y barbacoa' 'Instalaran gas'
#  'Preinstalacion' 'Al menjador' 'Dos, en el comedor y en la cocina'
#  'Pre-instalación' 'En salón estar' 'Una en salón, otra en cocina'
#  'Tipo estufa' 'Tiro con posibilidad de poner'
#  'Comedor y dormitorio de matrimonio' '5' 'En salón-comedor'
#  'En salón comedor' 'Metano+leña' 'Comedor /bodega' 'Gas'
#  'Instalación hecha' '...' 'Si, en el salón'
#  'De estilo moderno, integrado con cassete' 'Primera planta'
#  'En estudio 16 ext.' 'Estudio' 'Estudio y comedor de abajo'
#  'Chimenea en el salón' 'Muy decorativa' 'En salón comedor 35 m²'
#  'En el comedor y  habitación en tercera planta' 'en el comedor'
#  'En slaon' 'Zona barbacoa' 'En comedor-salón'
#  'En funcionamiento y situada en el salón-comedor' 'En el salón-comedor'
#  'En dormitorio principal' '2 caloríficas' 'Dos una en salon' 'Lavadero'
#  'Con lareira y horno de leña' 'De argon' 'Francesa de marmol'
#  'Estufa de pelet' 'Con insert' 'Deposito 1500 litros' 'A pellet' 'Bodega'
#  'Con cassete' 'Leña cassete turbina y mando' 'Acristalada'
#  'Opción de barbacoa en terraza' 'Si dispone de cocinilla'
#  'Estufa de pellets' 'Muy buena' 'Muy buena,' 'Barbacoa y chimenea'
#  'Cocina con chimena' 'En un salon aparte' 'En un segundo salón'
#  'Semisotano' 'False' 'Dos chimeneas, una en plata baja y otra en salón'
#  'En el local' '2 barbacoas' 'En zona bodega-comedor' 'En bodega'
#  'Con calefaccion' 'Chimenea en salon, de leña' 'Con estufa leña'
#  'Salon con casete' 'Propano' 'Salon mas horno y chimenea merendero'
#  'Con horno de asar' 'En salon grande' 'En el merendero'
#  'En salón y merendero' 'Cocina ganadera pasiega' 'De leña en el salon'
#  'Una en salön y otra  en cocina' 'En el salón con cassette y bodega'
#  'Dorm, salón y comedor' 'Salón y bodega' 'En salon y despacho'
#  'Chimenea funcionando' 'El bar tiene chimenea' 'En el salón de arriba'
#  'De leña conectada a radiadores' '2 salón y bodega']
#
# Valores únicos en la columna 'no_se_aceptan_mascotas': [nan 'Si']
#
# Valores únicos en la columna 'telefono': [nan 'Tomas' 'Si' 'Internet' 'Fibra óptica' 'Fibra optica' 'Fibra'
#  'Edificio' 'Instalacion' 'Available' 'Wifi'
#  'Conexión fibra, satélite, teléfono y otros' 'Linea de telefono y fibra'
#  'Cableado' 'Preinstalación'
#  'Instalación conexión wifi en todas las plantas' 'Fijo+internet' 'Alta'
#  'Instal.lacio' 'Fibra opotica' 'Videoportero']

# %%
# Vamos a aplicar una logica común ya que este dato en la página da tres posibilidades:
# Escribir la caracteristica concreta o especificar que si, lo hemos reducido a "Si" por simplificar
# Escribir que no, implica confirmación de que no se da esa caracteristica en dicho inmueble por lo que la tratamos como "No"
# La tercera opción es que devolviera la clave valor vacía, lo que significa que no se especifica, de esta forma no nos inventamos información
def limpiar_columnas_si_no(valor, valores_unicos):
    if pd.isna(valor) or valor.strip() == "":
        return "Sin especificar"
    if valor == "Sin especificar":
        return valor
    elif "no" in valor.lower().split():
        return "No"
    else:
        return "Si"

# Iterar sobre cada columna conflictiva y limpiar los valores
for col in columnas_si_no:
    valores_unicos = df[col].dropna().unique()
    df[col] = df[col].apply(lambda x: limpiar_columnas_si_no(x, valores_unicos))

# %%
# Crear un diccionario para almacenar los valores únicos de cada columna
valores_unicos = {}

# Iterar sobre cada columna conflictiva y obtener los valores únicos
for col in columnas_si_no:
    valores_unicos[col] = df[col].unique()

# Mostrar los valores únicos de cada columna
for col, valores in valores_unicos.items():
    print(f"Valores únicos en la columna '{col}': {valores}\n")
# Out:
# Valores únicos en la columna 'luz': ['Sin especificar' 'Si']
#
# Valores únicos en la columna 'sistema_de_seguridad': ['Sin especificar' 'Si']
#
# Valores únicos en la columna 'vidrios_dobles': ['Sin especificar' 'Si' 'No']
#
# Valores únicos en la columna 'se_aceptan_mascotas': ['Sin especificar' 'Si']
#
# Valores únicos en la columna 'calefaccion': ['Si' 'Sin especificar' 'No']
#
# Valores únicos en la columna 'jardin': ['Si' 'Sin especificar']
#
# Valores únicos en la columna 'trastero': ['Sin especificar' 'Si' 'No']
#
# Valores únicos en la columna 'gastos_de_comunidad': ['Sin especificar' 'Si' 'No']
#
# Valores únicos en la columna 'cocina_equipada': ['Sin especificar' 'Si' 'No']
#
# Valores únicos en la columna 'agua': ['Sin especificar' 'Si']
#
# Valores únicos en la columna 'aire_acondicionado': ['Sin especificar' 'Si' 'No']
#
# Valores únicos en la columna 'terraza': ['Sin especificar' 'Si' 'No']
#
# Valores únicos en la columna 'armarios_empotrados': ['Si' 'Sin especificar' 'No']
#
# Valores únicos en la columna 'balcon': ['Sin especificar' 'Si']
#
# Valores únicos en la columna 'garaje': ['Sin especificar' 'Si' 'No']
#
# Valores únicos en la columna 'puerta_blindada': ['Si' 'Sin especificar' 'No']
#
# Valores únicos en la columna 'adaptado_a_personas_con_movilidad_reducida': ['Sin especificar' 'Si']
#
# Valores únicos en la columna 'ascensor': ['Sin especificar' 'Si' 'No']
#
# Valores únicos en la columna 'alcantarillado': ['Sin especificar' 'Si']
#
# Valores únicos en la columna 'portero_automatico': ['Sin especificar' 'Si']
#
# Valores únicos en la columna 'exterior': ['Sin especificar' 'Si' 'No']
#
# Valores únicos en la columna 'piscina': ['Si' 'Sin especificar']
#
# Valores únicos en la columna 'calle_alumbrada': ['Sin especificar' 'Si' 'No']
#
# Valores únicos en la columna 'lavadero': ['Sin especificar' 'Si' 'No']
#
# Valores únicos en la columna 'amueblado': ['Sin especificar' 'Si' 'No']
#
# Valores únicos en la columna 'gas': ['Sin especificar' 'Si' 'No']
#
# Valores únicos en la columna 'comedor': ['Sin especificar' 'Si' 'No']
#
# Valores únicos en la columna 'chimenea': ['Sin especificar' 'Si' 'No']
#
# Valores únicos en la columna 'no_se_aceptan_mascotas': ['Sin especificar' 'Si']
#
# Valores únicos en la columna 'telefono': ['Sin especificar' 'Si']

# %%
# Limpieza y unión en la columna 'se_aceptan_mascotas' 
df['se_aceptan_mascotas'] = df.apply(lambda row: 'Si' if row['se_aceptan_mascotas'] == 'Si' else 
                                                ('No' if row['no_se_aceptan_mascotas'] == 'Si' else 'Sin especificar'), axis=1)

df = df.drop(columns=['no_se_aceptan_mascotas'])

# %%
df['orientacion'].value_counts()
# Out:
# orientacion
# Sur                          11580
# Este                          6898
# Sureste                       5466
# Norte                         3631
# Suroeste                      3029
#                              ...
# Sur-este-norte                   1
# Excelente                        1
# N/s                              1
# Oeste, este, a la montaña        1
# Sudeste, noroeste                1
# Name: count, Length: 211, dtype: int64

# %%
# Limpieza en la columna orientacion
mapeo_direcciones = {
    'norte': 'NORTE', 'n': 'NORTE', 'sur': 'SUR', 's': 'SUR', 
    'este': 'ESTE', 'e': 'ESTE', 'oeste': 'OESTE', 'o': 'OESTE', 
    'suroeste': 'SUROESTE', 'so': 'SUROESTE', 'sureste': 'SURESTE', 
    'se': 'SURESTE', 'noreste': 'NORESTE', 'ne': 'NORESTE', 
    'noroeste': 'NOROESTE', 'no': 'NOROESTE', 'este-sur': 'SURESTE', 
    'sur-oeste': 'SUROESTE', 'norte|este': 'NORESTE', 'norte|oeste': 'NOROESTE',
    'sur|este': 'SURESTE', 'north/east': 'NORESTE', 'north/west': 'NOROESTE',
    'south/east': 'SURESTE', 'south/west': 'SUROESTE', 'sur|oeste': 'SUROESTE',
    'norte|este|oeste': 'NORTE', 'se': 'SURESTE', 'sur, este, oeste': 'SUR',
    'norte::este': 'NORESTE', 'norte::oeste': 'NOROESTE', 'sur::este': 'SURESTE', 
    'sur::oeste': 'SUROESTE', 'sur::este::oeste': 'SUR'
}
df['orientacion'] = df['orientacion'].str.lower().map(mapeo_direcciones).fillna('Sin especificar')

# %%
df['orientacion'].value_counts()
# Out:
# orientacion
# Sin especificar    86183
# SUR                11633
# ESTE                6936
# SURESTE             5769
# NORTE               3683
# SUROESTE            3236
# OESTE               2908
# NORESTE             1647
# NOROESTE            1373
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['antiguedad', 'identificador', 'telefono', 'carpinteria_interior',
#        'ascensor', 'portero_automatico', 'armarios_empotrados', 'conservacion',
#        'superficie_construida', 'lavadero', 'calle_alumbrada', 'calefaccion',
#        'calle_asfaltada', 'codigo_postal', 'sistema_de_seguridad',
#        'aire_acondicionado', 'garaje', 'cocina_equipada', 'agencia', 'terraza',
#        'puerta_blindada', 'tipo_de_casa', 'gas', 'href', 'gastos_de_comunidad',
#        'se_aceptan_mascotas', 'adaptado_a_personas_con_movilidad_reducida',
#        'urbanizado', 'comedor', 'soleado', 'habitaciones', 'nombre',
#        'ubicacion', 'exterior', 'jardin', 'superficie_solar', 'planta',
#        'balcon', 'superficie', 'actualizacion', 'emisiones', 'vidrios_dobles',
#        'orientacion', 'precio', 'luz', 'consumo', 'trastero', 'coordenadas',
#        'superficie_util', 'agua', 'baños', 'tipo_suelo', 'chimenea',
#        'alcantarillado', 'precio_m2', 'timestamp', 'carpinteria_exterior',
#        'piscina', 'interior', 'amueblado'],
#       dtype='object')

# %%
# Elimino algunas ya por su poco valor informativo o por ser redundantes(Ej: Soleado se sobreentiende con la columna orientación)
df = df.drop(columns=['urbanizado', 'calle_asfaltada', 'soleado', 'interior'])

# %%
df["antiguedad"].value_counts()
# Out:
# antiguedad
# Más de 50 años        19706
# Entre 30 y 50 años    14209
# Entre 20 y 30 años    11183
# Entre 10 y 20 años    10702
# Menos de 5 años        7504
# Entre 5 y 10 años      1405
# Name: count, dtype: int64

# %%
# Columnas que deben ser 'category'
category_columns = [
    'telefono', 'ascensor', 'portero_automatico', 'armarios_empotrados', 'lavadero',
    'calle_alumbrada', 'calefaccion', 'sistema_de_seguridad', 'aire_acondicionado',
    'garaje', 'cocina_equipada', 'terraza', 'puerta_blindada', 'gas',
    'gastos_de_comunidad', 'adaptado_a_personas_con_movilidad_reducida', 'comedor',
    'exterior', 'jardin', 'balcon', 'vidrios_dobles', 'luz', 'trastero',
    'agua', 'chimenea', 'alcantarillado', 'piscina', 'amueblado'
]

# Columnas que deben ser 'object'
object_columns = [
    'antiguedad', 'identificador', 'carpinteria_interior', 'conservacion',
    'agencia', 'tipo_de_casa', 'href', 'se_aceptan_mascotas',
    'nombre', 'ubicacion', 'actualizacion', 'emisiones',
    'orientacion', 'consumo', 'coordenadas', 'carpinteria_exterior',
    'tipo_suelo', 'codigo_postal'
]

# Cambiar las columnas a category
for col in category_columns:
    df[col] = df[col].astype('category')

# Cambiar las columnas a object
for col in object_columns:
    df[col] = df[col].astype('object')

# Cambiar otros tipos de datos
df['superficie_construida'] = df['superficie_construida'].astype('float64')
df['superficie_solar'] = df['superficie_solar'].astype('float64')
df['superficie'] = df['superficie'].astype('float64')
df['precio'] = df['precio'].astype('float64')
df['superficie_util'] = df['superficie_util'].astype('float64')
df['precio_m2'] = df['precio_m2'].astype('float64')

df['habitaciones'] = df['habitaciones'].astype('Int64')
df['planta'] = df['planta'].astype('Int64')
df['baños'] = df['baños'].astype('Int64')

df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
df.dtypes.astype(str).sort_values()
# Out:
# habitaciones                                           Int64
# baños                                                  Int64
# planta                                                 Int64
# gastos_de_comunidad                                 category
# adaptado_a_personas_con_movilidad_reducida          category
# comedor                                             category
# piscina                                             category
# exterior                                            category
# jardin                                              category
# balcon                                              category
# vidrios_dobles                                      category
# luz                                                 category
# trastero                                            category
# agua                                                category
# chimenea                                            category
# alcantarillado                                      category
# gas                                                 category
# puerta_blindada                                     category
# amueblado                                           category
# calle_alumbrada                                     category
# armarios_empotrados                                 category
# ascensor                                            category
# terraza                                             category
# lavadero                                            category
# calefaccion                                         category
# telefono                                            category
# portero_automatico                                  category
# aire_acondicionado                                  category
# cocina_equipada                                     category
# sistema_de_seguridad                                category
# garaje                                              category
# timestamp                                     datetime64[ns]
# codigo_postal                                        float64
# precio                                               float64
# superficie                                           float64
# superficie_solar                                     float64
# superficie_util                                      float64
# precio_m2                                            float64
# superficie_construida                                float64
# tipo_suelo                                            object
# carpinteria_interior                                  object
# identificador                                         object
# carpinteria_exterior                                  object
# agencia                                               object
# emisiones                                             object
# consumo                                               object
# orientacion                                           object
# conservacion                                          object
# actualizacion                                         object
# ubicacion                                             object
# nombre                                                object
# se_aceptan_mascotas                                   object
# href                                                  object
# tipo_de_casa                                          object
# coordenadas                                           object
# antiguedad                                            object
# dtype: object

# %%
# Obtener los valores únicos de la columna "ubicacion"
ubicaciones = df["ubicacion"].unique()

# Exportar los valores a un archivo .txt
with open("ubicaciones.txt", "w") as file:
    for ubicacion in ubicaciones:
        file.write(ubicacion + "\n")

# %%
df["ubicacion"].unique()
# Out:
# array(['corredor_del_henares', 'madrid_noroeste', 'madrid_norte',
#        'madrid_sur', 'madrid_sureste', 'madrid_suroeste', 'arganzuela',
#        'madrid_capital_barajas', 'barrio_de_salamanca',
#        'madrid_capital_carabanchel', 'madrid_capital_centro',
#        'madrid_capital_chamartin', 'chamberi_distrito', 'ciudad_lineal',
#        'fuencarral_el_pardo', 'hortaleza', 'latina', 'moncloa_aravaca',
#        'moratalaz', 'puente_de_vallecas', 'madrid_capital_retiro',
#        'madrid_capital_san_blas', 'tetuan', 'madrid_capital_usera',
#        'madrid_capital_vicalvaro', 'villa_de_vallecas',
#        'villaverde_distrito', 'rioja_alta', 'rioja_baja', 'rioja_media',
#        'sierra_rioja_alta', 'sierra_rioja_baja',
#        'sierra_rioja_media_cameros', 'area_de_pamplona',
#        'navarra_media_oriental', 'navarra_nafarroa_noroeste', 'pirineos',
#        'navarra_nafarroa_ribera_alta', 'tierra_estella',
#        'navarra_nafarroa_tudela', 'area_de_aviles', 'area_del_nora',
#        'bajo_nalon_area_de_vaqueira', 'asturias_cabo_penas',
#        'camin_real_de_la_mesa_fuentes_del_narcea', 'comarca_de_la_sidra',
#        'gijon_concejo_xixon_conceyu', 'montana_central',
#        'oriente_de_asturias', 'oscos_eo_parque_historico_del_navia',
#        'oviedo_capital', 'valle_del_nalon', 'area_de_santander',
#        'ason_aguera', 'besaya', 'campoo_los_valles',
#        'cantabria_costa_occidental', 'costa_oriental', 'liebana',
#        'saja_nansa', 'trasmiera', 'valles_pasiegos',
#        'altiplano_y_oriental', 'alto_guadalentin', 'area_del_mar_menor',
#        'bajo_guadalentin', 'campo_de_cartagena', 'huerta_de_murcia',
#        'rio_mula_valle_ricote_vega_alta', 'fuerteventura', 'gran_canaria',
#        'lanzarote', 'el_hierro', 'la_gomera', 'la_palma', 'adeje',
#        'arafo', 'arico', 'arona', 'buenavista_del_norte', 'candelaria',
#        'el_rosario', 'el_sauzal', 'el_tanque', 'fasnia', 'garachico',
#        'granadilla_de_abona', 'guia_de_isora', 'guimar',
#        'icod_de_los_vinos', 'la_guancha', 'la_matanza_de_acentejo',
#        'la_orotava', 'la_victoria_de_acentejo', 'los_realejos',
#        'los_silos', 'puerto_de_la_cruz', 'san_cristobal_de_la_laguna',
#        'san_juan_de_la_rambla', 'san_miguel_de_abona',
#        'santa_cruz_de_tenerife_capital', 'santa_ursula',
#        'santiago_del_teide', 'tacoronte', 'tegueste',
#        'vilaflor_de_chasna', 'campina_sur', '_la_serena', 'la_siberia',
#        'llanos_de_olivenza', 'sierra_suroeste', 'tentudia',
#        'tierra_de_badajoz', 'tierra_de_barros',
#        'tierra_de_merida_vegas_bajas', '_vegas_altas', 'zafra_rio_bodion',
#        'alcantara_tajo_salor', 'area_de_caceres', 'campo_aranuelo',
#        'granadilla_las_hurdes', 'la_vera', 'las_villuercas_los_ibores',
#        'plasencia_monfrague', 'sierra_de_gata', 'tierra_de_montanchez',
#        'tierra_de_trujillo', 'valles_de_jerte_y_del_ambroz',
#        'vegas_de_alagon', 'bidasoa', 'debabarrena', 'debagoiena',
#        'donostialdea', 'goierri', 'tolosaldea', 'urola_kosta',
#        'arratia_nerbioi', 'bilbo_handia', 'el_rincon_de_ademuz',
#        'la_hoya_de_bunol', 'la_plana_de_utiel_requena', 'la_ribera_alta',
#        'la_ribera_baixa', 'la_safor', 'la_vall_albaida', 'los_serranos',
#        'valencia_capital', 'alt_vinalopo', 'baix_vinalopo', 'el_comtat',
#        'alacanti', 'alcoia', 'vinalopo_mitja', 'altea', 'benidorm',
#        'benimantell', 'bolulla', 'callosa_en_sarria', 'confrides',
#        'finestrat', 'alfas_del_pi', 'la_nucia',
#        'la_vila_joiosa_villajoyosa', 'orxeta', 'polop', 'relleu',
#        'tarbena', 'area_de_calpe_javea', 'area_de_denia',
#        'area_de_pego_orba', 'albatera', 'benferri', 'orihuela',
#        'pilar_de_la_horadada', 'san_miguel_de_salinas',
#        'acequion_los_naufragos', 'aguas_nuevas_torreblanca_sector_25',
#        'torrevieja_centro', 'la_mata_distrito',
#        'la_siesta_el_salado_torreta_el_chaparral',
#        'los_balcones_los_altos_punta_prima',
#        'torrevieja_nueva_torrevieja',
#        'playa_de_los_locos_los_frutales_cabo_cervera', 'playa_del_cura',
#        'algorfa', 'almoradi', 'benejuzar', 'benijofar', 'bigastro',
#        'callosa_de_segura', 'catral', 'cox', 'daya_nueva', 'daya_vieja',
#        'dolores', 'formentera_del_segura', 'guardamar_del_segura',
#        'jacarilla', 'los_montesinos', 'rafal', 'redovan', 'rojales',
#        'san_fulgencio', 'san_isidro',
#        'andorra_sierra_de_arcos_bajo_martin', 'area_de_teruel',
#        'bajo_aragon_alcaniz', 'cuencas_mineras', 'gudar_javalambre',
#        'jiloca', 'maestrazgo', 'matarrana', 'sierra_de_albarracin',
#        'alto_gallego', 'cinca_la_litera', 'hoya_de_huesca',
#        'la_jacetania', 'la_ribagorza', 'los_monegros', 'sobrarbe',
#        'somontano_de_barbastro', 'aranda_campo_de_borja',
#        'area_de_calatayud', 'area_de_zaragoza',
#        'bajo_aragon_caspe_bajo_cinca',
#        'campo_de_carinena_campo_de_belchite', 'campo_de_daroca',
#        'cinco_villas_la_jacetania_de_zaragoza', 'ribera_alta_del_ebro',
#        'ribera_baja_del_ebro_los_monegros_de_zaragoza',
#        'tarazona_y_el_moncayo', 'valdejalon', 'alt_emporda',
#        'baix_emporda', 'cerdanya_de_girona', 'garrotxa', 'girones',
#        'osona_de_girona', 'pla_de_estany', 'ripolles', 'selva',
#        'alt_urgell', 'alta_ribagorca', 'cerdanya_de_lleida', 'garrigues',
#        'noguera', 'pallars_jussa', 'pallars_sobira', 'pla_urgell',
#        'segarra', 'segria', 'solsones', 'urgell', 'val_aran',
#        'alt_penedes', 'anoia', 'bages', 'baix_llobregat', 'bergueda',
#        'garraf', 'llucanes', 'maresme', 'moianes', 'osona',
#        'valles_oriental', 'valles_occidental_nord',
#        'valles_occidental_sud', 'badalona', 'hospitalet_de_llobregat',
#        'sant_adria_de_besos', 'santa_coloma_de_gramenet', 'ciutat_vella',
#        'barcelona_capital_eixample', 'gracia_distrito', 'horta_guinardo',
#        'barcelona_capital_les_corts', 'nou_barris', 'sant_andreu',
#        'sant_marti', 'sants_montjuic', 'sarria_sant_gervasi', 'a_marina',
#        'a_ulloa_chantada_terra_de_lemos', 'area_de_lugo',
#        'os_ancares_sarria_quiroga', 'terra_cha_meira_a_fonsagrada',
#        'area_de_pontevedra', 'area_de_vigo', 'caldas_tabeiros_deza',
#        'condado_paradanta', 'mino_baixo', 'o_morrazo', 'o_salnes',
#        'allariz_maceda_terra_de_caldelas', 'area_de_ourense',
#        'baixa_limia_a_limia', 'o_carballino_o_ribeiro',
#        'terra_de_celanova', 'terra_de_trives_valdeorras', 'verin_viana',
#        'area_de_a_coruna', 'area_de_betanzos', 'area_de_ferrol',
#        'arzua_ordes_terra_de_melide', 'a_coruna_bergantinos',
#        'fisterra_terra_de_soneira', 'muros_xallas', 'noia_a_barcala',
#        'o_barbanza_o_sar', 'o_eume_ortegal', 'a_coruna_santiago',
#        'guadalajara_alcarria', 'campina', 'senorio_de_molina_alto_tajo',
#        'guadalajara_sierra_norte', 'la_campana_de_oropesa', 'la_jara',
#        'la_mancha_de_toledo', 'la_mesa_de_ocana', 'la_sagra',
#        'los_montes_de_toledo', 'sierra_de_san_vicente', 'toledo_talavera',
#        'toledo_capital', 'toledo_torrijos', 'alcarria', 'mancha_alta',
#        'mancha_baja', 'manchuela', 'serrania_alta', 'serrania_baja',
#        'serrania_media', 'albacete_capital', 'campos_de_hellin',
#        'la_mancha_del_jucar_centro', 'la_manchuela',
#        'monte_iberico_corredor_de_almansa',
#        'sierra_de_alcaraz_y_campo_de_montiel', 'sierra_segura',
#        'alcudia_montes', 'campo_de_calatrava', 'ciudad_real_la_mancha',
#        'ciudad_real_montiel', 'area_de_bejar', 'area_de_ciudad_rodrigo',
#        'area_de_penaranda_de_bracamonte', 'area_de_salamanca',
#        'area_de_vitigudino', 'area_de_arenas_de_san_pedro',
#        'area_de_avila', 'burgohondo_el_tiemblo_cebreros',
#        'el_barco_de_avila_piedrahita', 'la_morana_arevalo',
#        'area_de_cantalejo_riaza', 'area_de_cuellar', 'area_de_segovia',
#        'area_de_almazan', 'area_de_medinaceli', 'area_de_pinares',
#        'area_de_soria', 'campo_de_gomara', 'tierras_altas',
#        'tierras_del_burgo', 'alfoz_de_burgos', 'arlanza', 'ebro',
#        'la_bureba', 'las_merindades', 'montes_de_oca', 'odra_pisuerga',
#        'paramos', 'ribera_del_duero', 'sierra_de_la_demanda',
#        'montana_de_palencia', 'paramos_valles',
#        'tierra_de_campos_cerrato', 'area_de_valladolid',
#        'este_area_de_penafiel', 'norte_area_del_pisuerga_y_esgueva',
#        'oeste_area_de_tordesillas', 'sureste_area_de_iscar_y_olmedo',
#        'suroeste_area_de_medina_del_campo',
#        'tierra_de_campos_de_valladolid', 'area_de_astorga',
#        'area_de_sahagun', 'bierzo', 'el_paramo', 'esla_campos',
#        'la_baneza', 'la_cabrera', 'la_montana_de_luna',
#        'la_montana_de_riano', 'tierras_de_leon', 'alba_tabara',
#        'alfoz_de_toro', 'benavente_los_valles',
#        'la_guarena_tierra_del_vino', 'sanabria_la_carballeda', 'sayago',
#        'tierra_de_campos_de_zamora', 'zamora_tierra_del_pan'],
#       dtype=object)

# %%
#MAPEO POR PROVINCIAS
provincias = {
   'A Coruna': ['area_de_a_coruna', 'area_de_betanzos', 'area_de_ferrol',
       'arzua_ordes_terra_de_melide', 'a_coruna_bergantinos',
       'fisterra_terra_de_soneira', 'muros_xallas', 'noia_a_barcala',
       'o_barbanza_o_sar', 'o_eume_ortegal', 'a_coruna_santiago'],
    'Albacete': ['albacete_capital', 'campos_de_hellin',
       'la_mancha_del_jucar_centro', 'la_manchuela',
       'monte_iberico_corredor_de_almansa',
       'sierra_de_alcaraz_y_campo_de_montiel', 'sierra_segura'],
    'Alicante/Alacant': ['alt_vinalopo', 'baix_vinalopo', 'el_comtat',
       'alacanti', 'alcoia', 'vinalopo_mitja', 'altea', 'benidorm',
       'benimantell', 'bolulla', 'callosa_en_sarria', 'confrides',
       'finestrat', 'alfas_del_pi', 'la_nucia',
       'la_vila_joiosa_villajoyosa', 'orxeta', 'polop', 'relleu',
       'tarbena', 'area_de_calpe_javea', 'area_de_denia',
       'area_de_pego_orba', 'albatera', 'benferri', 'orihuela',
       'pilar_de_la_horadada', 'san_miguel_de_salinas',
       'acequion_los_naufragos', 'aguas_nuevas_torreblanca_sector_25',
       'torrevieja_centro', 'la_mata_distrito',
       'la_siesta_el_salado_torreta_el_chaparral',
       'los_balcones_los_altos_punta_prima',
       'torrevieja_nueva_torrevieja',
       'playa_de_los_locos_los_frutales_cabo_cervera', 'playa_del_cura',
       'algorfa', 'almoradi', 'benejuzar', 'benijofar', 'bigastro',
       'callosa_de_segura', 'catral', 'cox', 'daya_nueva', 'daya_vieja',
       'dolores', 'formentera_del_segura', 'guardamar_del_segura',
       'jacarilla', 'los_montesinos', 'rafal', 'redovan', 'rojales',
       'san_fulgencio', 'san_isidro',],
    'Almeria': [],
    'Araba/Alava': [],
    'Asturias': ['area_de_aviles', 'area_del_nora',
       'bajo_nalon_area_de_vaqueira', 'asturias_cabo_penas',
       'camin_real_de_la_mesa_fuentes_del_narcea', 'comarca_de_la_sidra',
       'gijon_concejo_xixon_conceyu', 'montana_central',
       'oriente_de_asturias', 'oscos_eo_parque_historico_del_navia',
       'oviedo_capital', 'valle_del_nalon'],
    'Avila': ['area_de_arenas_de_san_pedro',
       'area_de_avila', 'burgohondo_el_tiemblo_cebreros',
       'el_barco_de_avila_piedrahita', 'la_morana_arevalo'],
    'Badajoz': ['campina_sur', '_la_serena', 'la_siberia',
       'llanos_de_olivenza', 'sierra_suroeste', 'tentudia',
       'tierra_de_badajoz', 'tierra_de_barros',
       'tierra_de_merida_vegas_bajas', '_vegas_altas', 'zafra_rio_bodion'],
    'Islas Baleares/Illes Balears': [],
    'Barcelona': ['alt_penedes', 'anoia', 'bages', 'baix_llobregat', 'bergueda',
       'garraf', 'llucanes', 'maresme', 'moianes', 'osona',
       'valles_oriental', 'valles_occidental_nord',
       'valles_occidental_sud', 'badalona', 'hospitalet_de_llobregat',
       'sant_adria_de_besos', 'santa_coloma_de_gramenet', 'ciutat_vella',
       'barcelona_capital_eixample', 'gracia_distrito', 'horta_guinardo',
       'barcelona_capital_les_corts', 'nou_barris', 'sant_andreu',
       'sant_marti', 'sants_montjuic', 'sarria_sant_gervasi'],
    'Vizcaya/Bizkaia': ['arratia_nerbioi', 'bilbo_handia'],
    'Burgos': ['alfoz_de_burgos', 'arlanza', 'ebro',
       'la_bureba', 'las_merindades', 'montes_de_oca', 'odra_pisuerga',
       'paramos', 'ribera_del_duero', 'sierra_de_la_demanda'],
    'Caceres': ['alcantara_tajo_salor', 'area_de_caceres', 'campo_aranuelo',
       'granadilla_las_hurdes', 'la_vera', 'las_villuercas_los_ibores',
       'plasencia_monfrague', 'sierra_de_gata', 'tierra_de_montanchez',
       'tierra_de_trujillo', 'valles_de_jerte_y_del_ambroz',
       'vegas_de_alagon'],
    'Cadiz': [],
    'Cantabria': ['area_de_santander',
       'ason_aguera', 'besaya', 'campoo_los_valles',
       'cantabria_costa_occidental', 'costa_oriental', 'liebana',
       'saja_nansa', 'trasmiera', 'valles_pasiegos'],
    'Castellon/Castello': [],
    'Ciudad Real': ['alcudia_montes', 'campo_de_calatrava', 'ciudad_real_la_mancha',
       'ciudad_real_montiel',],
    'Cordoba': [],
    'Cuenca': ['alcarria', 'mancha_alta',
       'mancha_baja', 'manchuela', 'serrania_alta', 'serrania_baja',
       'serrania_media'],
    'Guipuzcoa/Gipuzkoa': ['bidasoa', 'debabarrena', 'debagoiena',
       'donostialdea', 'goierri', 'tolosaldea', 'urola_kosta'],
    'Girona': ['alt_emporda',
       'baix_emporda', 'cerdanya_de_girona', 'garrotxa', 'girones',
       'osona_de_girona', 'pla_de_estany', 'ripolles', 'selva'],
    'Granada': [],
    'Guadalajara': ['guadalajara_alcarria', 'campina', 'senorio_de_molina_alto_tajo',
       'guadalajara_sierra_norte'],
    'Huelva': [],
    'Huesca': ['alto_gallego', 'cinca_la_litera', 'hoya_de_huesca',
       'la_jacetania', 'la_ribagorza', 'los_monegros', 'sobrarbe',
       'somontano_de_barbastro'],
    'Jaen': [],
    'Leon': ['area_de_astorga',
       'area_de_sahagun', 'bierzo', 'el_paramo', 'esla_campos',
       'la_baneza', 'la_cabrera', 'la_montana_de_luna',
       'la_montana_de_riano', 'tierras_de_leon'],
    'Lleida': ['alt_urgell', 'alta_ribagorca', 'cerdanya_de_lleida', 'garrigues',
       'noguera', 'pallars_jussa', 'pallars_sobira', 'pla_urgell',
       'segarra', 'segria', 'solsones', 'urgell', 'val_aran'],
    'Lugo': ['a_marina','a_ulloa_chantada_terra_de_lemos', 'area_de_lugo',
       'os_ancares_sarria_quiroga', 'terra_cha_meira_a_fonsagrada'],
    'Madrid': ['corredor_del_henares', 'madrid_noroeste', 'madrid_norte',
       'madrid_sur', 'madrid_sureste', 'madrid_suroeste', 'arganzuela',
       'madrid_capital_barajas', 'barrio_de_salamanca',
       'madrid_capital_carabanchel', 'madrid_capital_centro',
       'madrid_capital_chamartin', 'chamberi_distrito', 'ciudad_lineal',
       'fuencarral_el_pardo', 'hortaleza', 'latina', 'moncloa_aravaca',
       'moratalaz', 'puente_de_vallecas', 'madrid_capital_retiro',
       'madrid_capital_san_blas', 'tetuan', 'madrid_capital_usera',
       'madrid_capital_vicalvaro', 'villa_de_vallecas',
       'villaverde_distrito'],
    'Malaga': [],
    'Murcia': ['altiplano_y_oriental', 'alto_guadalentin', 'area_del_mar_menor',
       'bajo_guadalentin', 'campo_de_cartagena', 'huerta_de_murcia',
       'rio_mula_valle_ricote_vega_alta'],
    'Navarra': ['area_de_pamplona',
       'navarra_media_oriental', 'navarra_nafarroa_noroeste', 'pirineos',
       'navarra_nafarroa_ribera_alta', 'tierra_estella',
       'navarra_nafarroa_tudela'],
    'Ourense': ['allariz_maceda_terra_de_caldelas', 'area_de_ourense',
       'baixa_limia_a_limia', 'o_carballino_o_ribeiro',
       'terra_de_celanova', 'terra_de_trives_valdeorras', 'verin_viana'],
    'Palencia': ['montana_de_palencia', 'paramos_valles',
       'tierra_de_campos_cerrato'],
    'Las Palmas': ['fuerteventura', 'gran_canaria',
       'lanzarote',],
    'Pontevedra': ['area_de_pontevedra', 'area_de_vigo', 'caldas_tabeiros_deza',
       'condado_paradanta', 'mino_baixo', 'o_morrazo', 'o_salnes'],
    'La Rioja': ['rioja_alta', 'rioja_baja', 'rioja_media',
       'sierra_rioja_alta', 'sierra_rioja_baja',
       'sierra_rioja_media_cameros'],
    'Salamanca': ['area_de_bejar', 'area_de_ciudad_rodrigo',
       'area_de_penaranda_de_bracamonte', 'area_de_salamanca',
       'area_de_vitigudino'],
    'Santa Cruz de Tenerife': ['el_hierro', 'la_gomera', 'la_palma', 'adeje',
       'arafo', 'arico', 'arona', 'buenavista_del_norte', 'candelaria',
       'el_rosario', 'el_sauzal', 'el_tanque', 'fasnia', 'garachico',
       'granadilla_de_abona', 'guia_de_isora', 'guimar',
       'icod_de_los_vinos', 'la_guancha', 'la_matanza_de_acentejo',
       'la_orotava', 'la_victoria_de_acentejo', 'los_realejos',
       'los_silos', 'puerto_de_la_cruz', 'san_cristobal_de_la_laguna',
       'san_juan_de_la_rambla', 'san_miguel_de_abona',
       'santa_cruz_de_tenerife_capital', 'santa_ursula',
       'santiago_del_teide', 'tacoronte', 'tegueste',
       'vilaflor_de_chasna'],
    'Segovia': ['area_de_cantalejo_riaza', 'area_de_cuellar', 'area_de_segovia'],
    'Sevilla': [],
    'Soria': ['area_de_almazan', 'area_de_medinaceli', 'area_de_pinares',
       'area_de_soria', 'campo_de_gomara', 'tierras_altas',
       'tierras_del_burgo'],
    'Tarragona': [],
    'Teruel': ['andorra_sierra_de_arcos_bajo_martin', 'area_de_teruel',
       'bajo_aragon_alcaniz', 'cuencas_mineras', 'gudar_javalambre',
       'jiloca', 'maestrazgo', 'matarrana', 'sierra_de_albarracin'],
    'Toledo': ['la_campana_de_oropesa', 'la_jara',
       'la_mancha_de_toledo', 'la_mesa_de_ocana', 'la_sagra',
       'los_montes_de_toledo', 'sierra_de_san_vicente', 'toledo_talavera',
       'toledo_capital', 'toledo_torrijos'],
    'Valencia': ['el_rincon_de_ademuz',
       'la_hoya_de_bunol', 'la_plana_de_utiel_requena', 'la_ribera_alta',
       'la_ribera_baixa', 'la_safor', 'la_vall_albaida', 'los_serranos',
       'valencia_capital'],
    'Valladolid': ['area_de_valladolid',
       'este_area_de_penafiel', 'norte_area_del_pisuerga_y_esgueva',
       'oeste_area_de_tordesillas', 'sureste_area_de_iscar_y_olmedo',
       'suroeste_area_de_medina_del_campo',
       'tierra_de_campos_de_valladolid'],
    'Zamora': ['alba_tabara',
       'alfoz_de_toro', 'benavente_los_valles',
       'la_guarena_tierra_del_vino', 'sanabria_la_carballeda', 'sayago',
       'tierra_de_campos_de_zamora', 'zamora_tierra_del_pan'],
    'Zaragoza': ['aranda_campo_de_borja',
       'area_de_calatayud', 'area_de_zaragoza',
       'bajo_aragon_caspe_bajo_cinca',
       'campo_de_carinena_campo_de_belchite', 'campo_de_daroca',
       'cinco_villas_la_jacetania_de_zaragoza', 'ribera_alta_del_ebro',
       'ribera_baja_del_ebro_los_monegros_de_zaragoza',
       'tarazona_y_el_moncayo', 'valdejalon'],
    'Ceuta': [],
    'Melilla': [],
    'Cerdanya Francesa': []
}

# %%
#MAPEO POR CCAA
ccaa_provincias = {
    'Pais Vasco': ['Araba/Alava', 'Vizcaya/Bizkaia', 'Guipuzcoa/Gipuzkoa'],
    'Castilla-La Mancha': ['Albacete', 'Ciudad Real', 'Cuenca', 'Guadalajara', 'Toledo'],
    'Comunidad Valenciana': ['Alicante/Alacant', 'Castellon/Castello', 'Valencia'],
    'Andalucia': ['Almeria', 'Cadiz', 'Cordoba', 'Granada', 'Huelva', 'Jaen', 'Malaga', 'Sevilla'],
    'Castilla Y Leon': ['Avila', 'Burgos', 'Leon', 'Palencia', 'Salamanca', 'Segovia', 'Soria', 'Valladolid', 'Zamora'],
    'Extremadura': ['Badajoz', 'Caceres'],
    'Islas Baleares/Illes Balears': ['Islas Baleares/Illes Balears'],
    'Cataluna': ['Barcelona', 'Girona', 'Lleida', 'Tarragona'],
    'Galicia': ['A Coruna', 'Lugo', 'Ourense', 'Pontevedra'],
    'Comunidad De Madrid': ['Madrid'],
    'Region De Murcia': ['Murcia'],
    'Comunidad Foral De Navarra': ['Navarra'],
    'Principado De Asturias': ['Asturias'],
    'Islas Canarias': ['Las Palmas', 'Santa Cruz de Tenerife'],
    'Cantabria': ['Cantabria'],
    'Aragon': ['Huesca', 'Teruel', 'Zaragoza'],
    'Ciudad De Ceuta': ['Ceuta'],
    'Ciudad De Melilla': ['Melilla'],
    'Cerdanya Francesa': ['Cerdanya Francesa']
}
